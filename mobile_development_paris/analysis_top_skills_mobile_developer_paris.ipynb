# %%
import pandas as pd
import os
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('AGGREGATED_DATA_mobile_developer_madrid.csv')

# %%
df.shape
# Out:
# (3099, 16)

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['company_name', 'position', 'location', 'url', 'date_posted',
#        'Number of applicants', 'full-time/part-time', 'seniority level',
#        'employees', 'descriptions', 'industry', 'top competitive skills',
#        'Hiring Trend Company Wide', 'Hiring Trend Company Wide-Engineering',
#        'Median Tenure'],
#       dtype='object')

# %%
pd.DataFrame(df['position'].value_counts()).reset_index()
# Out:
#                                                  index  position
# 0                                    software engineer        72
# 1                        software development engineer        67
# 2                                        ios developer        50
# 3                                    android developer        45
# 4                                       java developer        40
# 5                               java software engineer        39
# 6                               programador full stack        39
# 7                                  full stack engineer        31
# 8                             senior software engineer        28
# 9                                 full stack developer        24
# 10                             senior android engineer        22
# 11                                 fullstack developer        16
# 12                                senior developer net        16
# 13                            senior android developer        16
# 14                                senior ios developer        14
# 15                                ios developer senior        14
# 16                        full stack software engineer        13
# 17                                    android engineer        13
# 18                          software engineer frontend        12
# 19                              programador sharepoint        12
# 20                         full stack engineer decibel        12
# 21                              java backend developer        12
# 22   software engineer full stack bangkok based rel...        11
# 23                                  back end developer        11
# 24                    senior software engineer android        11
# 25                                 c software engineer        10
# 26                                   backend developer        10
# 27                    mobile platform engineer android        10
# 28                         android developer mid level        10
# 29                                   desarrollador ios        10
# 30                                  fullstack engineer        10
# 31                      android developer senior level        10
# 32                             senior backend engineer         9
# 33                        full stack developer react c         9
# 34   senior software engineer android bangkok based...         9
# 35                                  software developer         9
# 36                               programador fullstack         9
# 37                        mobile platform engineer ios         9
# 38   senior software engineer full stack bangkok ba...         9
# 39                       engineer software development         9
# 40                          desarrollador a full stack         9
# 41                                    programador java         9
# 42         development team full stack digital product         8
# 43                        software developer go remote         8
# 44                                mobile developer ios         8
# 45                               ios software engineer         8
# 46                                       net developer         8
# 47               android developer different locations         8
# 48         medior senior full stack for property squad         8
# 49                           software engineer backend         8
# 50                  dev ops senior engineer full stack         8
# 51   software developer go python acronis cyber pro...         8
# 52                backend developer go c cybersecurity         8
# 53              software engineer backend nodejs d f m         8
# 54                             android developer tidal         8
# 55                           backend software engineer         8
# 56         software developer go c acronis cyber files         8
# 57               front end developer software engineer         8
# 58                                ios mobile developer         8
# 59                                     programador plc         8
# 60                                    programador abap         8
# 61                senior go python c developer godaddy         8
# 62   software developer c with willingness to switc...         8
# 63                                  programador a abap         7
# 64                                     atc sw engineer         7
# 65                          fullstack python developer         7
# 66   senior frontend software engineer angular java...         7
# 67                     software engineer go 100 remoto         7
# 68                               desarrollador a con c         7
# 69                            desarrollador de android         7
# 70                               software engineer php         7
# 71                                     c developer ati         7
# 72                senior engineer software development         7
# 73                     ios engineer remote or relocate         7
# 74                          ios swift senior developer         7
# 75          senior software engineer backend analytics         7
# 76                         senior mobile app developer         7
# 77        senior backend developer acronis cyber files         7
# 78                    senior developer c cyber protect         7
# 79   senior frontend software engineer angular java...         7
# 80       software developer go global maintenance team         7
# 81                                      spark designer         7
# 82                           android software engineer         7
# 83                             java software developer         7
# 84   senior frontend software engineer javascript a...         7
# 85                            desarrollador full stack         7
# 86        senior kernel software developer for windows         7
# 87                              software engineer java         7
# 88                           software engineer fintech         7
# 89                                  desarrollador de c         7
# 90                      sw engineer production support         7
# 91                               ingeniero de software         7
# 92                                   ios app developer         7
# 93             software engineer back end core engines         6
# 94                              senior mobile engineer         6
# 95              software engineer frontend react d f m         6
# 96             c net developer full stack net core wpf         6
# 97   software developer go or c acronis management ...         6
# 98                      software engineer java galileo         6
# 99                    infrastructure software engineer         6
# 100                    senior android engineer fintech         6
# 101                           android engineer fintech         6
# 102                         senior prgrammer fullstack         6
# 103              software engineer ruby on rails react         6
# 104  software engineer vs code tooling language ser...         6
# 105                senior software engineer full stack         6
# 106        php python c developer hosting integrations         6
# 107         senior c software developer virtualization         6
# 108                c engineer for database development         6
# 109  lead staff software engineer android bangkok b...         6
# 110               senior software development engineer         6
# 111                        c or java software engineer         6
# 112              senior full stack engineer javascript         6
# 113                            pega analyst developers         6
# 114                      frontend software engineer ui         6
# 115  senior php python c developer hosting integrat...         6
# 116                    programador senior c 100 remoto         6
# 117                               programador abap h m         6
# 118       senior software engineer backend remote emea         6
# 119                                         programmer         6
# 120      senior android developer streaming team tidal         6
# 121                   open source software engineer go         5
# 122  full time software developer madrid english re...         5
# 123                  software engineer ide integration         5
# 124          programador senior nodejs 100 teletrabajo         5
# 125          senior full stack developer react node js         5
# 126          remote senior android developer full time         5
# 127                    senior mobile developer flutter         5
# 128                           mobile engineer frontend         5
# 129               senior software developer innovación         5
# 130                 principal software engineer mobile         5
# 131           internship software engineer bmw project         5
# 132                          junior software developer         5
# 133                                         full stack         5
# 134  senior data software engineer bangkok based re...         5
# 135                       mobile developer ios android         5
# 136                                   mobile developer         5
# 137                 junior full stack engineer decibel         5
# 138  junior frontend software engineer angular java...         5
# 139                          fullstack engineer madrid         5
# 140                                powershell engineer         5
# 141                              desarrollador a c h m         5
# 142                     associate ios engineer fintech         5
# 143                  backend software engineer node js         5
# 144                     back end o full stack engineer         5
# 145                        senior full stack developer         5
# 146                          senior software developer         5
# 147  lead staff full stack software engineer bangko...         5
# 148     full stack developer python javascript angular         5
# 149                        software engineer launchpad         5
# 150                               ios engineer fintech         5
# 151                        desarrollador ios swift v 4         5
# 152                           senior frontend engineer         5
# 153  full remote mid senior react nodejs frontend b...         5
# 154                                 frontend developer         5
# 155                       software engineer blockchain         5
# 156                          full stack angular y node         5
# 157  full stack nodejs react software engineer madr...         5
# 158                 business analyst software engineer         5
# 159                   frontend software engineer f m d         5
# 160                software engineer planning tracking         5
# 161                      programador visión artificial         5
# 162                     full stack software programmer         5
# 163  senior software engineer full stack engineer f...         5
# 164  calypso technical analyst ingeniero a de software         5
# 165                    senior software engineer remote         5
# 166                    microservices software engineer         5
# 167  blockchain ethereum fullstack software enginee...         5
# 168                         hq senior android engineer         5
# 169                             sr fullstack developer         5
# 170                     desarrollador a android kotlin         5
# 171                           c java software engineer         5
# 172                                       ios engineer         5
# 173  senior fullstack web developer acronis cyber f...         5
# 174              desarrollador a c para sistemas radar         5
# 175                               mobile test engineer         5
# 176                               qa software engineer         5
# 177                      full stack software developer         5
# 178                           online software engineer         5
# 179                       programador business central         5
# 180        senior full stack developer nodejs react js         5
# 181      software engineer openstack networking remote         5
# 182  senior software engineer backend spain relocation         5
# 183                               ios junior developer         5
# 184                                  clojure developer         5
# 185      full stack developer mean mern open to remote         4
# 186       software developer satellite control centers         4
# 187  full stack developer react python django open ...         4
# 188         mobile developer ios android hybrid madrid         4
# 189            desarrollador full stack jr teletrabajo         4
# 190                              full stack java react         4
# 191                  engineering manager full stack ui         4
# 192       full stack engineer front end specialisation         4
# 193               ingeniero a de desarrollo software c         4
# 194                 fullstack engineer remote friendly         4
# 195                               senior php developer         4
# 196                       fullstack developer sr react         4
# 197                    full stack developer java react         4
# 198                    android senior developer remoto         4
# 199  senior software engineer kubernetes multi clus...         4
# 200               senior fullstack developer to madrid         4
# 201                   senior software engineer fintech         4
# 202              full stack mid senior level developer         4
# 203                        programador front angular 8         4
# 204                      desarrollador java full stack         4
# 205                      mobile developer spain remote         4
# 206                                     react engineer         4
# 207                   full stack php y mysql developer         4
# 208                   android mobile backend developer         4
# 209               senior full stack developer ruby vue         4
# 210                 desarrolladores sénior android ios         4
# 211            full stack developer nodejs vuejs m w d         4
# 212         open source software engineer integrations         4
# 213            full stack developer net angular remote         4
# 214                         developer evangelist spain         4
# 215                         junior full stack engineer         4
# 216                  desarrollador móvil ios y android         4
# 217                       software developer front end         4
# 218                      full stack developer big data         4
# 219                      fullstack developer sr micros         4
# 220                   sr full stack big data developer         4
# 221     desarrollador a full stack react js net remoto         4
# 222  engineering student and graduate program remot...         4
# 223       sr software engineer staff software engineer         4
# 224                          full stack engineer rails         4
# 225          full stack engineer javascript java f m d         4
# 226                back end developer java spring boot         4
# 227                   software engineer event aug sept         4
# 228                  senior software engineer back end         4
# 229           full stack developer java open to remote         4
# 230                              desarrollador angular         4
# 231                   senior full stack developer java         4
# 232  senior software engineer real time microservic...         4
# 233    full stack software engineer marketing platform         4
# 234                               servicenow developer         4
# 235  senior software developer performance advanced...         4
# 236                            desarrollador a android         4
# 237                 full stack developer node js f m d         4
# 238  senior fullstack developer remote friendly 40 50k         4
# 239                  ingeniero a de software fullstack         4
# 240                desarrollador fullstack react azure         4
# 241           senior full stack engineer ruby on rails         4
# 242            senior software engineer ansible remote         4
# 243            software engineer java senior developer         4
# 244                           software engineer python         4
# 245                         full stack node js angular         4
# 246              senior software engineer spain remote         4
# 247  full stack software developer rails vulnerabil...         4
# 248          space critical on board software engineer         4
# 249                  analista desarrollador full stack         4
# 250            senior frontend software engineer f m d         4
# 251                   senior android software engineer         4
# 252                ingeniero de desarrollo de software         4
# 253                           fullstack java developer         4
# 254                          aem full stack consultant         4
# 255                 javascript full stack engineer aws         4
# 256              open source software engineer node js         4
# 257  senior software engineer linux virtualization ...         4
# 258  senior software engineer ios bangkok based rel...         4
# 259                          fullstack engineer intern         4
# 260                       développeur fullstack js h f         4
# 261                    open source software engineer c         4
# 262                           golang software engineer         4
# 263               full stack developer programador web         4
# 264                    software engineer accessibility         4
# 265                   senior software engineer backend         4
# 266               observability senior go engineer apm         4
# 267               desarrollador fullstack node angular         4
# 268  fullstack developer php symfony vuejs 100 remo...         4
# 269                        ios senior developer remote         4
# 270                     c developer cloud integrations         4
# 271                       ios test automation engineer         4
# 272                  principal full stack ui developer         4
# 273                desarrollador senior android kotlin         4
# 274                    software engineer global twilio         4
# 275                    programador front angular html5         4
# 276                           desarrollador a software         4
# 277                          fullstack engineer senior         4
# 278                             full stack php angular         4
# 279         junior mid full stack javascript developer         4
# 280                    sw development engineer in test         4
# 281                         full stack engineer python         4
# 282                                    groovy engineer         4
# 283  ingeniero a de software fullstack nodejs angul...         4
# 284  senior software engineer advanced cluster secu...         4
# 285                  programador google gas javascript         4
# 286                         full stack engineer remote         4
# 287                           software engineer devops         4
# 288                      rendering software engineer c         4
# 289  software engineer junior 1 3 years of experien...         4
# 290           full stack engineer net sector insurtech         4
# 291                   desarrollador fullstack net core         4
# 292              desarrollador a ios objective c swift         4
# 293                   ios engineer b2c fintech lending         4
# 294                         backend software developer         4
# 295                        full stack senior developer         4
# 296           observability senior full stack engineer         4
# 297                                   python developer         4
# 298                         sr full stack ui developer         4
# 299                         senior fullstack developer         4
# 300                            erlang developer remote         4
# 301               full stack developer dubai or remote         4
# 302               desarrollador fullstack java angular         4
# 303               software engineer saas python remote         4
# 304                           android developer remoto         4
# 305                               desarrolladores java         4
# 306                                 data scientist f m         4
# 307                            mid full stack engineer         4
# 308            desarrollador ios desarrollador android         4
# 309                   senior full stack data scientist         4
# 310  full stack engineer data team all levels bangk...         4
# 311       software engineer voice regional engineering         4
# 312  elasticsearch senior software engineer analyti...         4
# 313                       desarrollador senior android         4
# 314              desarrollador de aplicaciones móviles         4
# 315                         fullstack developer junior         4
# 316  software development engineer cloud iaas security         4
# 317                        full stack developer remote         4
# 318                  manual qa engineer mobile fintech         4
# 319                      fullstack developer c angular         4
# 320       full stack developer java angular 100 remote         4
# 321  desarrollador full stack full stack developer ...         4
# 322                        software developer back end         4
# 323                             software developer sas         4
# 324                       software engineer devops sre         4
# 325                    jnr full stack engineer decibel         4
# 326  ingenieros front end full stack junior onsite ...         4
# 327                 software engineer billing platform         4
# 328         senior full stack engineer ai spain remote         4
# 329           programador full stack a tiempo completo         4
# 330                fcas2021 full stack developer d m f         4
# 331               programador front angular desarrollo         4
# 332       mobile developer react native open to remote         4
# 333                       desarrollador android senior         4
# 334                      staff full stack ui developer         4
# 335  senior backend developer golang c protection f...         4
# 336                                        c developer         4
# 337                    go developer acronis devicelock         3
# 338                       java cloud software engineer         3
# 339                                      ios team lead         3
# 340                          senior frontend developer         3
# 341  software development engineer emea multiple lo...         3
# 342                        software engineer js madrid         3
# 343                 ingeniero a de software javascript         3
# 344                         3d software engineer cloud         3
# 345                        cloud native java developer         3
# 346  data engineer apache spark java scala bangkok ...         3
# 347                            programador a java j2ee         3
# 348                  navigation sw algorithms engineer         3
# 349       java groovy senior backend software engineer         3
# 350                        software engineer iot cloud         3
# 351            senior frontend developer total protect         3
# 352              senior elixir software engineer d f m         3
# 353                         frontend software engineer         3
# 354                                senior ios engineer         3
# 355  senior software engineer go prometheus monitor...         3
# 356                         software engineer back end         3
# 357  software engineer design and validation space ...         3
# 358  senior servicenow developer poland or spain re...         3
# 359                      desarollador a android kotlin         3
# 360                              programador dynatrace         3
# 361                    desarrollador a software junior         3
# 362    senior software engineer scala edge engineering         3
# 363    graduate java developer consultant madrid spain         3
# 364  ingeniero a de desarrollo sw de aplicación pro...         3
# 365                   software engineer space missions         3
# 366                        desarrollador c sobre linux         3
# 367                  desarrollador desarrolladora java         3
# 368  senior software engineer trilogy remote 60 000...         3
# 369                       senior backend engineer java         3
# 370                         fullstack developer madrid         3
# 371  java developer big data platform bangkok based...         3
# 372                   senior frontend developer vue js         3
# 373                                      programador c         3
# 374                              software q a engineer         3
# 375                               c software developer         3
# 376                azure cloud microservices architect         3
# 377              analista programador a android senior         3
# 378                     sw engineer for ground segment         3
# 379                   programador mobile ios o android         3
# 380  senior software engineer openstack nova comput...         3
# 381                                 java bpm developer         3
# 382  software engineer trilogy remote 200 000 year usd         3
# 383  software development engineer graduate 2020 20...         3
# 384                             software engineer gnss         3
# 385     observability senior go engineer elastic agent         3
# 386                       c backend software developer         3
# 387                         devops desarrollador azure         3
# 388             java developer consultant madrid spain         3
# 389                     senior software engineer m f d         3
# 390                           junior programmer oracle         3
# 391          appln architect azure cloud modernization         3
# 392                    golang senior software engineer         3
# 393  senior software engineer migration toolkit for...         3
# 394                               net senior developer         3
# 395                                programador android         3
# 396            senior software engineer open to remote         3
# 397                           sr software dev engineer         3
# 398                         software engineer for gnss         3
# 399                    sdet software developer testing         3
# 400  software development engineer various location...         3
# 401                          desarrollador a sw appian         3
# 402                        full stack junior developer         3
# 403                       microservices java developer         3
# 404          software engineer docker images community         3
# 405                     software backend engineer java         3
# 406            software engineer localisation platform         3
# 407                          desarrollador de software         3
# 408                                software engineer c         3
# 409  desarrollador a de aplicaciones de movilidad t...         3
# 410          software engineer developer observability         3
# 411              analista programador frontend android         3
# 412                               desarrollador nodejs         3
# 413                  app dev solution sales specialist         3
# 414                       ingeniero sw c video cdn 45k         3
# 415       outqar076 backend java engineer api managers         3
# 416                        programador a front angular         3
# 417                                    desarrollador c         3
# 418                  software engineer for rail sector         3
# 419  senior software engineer customer development ...         3
# 420            senior software engineer backend remote         3
# 421              senior frontend developer backup core         3
# 422                                    programador net         3
# 423                      senior ruby software engineer         3
# 424                        es programador de ios swift         3
# 425        software engineer javascript space projects         3
# 426  programadol 200mg full stack developer startup...         3
# 427            java backend developers based in madrid         3
# 428                   frontend software engineer m w d         3
# 429                          programador apx aso cells         3
# 430         senior software engineer release platforms         3
# 431                                  senior c engineer         3
# 432                              desarrollador de java         3
# 433                         programador con banksphere         3
# 434          becario de full stack developer en madrid         2
# 435                   desarrollador experienced appian         2
# 436                    lead full stack engineer 48 000         2
# 437                           consultor programador bi         2
# 438                    senior frontend engineer madrid         2
# 439                 desarrollador a de software c java         2
# 440         técnico desarrollo de aplicaciones daw dam         2
# 441   ingeniero de software integración continua ci cd         2
# 442                               qlik sense developer         2
# 443                             analista desarrollador         2
# 444                   desarrollador angular remoto 100         2
# 445                         desarrollador a c wpf xaml         2
# 446                          crm application developer         2
# 447  desarrolladores y analistas programadores spri...         2
# 448                         desarrollador react remoto         2
# 449       desarrolladores as senior java spring oracle         2
# 450                   sr software development engineer         2
# 451               software development engineer madrid         2
# 452                      desarrollador de aplicaciones         2
# 453                       java microservicios engineer         2
# 454                        software engineer devsecops         2
# 455                      syap application developer fg         2
# 456          senior software engineer machine learning         2
# 457                             programador a java h m         2
# 458                          desarrollador powercenter         2
# 459                           java kotlin engineer emv         2
# 460  developer in test performance automation qa en...         2
# 461                           desarrollador servicenow         2
# 462                     desarrollador nodejs remoto100         2
# 463                  desarrollador a kendo y o angular         2
# 464               desarrolladores front back fullstack         2
# 465               desarrollador a integración continua         2
# 466                                 programador a java         2
# 467        elasticsearch java engineer query languages         2
# 468            senior full stack engineer celonis labs         2
# 469                             full stack js engineer         2
# 470                                front end developer         2
# 471                    senior software engineer python         2
# 472                      desarrolladores as appian bpm         2
# 473                             backend developer java         2
# 474                   software development engineer ii         2
# 475                                      vue developer         2
# 476                           adobe campaign developer         2
# 477               backend engineer senior growth squad         2
# 478               senior desktop application developer         2
# 479      software engineer juju go distributed systems         2
# 480                                 mid java developer         2
# 481                              application developer         2
# 482                        desarrolladores java spring         2
# 483  senior software engineer kubernetes and opensh...         2
# 484                            desarrolladores móviles         2
# 485        go python developer disaster recovery cloud         2
# 486                               java spring engineer         2
# 487                               maquetador developer         2
# 488                         java javascript programmer         2
# 489                       field software engineer emea         2
# 490       backend engineer brands and partners revenue         2
# 491             ingeniero a software embarcado crítico         2
# 492                                     node developer         2
# 493                         programador fullstack java         2
# 494                  senior frontend developer storage         2
# 495                                xflow developer m f         2
# 496                        programador java vb net h m         2
# 497            senior golang c developer cybersecurity         2
# 498   ingeniero software embebido microblaze arm linux         2
# 499                                 desarrollador odoo         2
# 500                  desarrollador cloud madrid remoto         2
# 501                         java developer con francés         2
# 502  messaging and collaboration specialist evening...         2
# 503                             react senior developer         2
# 504                                    programador a c         2
# 505                               power apps developer         2
# 506                              privacy it specialist         2
# 507                             programador salesforce         2
# 508                                developer fullstack         2
# 509                    desarrollador mobile ios senior         2
# 510                              desarrollador flutter         2
# 511                   junior devops engineer cloud aws         2
# 512  elasticsearch principal java engineer security...         2
# 513                   java application engineer madrid         2
# 514          ms power platform developer supporter m f         2
# 515         lingüista computacional desarrollador a ia         2
# 516                         es developer microservices         2
# 517  backend software engineer remote euro crypto e...         2
# 518  python backend developer acronis cyber infrast...         2
# 519                   desarrolladores y analistas java         2
# 520                               software developer c         2
# 521                  desarrollador analista bpm appian         2
# 522  backend software engineer fully remote crypto ...         2
# 523          desarrollador a de aplicaciones cloud aws         2
# 524                   software engineer backend secops         2
# 525                 desarrollador perfil angular react         2
# 526                             desarrollador a appian         2
# 527  application developer c developer desarrollador c         2
# 528                            senior python developer         2
# 529                            programador a o ap java         2
# 530                            junior backend engineer         2
# 531                             desarrollador senior c         2
# 532       devops python developer to global rnd devops         2
# 533                                 graduate developer         2
# 534                            front end web developer         2
# 535                  programador a java microservicios         2
# 536                              developer job stage 4         2
# 537                             backend java developer         2
# 538                      syap application developer dc         2
# 539                     desarrollador a microservicios         2
# 540               relocation java developer all levels         2
# 541                   programador en java y kubernetes         2
# 542                       desarrollador a para cluster         2
# 543                          desarrollador de back end         2
# 544  sr software development engineer in test ecosy...         2
# 545                   prácticas curriculares developer         2
# 546                   ingeniero a de software net java         2
# 547                        ingeniero desarrollador rpa         2
# 548                      syap application developer rd         2
# 549                        frontend software developer         2
# 550        senior backend software engineer java f m d         2
# 551    technology application developer c powerbuilder         2
# 552                             saas software engineer         2
# 553                          desarrollador python nifi         2
# 554                  ingeniero a software java angular         2
# 555                       programador senior abap hana         2
# 556                         programador java fullstack         2
# 557            senior software engineer space projects         2
# 558                       psse fortran model developer         2
# 559                                desarrollador a rpa         2
# 560                                  api developer sgt         2
# 561                   cloud software developer java go         2
# 562      desarrollador a fpga para sistemas espaciales         2
# 563               programador java angular teletrabajo         2
# 564                                desarrollador react         2
# 565             frontend developer virtualization team         2
# 566          desarrollador a front angular teletrabajo         2
# 567                    programador java spring angular         2
# 568                      es big data software engineer         2
# 569                        programador a java big data         2
# 570                                 senior ux designer         2
# 571      application developer cornerstone id 210006nx         2
# 572       desarrolladores no code modeladores técnicos         2
# 573            java software engineer insurtech madrid         2
# 574                    desarrollador react teletrabajo         2
# 575                            desarrollador a angular         2
# 576              desarrollad r de aplicaciones móviles         2
# 577                         syap application developer         2
# 578                   programador java teletrabajo 100         2
# 579                         java developer id 210005gq         2
# 580                                 programador junior         2
# 581                  java software engineer remoto 100         2
# 582                senior software engineer iam crypto         2
# 583                                       go developer         2
# 584                               java hcis developers         2
# 585  remote working senior online programmer aaa sp...         2
# 586                                es programador java         2
# 587                                   backend engineer         2
# 588               ingeniero a de software java galileo         2
# 589                        programador java postgresql         2
# 590               programador java desarrollo software         2
# 591               google cloud microservices architect         2
# 592       systems level software developer for windows         2
# 593                ingeniero a ip mpls productos nokia         2
# 594              senior back end engineer core banking         2
# 595  java staff engineer workspace one orchestrator...         2
# 596                          desarrollador php soporte         2
# 597               programador a ap java microservicios         2
# 598                 java support engineer madrid spain         2
# 599                                       xr developer         2
# 600                      developer dynamics 365 f o ax         2
# 601  react native developer also available for full...         2
# 602               computer technician software support         2
# 603  programador a net para mantenimiento aplicacio...         2
# 604                         display campaign developer         2
# 605                       ingeniero a de software java         2
# 606          programador a y técnico a de soporte java         2
# 607                 open source software engineer java         2
# 608                        programador a senior siebel         2
# 609               staff backend engineer f m d payroll         2
# 610                                 manager salesforce         1
# 611  frontend engineer employee performance develop...         1
# 612  software developer in test automation qa engin...         1
# 613            senior js developer advanced automation         1
# 614  mission planning and development system softwa...         1
# 615                  senior frontend developer angular         1
# 616  senior developer c go acronis cyber infrastruc...         1
# 617            product engineer celonis for consulting         1
# 618              backend engineer data platform madrid         1
# 619                       python spring boot developer         1
# 620      senior frontend developer acronis cyber files         1
# 621  staff software engineer ruby on rails and java...         1
# 622                     back end developer with german         1
# 623                         senior software engineer c         1
# 624  open source software engineer php extension ma...         1
# 625                           senior back end engineer         1
# 626  open source software engineer container ecosys...         1
# 627                                    azure architect         1
# 628       programadores as sin experiencia ios android         1
# 629                        programador a c inglés alto         1
# 630  outqar071 senior backend java developer devops...         1
# 631             web developer wordpress open to remote         1
# 632         appln architect google cloud modernization         1
# 633                              desarrollador backend         1
# 634     ingeniero a desarrollo electrónica de potencia         1
# 635        sap ibp_advanced app engineering specialist         1
# 636                       senior build engineer mobile         1
# 637                 senior c c developer platform team         1
# 638              web developer drupal 8 open to remote         1
# 639                             back end web developer         1
# 640                         engineering manager mobile         1
# 641  tech transformation digital solution architect...         1
# 642                          programador a plc y scada         1
# 643                       desarrollador full stack net         1
# 644                         backend engineer invoicing         1
# 645                            fullstack developer net         1
# 646                   backend software engineer revops         1
# 647                 performance automation qa engineer         1
# 648  senior backend software engineer java kotlin f...         1
# 649                        mobile technical leader h m         1
# 650        senior frontend developer disaster recovery         1
# 651                  ingeniero de proyectos automoción         1
# 652                         backend developer java8 11         1
# 653                  platform specialist web developer         1
# 654                             mid frontend developer         1
# 655  senior golang developer performance advanced a...         1
# 656              react react native frontend tech lead         1
# 657                      ingeniero a de desarrollo net         1
# 658                      php backend developer laravel         1
# 659  desarrollador microservicios kafka 100 teletra...         1
# 660        ingeniero a senior desarrollo front angular         1
# 661                     fullstack php developer junior         1
# 662                               ui software engineer         1
# 663                       principal software developer         1
# 664  senior database developer cyber and business s...         1
# 665                   desarrollador a front end mobile         1
# 666           linux developer go c c php cybersecurity         1
# 667                                  programador linux         1
# 668    application architect azure cloud modernization         1
# 669  senior python developer in cloud integrations ...         1
# 670                   backend developer net remote 100         1
# 671                  product manager software engineer         1
# 672                        desarrollador de software c         1
# 673             appn architect aws cloud modernization         1
# 674                      backend developer apache nifi         1
# 675                         programador senior soporte         1
# 676                    senior frontend developer m f d         1
# 677                                programador c jr sr         1
# 678                                      product owner         1
# 679                      senior backend engineer f m d         1
# 680  azure monitoring abrs security identity suppor...         1
# 681                          senior front end engineer         1
# 682              backend developer acronis cyber files         1
# 683               google cloud advisory solutions lead         1
# 684                          devops lifecycle engineer         1
# 685                                        qa engineer         1
# 686                desarrollador movilidad android ios         1
# 687              senior database engineer spain remote         1
# 688                                senior software net         1
# 689  desarrollador a de aplicaciones web typescript...         1
# 690                                   groovy developer         1
# 691                 senior software engineer front end         1
# 692  principal software engineer full stack localiz...         1
# 693                         programador de php backend         1
# 694                       back end developer freelance         1
# 695                           desarrollador a c python         1
# 696  analista programador a frontend backend movilidad         1
# 697    software development engineer ab marketing tech         1
# 698         ingeniero a de desarrollo hardware y fpgas         1
# 699        programador a react redux trabajo en remoto         1
# 700                               web developer madrid         1
# 701           lead python developer cloud integrations         1
# 702                desarrollador a scripting telefonía         1
# 703  application security analyst consultant implem...         1
# 704          backend engineer billings and settlements         1
# 705                           desarrollador c embebido         1
# 706                 senior front end software engineer         1
# 707  backend software engineer remote fully crypto ...         1
# 708                 ingeniero desarrollo movilidad ios         1
# 709                                      web developer         1
# 710                  sr backend python engineer london         1
# 711        senior golang developer advanced automation         1
# 712               senior software engineer ruby stella         1
# 713  programador java net cloud devops 100 teletrabajo         1
# 714                               commercial developer         1
# 715  programador a e implementador a plataforma moo...         1
# 716                              mid backend developer         1
# 717    junior frontend developer acronis cyber protect         1
# 718  lead staff software engineer ios bangkok based...         1
# 719                                     sales engineer         1
# 720           frontend developer acronis cyber protect         1
# 721  junior backend engineer f m d ruby on rails ma...         1
# 722                       software development manager         1
# 723                              desarrollador pentaho         1
# 724            programador senior y programador junior         1
# 725       software engineer high performance computing         1
# 726                 java con big data developer remoto         1
# 727                web developer moodle open to remote         1
# 728             senior business intelligence developer         1
# 729                              software engineer m f         1
# 730                     ingeniero a de software senior         1
# 731                        systems software engineer c         1
# 732  back end lead staff software engineer bangkok ...         1
# 733  ingeniero de desarrollo tramitación proyectos ...         1
# 734  lead software developer c golang acronis cyber...         1
# 735         senior backend engineer payments and fraud         1
# 736                          marketing cloud developer         1
# 737  automated qa developer python golang platform ...         1
# 738        desarrollador software embebido labview y c         1
# 739                      software engineer backend web         1
# 740                         analista desarrollador rpa         1
# 741             ingeniero de software frontend backend         1
# 742  application security analyst consultant valida...         1
# 743                   desarrollador a sw appian madrid         1
# 744  observability senior software engineer develop...         1
# 745        srvqar068 senior backend java engineer bots         1
# 746  tech transformation digital solution architect...         1
# 747                                desarrollador a aws         1
# 748                         senior front end developer         1
# 749                 front end web developer cms author         1
# 750    principal kernel software developer for windows         1
# 751  senior automation qa acronis cyber infrastructure         1
# 752       recién titulados accenture technology madrid         1
# 753                     frontend developer backup core         1
# 754         programador frontend y programador backend         1
# 755                        front end developer angular         1
# 756         sap pp pm_advanced app engineering manager         1
# 757          senior solution architect pre sales spain         1
# 758            appln architect aws cloud modernization         1
# 759                         programador backend senior         1
# 760           senior net developer advanced automation         1
# 761  back end team engineer bangkok based relocatio...         1
# 762                          software engineering lead         1
# 763                            backend engineer madrid         1
# 764                           devops platform engineer         1
# 765  lead kernel software developer acronis cyber i...         1
# 766                        architect digital platforms         1
# 767                    lead frontend developer storage         1
# 768      software development engineer amazon business         1
# 769  camera app developer focus embedded image anal...         1
# 770  observability senior software engineer browser...         1
# 771                      cloud ignite graduate program         1
# 772                                  creative designer         1
# 773                              programador websphere         1
# 774                                    programador h m         1
# 775                                 solutions engineer         1
# 776    remote working c programmer aaa sport ips spain         1
# 777                python back end developer dubai uae         1
# 778              senior sales engineer southern europe         1
# 779                     frontend web developer fintech         1
# 780                                  solution engineer         1
# 781                     programador backend php senior         1
# 782                      backend engineer web services         1
# 783                     director of product management         1
# 784         ingeniero a de desarrollo coach devops h m         1
# 785                  aws cloud microservices architect         1
# 786                   programador front angular remoto         1
# 787                              junior java developer         1
# 788                 learning development web developer         1
# 789                          c software engineer modes         1
# 790                            backend engineer 65 000         1
# 791                         back end node js developer         1

# %%
df['position'] = df['position'].apply(lambda x: x.lower())
df['descriptions'] = df['descriptions'].apply(lambda x: x.lower())

# %%
def filter_df(x, y):
    if ('mobile' in x) or ('android' in x) or ('ios' in x) or ('swift' in x) or ('kotlin' in x) :
        return "keep"
    else:
        if ('android' in y) or ('ios' in y) or ('mobile development' in y) or ('mobile developer' in y):
            return 'keep'
        elif ('swift' in y) or ('kotlin' in y):
            return 'keep'
        else:
            return 'remove'

# %%
df['new_filter'] = list(map(filter_df, df['position'], df['descriptions']))

# %%
df = df[df['new_filter']=='keep'].reset_index(drop=True)
df = df.drop(['new_filter'], axis=1)

# %%
df.shape
# Out:
# (1430, 15)

# %% [markdown]
# # Top Companies Hiring

# %%
temp = pd.DataFrame(df['company_name'].value_counts()).reset_index()
temp.columns =['company_name', 'number of postings']
temp.head(30)
# Out:
#                      company_name  number of postings
# 0                           agoda                  45
# 1                           tymit                  41
# 2                          inetum                  35
# 3                         zendesk                  35
# 4   serem consultoría empresarial                  31
# 5           capgemini engineering                  28
# 6                          everis                  27
# 7                  page personnel                  24
# 8                          veepee                  22
# 9                  robert walters                  21
# 10               innocv solutions                  21
# 11               accenture españa                  21
# 12                      pulselive                  20
# 13                        ekkiden                  19
# 14                        acronis                  19
# 15                     acid tango                  18
# 16                         cabify                  18
# 17                         amazon                  17
# 18                      grupo cmc                  17
# 19     idential global consulting                  17
# 20                       devoteam                  16
# 21                          indra                  15
# 22                          fever                  15
# 23                      nexplayer                  15
# 24                        avanade                  14
# 25                           vass                  14
# 26                         loycus                  14
# 27                         taxfix                  14
# 28                          tidal                  14
# 29                            ibm                  13

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=temp.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Positions

# %%
top_positions = pd.DataFrame(df['position'].value_counts()).reset_index()
top_positions.columns = ['position', 'count']
top_positions
# Out:
#                                               position  count
# 0                                        ios developer     50
# 1                                    android developer     45
# 2                               programador full stack     27
# 3                              senior android engineer     22
# 4                                       java developer     18
# 5                                    software engineer     18
# 6                                  fullstack developer     16
# 7                                 full stack developer     16
# 8                             senior android developer     16
# 9                                 senior ios developer     14
# 10                                ios developer senior     14
# 11                                 full stack engineer     14
# 12                              java software engineer     13
# 13                                    android engineer     13
# 14                            senior software engineer     12
# 15   software engineer full stack bangkok based rel...     11
# 16                    senior software engineer android     11
# 17                         android developer mid level     10
# 18                                   desarrollador ios     10
# 19                    mobile platform engineer android     10
# 20                      android developer senior level     10
# 21                          desarrollador a full stack      9
# 22   senior software engineer android bangkok based...      9
# 23                                    programador java      9
# 24                       software development engineer      9
# 25   senior software engineer full stack bangkok ba...      9
# 26                        mobile platform engineer ios      9
# 27                                  back end developer      8
# 28                             android developer tidal      8
# 29                               ios software engineer      8
# 30              software engineer backend nodejs d f m      8
# 31                                mobile developer ios      8
# 32                                ios mobile developer      8
# 33               android developer different locations      8
# 34                                  programador a abap      7
# 35                               desarrollador a con c      7
# 36                          ios swift senior developer      7
# 37                         senior mobile app developer      7
# 38                               ingeniero de software      7
# 39                           android software engineer      7
# 40                                   backend developer      7
# 41                     ios engineer remote or relocate      7
# 42                            desarrollador de android      7
# 43                           software engineer fintech      7
# 44                                   ios app developer      7
# 45             software engineer back end core engines      6
# 46                              senior mobile engineer      6
# 47                     programador senior c 100 remoto      6
# 48                               programador fullstack      6
# 49              software engineer frontend react d f m      6
# 50   lead staff software engineer android bangkok b...      6
# 51                             pega analyst developers      6
# 52       senior android developer streaming team tidal      6
# 53                                programador abap h m      6
# 54                         c or java software engineer      6
# 55                 c engineer for database development      6
# 56                            android engineer fintech      6
# 57                                  software developer      6
# 58                              programador sharepoint      6
# 59                     senior android engineer fintech      6
# 60               senior full stack engineer javascript      6
# 61                        mobile developer ios android      5
# 62                               software engineer php      5
# 63                                mobile test engineer      5
# 64   blockchain ethereum fullstack software enginee...      5
# 65                         desarrollador ios swift v 4      5
# 66                  principal software engineer mobile      5
# 67                 software engineer planning tracking      5
# 68                           full stack angular y node      5
# 69                senior software developer innovación      5
# 70           remote senior android developer full time      5
# 71                      associate ios engineer fintech      5
# 72                                    mobile developer      5
# 73                                ios junior developer      5
# 74                               desarrollador a c h m      5
# 75                                        ios engineer      5
# 76                            mobile engineer frontend      5
# 77                            desarrollador full stack      5
# 78                                   clojure developer      5
# 79                      desarrollador a android kotlin      5
# 80   lead staff full stack software engineer bangko...      5
# 81                          hq senior android engineer      5
# 82   calypso technical analyst ingeniero a de software      5
# 83                        programador business central      5
# 84                             senior backend engineer      5
# 85   senior software engineer full stack engineer f...      5
# 86                     senior mobile developer flutter      5
# 87                                qa software engineer      5
# 88   full stack nodejs react software engineer madr...      5
# 89                             java software developer      5
# 90           programador senior nodejs 100 teletrabajo      5
# 91                       programador visión artificial      5
# 92                        software engineer blockchain      5
# 93                                ios engineer fintech      5
# 94   full remote mid senior react nodejs frontend b...      5
# 95                              full stack php angular      4
# 96             desarrollador full stack jr teletrabajo      4
# 97                    ios engineer b2c fintech lending      4
# 98                   manual qa engineer mobile fintech      4
# 99                        software developer front end      4
# 100                   senior full stack developer java      4
# 101                   full stack php y mysql developer      4
# 102     desarrollador a full stack react js net remoto      4
# 103                        software developer back end      4
# 104                       fullstack developer sr react      4
# 105               programador front angular desarrollo      4
# 106               senior software development engineer      4
# 107                        ios senior developer remote      4
# 108       mobile developer react native open to remote      4
# 109                             software developer sas      4
# 110                          fullstack engineer intern      4
# 111                         full stack engineer remote      4
# 112  fullstack developer php symfony vuejs 100 remo...      4
# 113                                 fullstack engineer      4
# 114            software engineer java senior developer      4
# 115                           android developer remoto      4
# 116         mobile developer ios android hybrid madrid      4
# 117                      mobile developer spain remote      4
# 118                   senior android software engineer      4
# 119                            desarrollador a android      4
# 120           programador full stack a tiempo completo      4
# 121                  ingeniero a de software fullstack      4
# 122                  programador google gas javascript      4
# 123                         senior fullstack developer      4
# 124                   desarrollador fullstack net core      4
# 125                      desarrollador java full stack      4
# 126  ingenieros front end full stack junior onsite ...      4
# 127               desarrollador fullstack java angular      4
# 128                         full stack engineer python      4
# 129                       ios test automation engineer      4
# 130              desarrollador a ios objective c swift      4
# 131  ingeniero a de software fullstack nodejs angul...      4
# 132                  desarrollador móvil ios y android      4
# 133  senior software engineer ios bangkok based rel...      4
# 134  desarrollador full stack full stack developer ...      4
# 135                    android senior developer remoto      4
# 136                    sw development engineer in test      4
# 137               ingeniero a de desarrollo software c      4
# 138                desarrollador fullstack react azure      4
# 139         senior full stack engineer ai spain remote      4
# 140                                     react engineer      4
# 141                      fullstack developer sr micros      4
# 142            desarrollador ios desarrollador android      4
# 143              desarrollador de aplicaciones móviles      4
# 144                   android mobile backend developer      4
# 145           full stack developer java open to remote      4
# 146                           desarrollador a software      4
# 147                 desarrolladores sénior android ios      4
# 148                       desarrollador senior android      4
# 149  full stack developer react python django open ...      4
# 150  engineering student and graduate program remot...      4
# 151                      fullstack developer c angular      4
# 152           full stack engineer net sector insurtech      4
# 153                               desarrolladores java      4
# 154                  analista desarrollador full stack      4
# 155                       desarrollador android senior      4
# 156      full stack developer mean mern open to remote      4
# 157                desarrollador senior android kotlin      4
# 158                   senior software engineer fintech      4
# 159                                   programador abap      4
# 160                        full stack senior developer      4
# 161                        programador front angular 8      4
# 162                         fullstack developer junior      4
# 163                         3d software engineer cloud      3
# 164                  desarrollador desarrolladora java      3
# 165                                 frontend developer      3
# 166                          programador apx aso cells      3
# 167                                    programador net      3
# 168                azure cloud microservices architect      3
# 169                   programador mobile ios o android      3
# 170                      desarollador a android kotlin      3
# 171                                      programador c      3
# 172                              desarrollador de java      3
# 173              analista programador a android senior      3
# 174                                programador android      3
# 175                  app dev solution sales specialist      3
# 176                           senior frontend engineer      3
# 177                               net senior developer      3
# 178                                      ios team lead      3
# 179                          desarrollador a sw appian      3
# 180                       ingeniero sw c video cdn 45k      3
# 181              analista programador frontend android      3
# 182                        programador a front angular      3
# 183                          software engineer backend      3
# 184                       senior backend engineer java      3
# 185                          backend software engineer      3
# 186                                  senior c engineer      3
# 187  desarrollador a de aplicaciones de movilidad t...      3
# 188                          desarrollador de software      3
# 189       outqar076 backend java engineer api managers      3
# 190                 ingeniero a de software javascript      3
# 191                                senior ios engineer      3
# 192  programadol 200mg full stack developer startup...      3
# 193                        es programador de ios swift      3
# 194          appln architect azure cloud modernization      3
# 195                   desarrolladores y analistas java      2
# 196                   cloud software developer java go      2
# 197                          crm application developer      2
# 198                          desarrollador powercenter      2
# 199                       programador senior abap hana      2
# 200                  desarrollador cloud madrid remoto      2
# 201                            desarrollador a angular      2
# 202  java staff engineer workspace one orchestrator...      2
# 203                                       xr developer      2
# 204                             analista desarrollador      2
# 205               desarrolladores front back fullstack      2
# 206              senior back end engineer core banking      2
# 207              desarrollad r de aplicaciones móviles      2
# 208               staff backend engineer f m d payroll      2
# 209                        ingeniero desarrollador rpa      2
# 210                               desarrollador nodejs      2
# 211                   sr software development engineer      2
# 212      application developer cornerstone id 210006nx      2
# 213                ingeniero a ip mpls productos nokia      2
# 214  desarrolladores y analistas programadores spri...      2
# 215                              desarrollador flutter      2
# 216          programador a y técnico a de soporte java      2
# 217                      desarrollador de aplicaciones      2
# 218                    desarrollador react teletrabajo      2
# 219                   programador java teletrabajo 100      2
# 220          becario de full stack developer en madrid      2
# 221                    programador java spring angular      2
# 222                               java spring engineer      2
# 223                                   python developer      2
# 224                           consultor programador bi      2
# 225                       desarrollador a para cluster      2
# 226                       ingeniero a de software java      2
# 227                       java microservicios engineer      2
# 228   ingeniero software embebido microblaze arm linux      2
# 229  messaging and collaboration specialist evening...      2
# 230                    lead full stack engineer 48 000      2
# 231                         programador java fullstack      2
# 232                   ingeniero a de software net java      2
# 233       desarrolladores as senior java spring oracle      2
# 234                                developer fullstack      2
# 235                          senior frontend developer      2
# 236                           java kotlin engineer emv      2
# 237   ingeniero de software integración continua ci cd      2
# 238       desarrolladores no code modeladores técnicos      2
# 239          desarrollador a de aplicaciones cloud aws      2
# 240                         es developer microservices      2
# 241                          desarrollador python nifi      2
# 242                               maquetador developer      2
# 243                     desarrollador a microservicios      2
# 244                 desarrollador perfil angular react      2
# 245                         java developer id 210005gq      2
# 246                             programador a java h m      2
# 247                   desarrollador experienced appian      2
# 248                        programador a java big data      2
# 249                  programador a java microservicios      2
# 250         técnico desarrollo de aplicaciones daw dam      2
# 251    technology application developer c powerbuilder      2
# 252                             desarrollador a appian      2
# 253                    desarrollador mobile ios senior      2
# 254         lingüista computacional desarrollador a ia      2
# 255                            programador a o ap java      2
# 256                   prácticas curriculares developer      2
# 257                             backend developer java      2
# 258                                      vue developer      2
# 259                                 programador a java      2
# 260                                 senior ux designer      2
# 261               programador a ap java microservicios      2
# 262                  ingeniero a software java angular      2
# 263               desarrollador a integración continua      2
# 264                         desarrollador a c wpf xaml      2
# 265                         programador fullstack java      2
# 266                            desarrolladores móviles      2
# 267                             programador salesforce      2
# 268                      desarrolladores as appian bpm      2
# 269               programador java angular teletrabajo      2
# 270  react native developer also available for full...      2
# 271                                    programador a c      2
# 272                                 programador junior      2
# 273                                es programador java      2
# 274                      developer dynamics 365 f o ax      2
# 275               google cloud microservices architect      2
# 276                           devops platform engineer      1
# 277                                   backend engineer      1
# 278         programador frontend y programador backend      1
# 279                   desarrollador a sw appian madrid      1
# 280                 ingeniero desarrollo movilidad ios      1
# 281                       software development manager      1
# 282                       desarrollador full stack net      1
# 283                       back end developer freelance      1
# 284                 java con big data developer remoto      1
# 285                web developer moodle open to remote      1
# 286                         programador backend senior      1
# 287                                programador c jr sr      1
# 288                              desarrollador pentaho      1
# 289         ingeniero a de desarrollo coach devops h m      1
# 290              senior sales engineer southern europe      1
# 291  desarrollador microservicios kafka 100 teletra...      1
# 292                      ingeniero a de desarrollo net      1
# 293                  aws cloud microservices architect      1
# 294                   backend software engineer revops      1
# 295            appln architect aws cloud modernization      1
# 296                        desarrollador de software c      1
# 297                            front end web developer      1
# 298                      cloud ignite graduate program      1
# 299                          devops lifecycle engineer      1
# 300             appn architect aws cloud modernization      1
# 301                           desarrollador a c python      1
# 302                            backend engineer 65 000      1
# 303  software developer in test automation qa engin...      1
# 304                                     sales engineer      1
# 305                          programador a plc y scada      1
# 306                        architect digital platforms      1
# 307    software development engineer ab marketing tech      1
# 308               google cloud advisory solutions lead      1
# 309              web developer drupal 8 open to remote      1
# 310                  product manager software engineer      1
# 311                                        qa engineer      1
# 312              react react native frontend tech lead      1
# 313  senior backend software engineer java kotlin f...      1
# 314                                    azure architect      1
# 315       programadores as sin experiencia ios android      1
# 316             web developer wordpress open to remote      1
# 317  lead staff software engineer ios bangkok based...      1
# 318  programador a e implementador a plataforma moo...      1
# 319  analista programador a frontend backend movilidad      1
# 320                   desarrollador a front end mobile      1
# 321            programador senior y programador junior      1
# 322                             back end web developer      1
# 323                       python spring boot developer      1
# 324  senior automation qa acronis cyber infrastructure      1
# 325                               commercial developer      1
# 326  outqar071 senior backend java developer devops...      1
# 327                      backend developer apache nifi      1
# 328                        mobile technical leader h m      1
# 329                                  solution engineer      1
# 330                         backend developer java8 11      1
# 331                                 manager salesforce      1
# 332                         back end node js developer      1
# 333                               web developer madrid      1
# 334                         engineering manager mobile      1
# 335       recién titulados accenture technology madrid      1
# 336                desarrollador a scripting telefonía      1
# 337                    senior frontend engineer madrid      1
# 338  ingeniero de desarrollo tramitación proyectos ...      1
# 339  programador java net cloud devops 100 teletrabajo      1
# 340                                desarrollador a aws      1
# 341  automated qa developer python golang platform ...      1
# 342  desarrollador a de aplicaciones web typescript...      1
# 343             ingeniero de software frontend backend      1
# 344                                 solutions engineer      1
# 345                     frontend web developer fintech      1
# 346                desarrollador movilidad android ios      1
# 347                     programador backend php senior      1
# 348                         programador senior soporte      1
# 349        ingeniero a senior desarrollo front angular      1
# 350                              desarrollador backend      1
# 351                      senior backend engineer f m d      1
# 352                       senior build engineer mobile      1

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="position", y="count", data=top_positions.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
df.columns
# Out:
# Index(['company_name', 'position', 'location', 'url', 'date_posted',
#        'Number of applicants', 'full-time/part-time', 'seniority level',
#        'employees', 'descriptions', 'industry', 'top competitive skills',
#        'Hiring Trend Company Wide', 'Hiring Trend Company Wide-Engineering',
#        'Median Tenure'],
#       dtype='object')

# %%
top_skills = []
for row_content in df['top competitive skills']:
    row_content = row_content.replace('/', ' ').replace('-', ' ')
    if len(row_content) > 3:
        try:
            for item in re.findall('\w+ \w+ \w+', row_content):  # Skills with 3 words
                top_skills.append(item)
            for item in re.findall('\w+ \w+', row_content):  # Skills with 2 words
                top_skills.append(item)
            for item in re.findall('\'\w+\'', row_content):  # Skill with single word
                top_skills.append(re.findall('\w+', item)[0])
        except TypeError:
            pass

top_skills = [item.lower() for item in top_skills]

# %%
def clean_skill(x):
    if ('cascading' in x) or ('css' in x):
        return 'css'
    elif 'ios' in x:
        return 'ios'
    elif 'android' in x:
        return 'android'
    elif 'sql' in x:
        return'sql'
    elif 'object oriented' in x:
        return 'object oriented programing'
    elif 'back end' in x:
        return 'back end'
    elif 'front end' in x:
        return 'front end'
    elif ('full stack' in x) or ('fullstack' in x):
        return 'full stack'
    elif 'user interface' in x:
        return 'user interface design'
    elif 'php' in x:
        return 'php'
    elif 'model view' in x:
        return 'model view'
    elif 'programming' in x:
        return 'programming language'
    elif 'azure' in x:
        return 'azure'
    elif 'web design' in x:
        return 'web design'
    elif ('software project' in x) or ('project management' in x):
        return 'project management'
    elif 'java database' in x:
        return 'java database'
    elif 'sap' in x:
        return 'sap'
    elif 'apis' in x:
        return 'apis'
    else:
        return x

# %%
top_skills = pd.Series(top_skills).apply(clean_skill)

# %% [markdown]
# # Top Skills of the candidates who applied for the job

# %%
x = pd.DataFrame(pd.DataFrame(top_skills).value_counts())
x.columns = ['count']
x = x.reset_index()
x.columns = ['skill', 'count']
x = x[x['count']> 7]
x
# Out:
#                               skill  count
# 0                               sql    723
# 1                               css    474
# 2                           android    404
# 3                        javascript    331
# 4              programming language    308
# 5                              java    248
# 6                               php    196
# 7                              html    145
# 8                           english    142
# 9                   web development    126
# 10                              git    117
# 11                              ios    116
# 12                            html5    104
# 13                           kotlin     96
# 14                          mongodb     91
# 15                         teamwork     73
# 16                       model view     72
# 17             software development     70
# 18                  microsoft excel     65
# 19                           matlab     64
# 20                 microsoft office     55
# 21       object oriented programing     54
# 22               project management     52
# 23                        databases     51
# 24                          eclipse     49
# 25                   microsoft word     48
# 26                          spanish     47
# 27                  oracle database     46
# 28                         back end     46
# 29                              sap     45
# 30                             jira     45
# 31          application development     44
# 32                            scrum     43
# 33            user interface design     42
# 34                           github     42
# 35                            xcode     41
# 36                       full stack     40
# 37                        hibernate     38
# 38                       leadership     36
# 39                        bootstrap     35
# 40                            linux     34
# 41                            unity     33
# 42                            maven     32
# 43                        angularjs     31
# 44                           jquery     30
# 45                         firebase     30
# 46                      engineering     29
# 47                             sass     29
# 48             microsoft powerpoint     28
# 49                        front end     28
# 50              agile methodologies     27
# 51                             json     27
# 52                 machine learning     26
# 53                 spring framework     26
# 54                  data structures     25
# 55                    data analysis     25
# 56               mobile application     24
# 57                  team leadership     24
# 58                analytical skills     23
# 59                          arduino     23
# 60                              xml     23
# 61   mobile application development     22
# 62                      spring boot     22
# 63                          jenkins     21
# 64                             ajax     20
# 65                       web design     20
# 66                    communication     18
# 67                         training     18
# 68                  adobe photoshop     17
# 69                          windows     17
# 70                adobe illustrator     17
# 71                    java database     16
# 72                     web services     16
# 73                            latex     16
# 74                       jakarta ee     16
# 75                  docker products     16
# 76                 computer science     16
# 77                             vhdl     15
# 78                  software design     15
# 79                 customer service     15
# 80                         retrofit     15
# 81                       management     15
# 82                          angular     15
# 83              mobile applications     14
# 84                      advertising     14
# 85                      objective c     14
# 86                    net framework     14
# 87                            azure     14
# 88                          graphql     13
# 89                    visual studio     13
# 90                         selenium     13
# 91                       ecmascript     13
# 92                         research     12
# 93                        marketing     12
# 94                     tortoise svn     12
# 95                      electricity     12
# 96                           design     12
# 97                          flutter     11
# 98                    microservices     11
# 99                       typescript     11
# 100                       wordpress     11
# 101                      e commerce     11
# 102                 troubleshooting     11
# 103                      networking     11
# 104                   documentation     11
# 105                      spring mvc     11
# 106                     electronics     11
# 107                    unit testing     11
# 108                            apis     11
# 109                       core data     11
# 110                   cybersecurity     11
# 111                        netbeans     10
# 112                      life cycle     10
# 113                 test automation     10
# 114             restful webservices     10
# 115             jakarta persistence     10
# 116                      confluence      9
# 117                     test driven      9
# 118                    data science      9
# 119                          django      9
# 120                   intellij idea      9
# 121              reporting services      9
# 122                      google ads      9
# 123                        big data      9
# 124                web applications      9
# 125         test driven development      9
# 126                       bmc helix      9
# 127                    mongoose odm      9
# 128                  bmc helix itsm      9
# 129             business management      9
# 130                          javase      9
# 131       software development life      8
# 132                           rs232      8
# 133            interpersonal skills      8
# 134                          devops      8
# 135               operating systems      8
# 136                         autocad      8

# %%
'swift' in x['skill']
# Out:
# False

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=x.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
skills = x['skill']
skills = list(skills.values)

# %%
skills.append('swift')

# %%
other_skills = ['xamarin', 'appcelerator', 'cordova', 'phonegap', 'buildfire', 'ionic', 'android sdk', 
               'android studio', 'angular', 'objective-c', 'dart', 'lua', 'rust' ,'action script' ,
               'mobile design']

# %%
skills = skills + other_skills

# %% [markdown]
# # Top Skills Asked by the employers

# %%
import re

# %%
skills_count = {}
for skill in skills:
    counter = 0
    for description in df['descriptions']:
        if (skill == 'ci') and len(re.findall('ci ', description))>0:
            counter+=1
        elif skill in description:
            counter += 1
    skills_count[skill] = counter

# %%
skills_count = pd.DataFrame(dict(sorted(skills_count.items(), key=lambda x: x[1], reverse=True)).items())
skills_count.columns = ['skill', 'count']

# %%
skills_count
# Out:
#                               skill  count
# 0                               ios   1153
# 1                              java    929
# 2                               git    872
# 3                            design    570
# 4                           android    492
# 5                       engineering    417
# 6                        javascript    401
# 7                             unity    400
# 8                            kotlin    393
# 9                           english    383
# 10                             apis    342
# 11                              sql    330
# 12                          angular    310
# 13                            swift    291
# 14                    communication    254
# 15                            scrum    243
# 16                              css    232
# 17                             html    231
# 18                       management    226
# 19                       full stack    214
# 20                          jenkins    190
# 21                           github    168
# 22                        front end    165
# 23                       typescript    163
# 24                             jira    156
# 25                       life cycle    151
# 26                 computer science    150
# 27                            azure    145
# 28             software development    136
# 29                      objective c    135
# 30             programming language    133
# 31                       leadership    124
# 32                              php    121
# 33                           devops    121
# 34                         training    120
# 35                      spring boot    116
# 36                        marketing    108
# 37                         big data    107
# 38                         back end    102
# 39                            maven    102
# 40              agile methodologies    102
# 41                          graphql     95
# 42                          spanish     91
# 43                             json     89
# 44                     unit testing     88
# 45                            html5     86
# 46                            linux     86
# 47          application development     80
# 48                     web services     79
# 49                         retrofit     79
# 50                              sap     73
# 51                         research     73
# 52                 web applications     72
# 53                 machine learning     71
# 54               mobile application     69
# 55                             rust     69
# 56                        databases     67
# 57                      android sdk     65
# 58                              lua     65
# 59                         firebase     62
# 60                            xcode     59
# 61                          mongodb     58
# 62                         teamwork     52
# 63                  data structures     50
# 64                        hibernate     49
# 65              mobile applications     49
# 66                    microservices     49
# 67                           jquery     46
# 68                        bootstrap     45
# 69                  software design     45
# 70                       confluence     45
# 71                             sass     42
# 72                              xml     41
# 73                 spring framework     40
# 74                 customer service     40
# 75                            ionic     40
# 76        software development life     37
# 77                        angularjs     36
# 78                    documentation     34
# 79                           django     32
# 80                             dart     31
# 81                   android studio     30
# 82                analytical skills     25
# 83                     data science     25
# 84                       e commerce     24
# 85                          cordova     24
# 86                          windows     23
# 87                         selenium     23
# 88                          flutter     23
# 89                  web development     20
# 90                          eclipse     18
# 91   mobile application development     18
# 92                    visual studio     18
# 93                        core data     18
# 94                operating systems     18
# 95               project management     17
# 96                  troubleshooting     15
# 97                  test automation     14
# 98                             ajax     12
# 99                      test driven     12
# 100                       wordpress     11
# 101                   data analysis     10
# 102                      spring mvc     10
# 103         test driven development      8
# 104                      web design      7
# 105                   net framework      6
# 106                      networking      6
# 107                   cybersecurity      5
# 108            interpersonal skills      5
# 109                          matlab      4
# 110                         xamarin      4
# 111                        phonegap      4
# 112                   java database      3
# 113                      ecmascript      2
# 114                     electronics      2
# 115                         autocad      1
# 116                    appcelerator      1
# 117                      model view      0
# 118                 microsoft excel      0
# 119                microsoft office      0
# 120      object oriented programing      0
# 121                  microsoft word      0
# 122                 oracle database      0
# 123           user interface design      0
# 124            microsoft powerpoint      0
# 125                 team leadership      0
# 126                         arduino      0
# 127                 adobe photoshop      0
# 128               adobe illustrator      0
# 129                           latex      0
# 130                      jakarta ee      0
# 131                 docker products      0
# 132                            vhdl      0
# 133                     advertising      0
# 134                    tortoise svn      0
# 135                     electricity      0
# 136                        netbeans      0
# 137             restful webservices      0
# 138             jakarta persistence      0
# 139                   intellij idea      0
# 140              reporting services      0
# 141                      google ads      0
# 142                       bmc helix      0
# 143                    mongoose odm      0
# 144                  bmc helix itsm      0
# 145             business management      0
# 146                          javase      0
# 147                           rs232      0
# 148                       buildfire      0
# 149                     objective-c      0
# 150                   action script      0
# 151                   mobile design      0

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
## Next analysis : Top skills for iOS jobs and for Android Jobs

# %%
df['position'].value_counts()
# Out:
# ios developer                                                                      50
# android developer                                                                  45
# programador full stack                                                             27
# senior android engineer                                                            22
# java developer                                                                     18
# software engineer                                                                  18
# fullstack developer                                                                16
# full stack developer                                                               16
# senior android developer                                                           16
# senior ios developer                                                               14
# ios developer senior                                                               14
# full stack engineer                                                                14
# java software engineer                                                             13
# android engineer                                                                   13
# senior software engineer                                                           12
# software engineer full stack bangkok based relocation provided                     11
# senior software engineer android                                                   11
# android developer mid level                                                        10
# desarrollador ios                                                                  10
# mobile platform engineer android                                                   10
# android developer senior level                                                     10
# desarrollador a full stack                                                          9
# senior software engineer android bangkok based relocation provided                  9
# programador java                                                                    9
# software development engineer                                                       9
# senior software engineer full stack bangkok based relocation provided               9
# mobile platform engineer ios                                                        9
# back end developer                                                                  8
# android developer tidal                                                             8
# ios software engineer                                                               8
# software engineer backend nodejs d f m                                              8
# mobile developer ios                                                                8
# ios mobile developer                                                                8
# android developer different locations                                               8
# programador a abap                                                                  7
# desarrollador a con c                                                               7
# ios swift senior developer                                                          7
# senior mobile app developer                                                         7
# ingeniero de software                                                               7
# android software engineer                                                           7
# backend developer                                                                   7
# ios engineer remote or relocate                                                     7
# desarrollador de android                                                            7
# software engineer fintech                                                           7
# ios app developer                                                                   7
# software engineer back end core engines                                             6
# senior mobile engineer                                                              6
# programador senior c 100 remoto                                                     6
# programador fullstack                                                               6
# software engineer frontend react d f m                                              6
# lead staff software engineer android bangkok based relocation provided              6
# pega analyst developers                                                             6
# senior android developer streaming team tidal                                       6
# programador abap h m                                                                6
# c or java software engineer                                                         6
# c engineer for database development                                                 6
# android engineer fintech                                                            6
# software developer                                                                  6
# programador sharepoint                                                              6
# senior android engineer fintech                                                     6
# senior full stack engineer javascript                                               6
# mobile developer ios android                                                        5
# software engineer php                                                               5
# mobile test engineer                                                                5
# blockchain ethereum fullstack software engineer java groovy react                   5
# desarrollador ios swift v 4                                                         5
# principal software engineer mobile                                                  5
# software engineer planning tracking                                                 5
# full stack angular y node                                                           5
# senior software developer innovación                                                5
# remote senior android developer full time                                           5
# associate ios engineer fintech                                                      5
# mobile developer                                                                    5
# ios junior developer                                                                5
# desarrollador a c h m                                                               5
# ios engineer                                                                        5
# mobile engineer frontend                                                            5
# desarrollador full stack                                                            5
# clojure developer                                                                   5
# desarrollador a android kotlin                                                      5
# lead staff full stack software engineer bangkok based relocation provided           5
# hq senior android engineer                                                          5
# calypso technical analyst ingeniero a de software                                   5
# programador business central                                                        5
# senior backend engineer                                                             5
# senior software engineer full stack engineer front end back end madrid              5
# senior mobile developer flutter                                                     5
# qa software engineer                                                                5
# full stack nodejs react software engineer madrid remote                             5
# java software developer                                                             5
# programador senior nodejs 100 teletrabajo                                           5
# programador visión artificial                                                       5
# software engineer blockchain                                                        5
# ios engineer fintech                                                                5
# full remote mid senior react nodejs frontend backend fullstack engineers            5
# full stack php angular                                                              4
# desarrollador full stack jr teletrabajo                                             4
# ios engineer b2c fintech lending                                                    4
# manual qa engineer mobile fintech                                                   4
# software developer front end                                                        4
# senior full stack developer java                                                    4
# full stack php y mysql developer                                                    4
# desarrollador a full stack react js net remoto                                      4
# software developer back end                                                         4
# fullstack developer sr react                                                        4
# programador front angular desarrollo                                                4
# senior software development engineer                                                4
# ios senior developer remote                                                         4
# mobile developer react native open to remote                                        4
# software developer sas                                                              4
# fullstack engineer intern                                                           4
# full stack engineer remote                                                          4
# fullstack developer php symfony vuejs 100 remoto h m                                4
# fullstack engineer                                                                  4
# software engineer java senior developer                                             4
# android developer remoto                                                            4
# mobile developer ios android hybrid madrid                                          4
# mobile developer spain remote                                                       4
# senior android software engineer                                                    4
# desarrollador a android                                                             4
# programador full stack a tiempo completo                                            4
# ingeniero a de software fullstack                                                   4
# programador google gas javascript                                                   4
# senior fullstack developer                                                          4
# desarrollador fullstack net core                                                    4
# desarrollador java full stack                                                       4
# ingenieros front end full stack junior onsite madrid                                4
# desarrollador fullstack java angular                                                4
# full stack engineer python                                                          4
# ios test automation engineer                                                        4
# desarrollador a ios objective c swift                                               4
# ingeniero a de software fullstack nodejs angular graphql                            4
# desarrollador móvil ios y android                                                   4
# senior software engineer ios bangkok based relocation provided                      4
# desarrollador full stack full stack developer full stack software engineer          4
# android senior developer remoto                                                     4
# sw development engineer in test                                                     4
# ingeniero a de desarrollo software c                                                4
# desarrollador fullstack react azure                                                 4
# senior full stack engineer ai spain remote                                          4
# react engineer                                                                      4
# fullstack developer sr micros                                                       4
# desarrollador ios desarrollador android                                             4
# desarrollador de aplicaciones móviles                                               4
# android mobile backend developer                                                    4
# full stack developer java open to remote                                            4
# desarrollador a software                                                            4
# desarrolladores sénior android ios                                                  4
# desarrollador senior android                                                        4
# full stack developer react python django open to remote                             4
# engineering student and graduate program remote or relocate                         4
# fullstack developer c angular                                                       4
# full stack engineer net sector insurtech                                            4
# desarrolladores java                                                                4
# analista desarrollador full stack                                                   4
# desarrollador android senior                                                        4
# full stack developer mean mern open to remote                                       4
# desarrollador senior android kotlin                                                 4
# senior software engineer fintech                                                    4
# programador abap                                                                    4
# full stack senior developer                                                         4
# programador front angular 8                                                         4
# fullstack developer junior                                                          4
# 3d software engineer cloud                                                          3
# desarrollador desarrolladora java                                                   3
# frontend developer                                                                  3
# programador apx aso cells                                                           3
# programador net                                                                     3
# azure cloud microservices architect                                                 3
# programador mobile ios o android                                                    3
# desarollador a android kotlin                                                       3
# programador c                                                                       3
# desarrollador de java                                                               3
# analista programador a android senior                                               3
# programador android                                                                 3
# app dev solution sales specialist                                                   3
# senior frontend engineer                                                            3
# net senior developer                                                                3
# ios team lead                                                                       3
# desarrollador a sw appian                                                           3
# ingeniero sw c video cdn 45k                                                        3
# analista programador frontend android                                               3
# programador a front angular                                                         3
# software engineer backend                                                           3
# senior backend engineer java                                                        3
# backend software engineer                                                           3
# senior c engineer                                                                   3
# desarrollador a de aplicaciones de movilidad teletrabajo                            3
# desarrollador de software                                                           3
# outqar076 backend java engineer api managers                                        3
# ingeniero a de software javascript                                                  3
# senior ios engineer                                                                 3
# programadol 200mg full stack developer startup saas                                 3
# es programador de ios swift                                                         3
# appln architect azure cloud modernization                                           3
# desarrolladores y analistas java                                                    2
# cloud software developer java go                                                    2
# crm application developer                                                           2
# desarrollador powercenter                                                           2
# programador senior abap hana                                                        2
# desarrollador cloud madrid remoto                                                   2
# desarrollador a angular                                                             2
# java staff engineer workspace one orchestrator opportunity for working remotely     2
# xr developer                                                                        2
# analista desarrollador                                                              2
# desarrolladores front back fullstack                                                2
# senior back end engineer core banking                                               2
# desarrollad r de aplicaciones móviles                                               2
# staff backend engineer f m d payroll                                                2
# ingeniero desarrollador rpa                                                         2
# desarrollador nodejs                                                                2
# sr software development engineer                                                    2
# application developer cornerstone id 210006nx                                       2
# ingeniero a ip mpls productos nokia                                                 2
# desarrolladores y analistas programadores spring boot microservicios                2
# desarrollador flutter                                                               2
# programador a y técnico a de soporte java                                           2
# desarrollador de aplicaciones                                                       2
# desarrollador react teletrabajo                                                     2
# programador java teletrabajo 100                                                    2
# becario de full stack developer en madrid                                           2
# programador java spring angular                                                     2
# java spring engineer                                                                2
# python developer                                                                    2
# consultor programador bi                                                            2
# desarrollador a para cluster                                                        2
# ingeniero a de software java                                                        2
# java microservicios engineer                                                        2
# ingeniero software embebido microblaze arm linux                                    2
# messaging and collaboration specialist evening shift                                2
# lead full stack engineer 48 000                                                     2
# programador java fullstack                                                          2
# ingeniero a de software net java                                                    2
# desarrolladores as senior java spring oracle                                        2
# developer fullstack                                                                 2
# senior frontend developer                                                           2
# java kotlin engineer emv                                                            2
# ingeniero de software integración continua ci cd                                    2
# desarrolladores no code modeladores técnicos                                        2
# desarrollador a de aplicaciones cloud aws                                           2
# es developer microservices                                                          2
# desarrollador python nifi                                                           2
# maquetador developer                                                                2
# desarrollador a microservicios                                                      2
# desarrollador perfil angular react                                                  2
# java developer id 210005gq                                                          2
# programador a java h m                                                              2
# desarrollador experienced appian                                                    2
# programador a java big data                                                         2
# programador a java microservicios                                                   2
# técnico desarrollo de aplicaciones daw dam                                          2
# technology application developer c powerbuilder                                     2
# desarrollador a appian                                                              2
# desarrollador mobile ios senior                                                     2
# lingüista computacional desarrollador a ia                                          2
# programador a o ap java                                                             2
# prácticas curriculares developer                                                    2
# backend developer java                                                              2
# vue developer                                                                       2
# programador a java                                                                  2
# senior ux designer                                                                  2
# programador a ap java microservicios                                                2
# ingeniero a software java angular                                                   2
# desarrollador a integración continua                                                2
# desarrollador a c wpf xaml                                                          2
# programador fullstack java                                                          2
# desarrolladores móviles                                                             2
# programador salesforce                                                              2
# desarrolladores as appian bpm                                                       2
# programador java angular teletrabajo                                                2
# react native developer also available for full remote working                       2
# programador a c                                                                     2
# programador junior                                                                  2
# es programador java                                                                 2
# developer dynamics 365 f o ax                                                       2
# google cloud microservices architect                                                2
# devops platform engineer                                                            1
# backend engineer                                                                    1
# programador frontend y programador backend                                          1
# desarrollador a sw appian madrid                                                    1
# ingeniero desarrollo movilidad ios                                                  1
# software development manager                                                        1
# desarrollador full stack net                                                        1
# back end developer freelance                                                        1
# java con big data developer remoto                                                  1
# web developer moodle open to remote                                                 1
# programador backend senior                                                          1
# programador c jr sr                                                                 1
# desarrollador pentaho                                                               1
# ingeniero a de desarrollo coach devops h m                                          1
# senior sales engineer southern europe                                               1
# desarrollador microservicios kafka 100 teletrabajo                                  1
# ingeniero a de desarrollo net                                                       1
# aws cloud microservices architect                                                   1
# backend software engineer revops                                                    1
# appln architect aws cloud modernization                                             1
# desarrollador de software c                                                         1
# front end web developer                                                             1
# cloud ignite graduate program                                                       1
# devops lifecycle engineer                                                           1
# appn architect aws cloud modernization                                              1
# desarrollador a c python                                                            1
# backend engineer 65 000                                                             1
# software developer in test automation qa engineer acronis cyber infrastructure      1
# sales engineer                                                                      1
# programador a plc y scada                                                           1
# architect digital platforms                                                         1
# software development engineer ab marketing tech                                     1
# google cloud advisory solutions lead                                                1
# web developer drupal 8 open to remote                                               1
# product manager software engineer                                                   1
# qa engineer                                                                         1
# react react native frontend tech lead                                               1
# senior backend software engineer java kotlin f m d                                  1
# azure architect                                                                     1
# programadores as sin experiencia ios android                                        1
# web developer wordpress open to remote                                              1
# lead staff software engineer ios bangkok based relocation provided                  1
# programador a e implementador a plataforma moodle iomad                             1
# analista programador a frontend backend movilidad                                   1
# desarrollador a front end mobile                                                    1
# programador senior y programador junior                                             1
# back end web developer                                                              1
# python spring boot developer                                                        1
# senior automation qa acronis cyber infrastructure                                   1
# commercial developer                                                                1
# outqar071 senior backend java developer devops engineer                             1
# backend developer apache nifi                                                       1
# mobile technical leader h m                                                         1
# solution engineer                                                                   1
# backend developer java8 11                                                          1
# manager salesforce                                                                  1
# back end node js developer                                                          1
# web developer madrid                                                                1
# engineering manager mobile                                                          1
# recién titulados accenture technology madrid                                        1
# desarrollador a scripting telefonía                                                 1
# senior frontend engineer madrid                                                     1
# ingeniero de desarrollo tramitación proyectos fotovoltaicos                         1
# programador java net cloud devops 100 teletrabajo                                   1
# desarrollador a aws                                                                 1
# automated qa developer python golang platform team                                  1
# desarrollador a de aplicaciones web typescript reactjs                              1
# ingeniero de software frontend backend                                              1
# solutions engineer                                                                  1
# frontend web developer fintech                                                      1
# desarrollador movilidad android ios                                                 1
# programador backend php senior                                                      1
# programador senior soporte                                                          1
# ingeniero a senior desarrollo front angular                                         1
# desarrollador backend                                                               1
# senior backend engineer f m d                                                       1
# senior build engineer mobile                                                        1
# Name: position, dtype: int64

# %%
def iOS_android_positions(x):
    if 'ios' in x:
        return 'ios'
    elif 'android' in x:
        return 'android'
    else:
        return 'other'

# %%
df['platform'] = df['position'].apply(iOS_android_positions)

# %% [markdown]
# # iOS Analysis

# %%
ios_df = df[df['platform']=='ios']
ios_df.shape
# Out:
# (237, 16)

# %%
skills_count_ios = {}
counter = 0
for skill in skills:
    counter = 0
    for description in ios_df['descriptions']:
        if (skill == 'ci'):
            if len(re.findall('ci ', description))>0:
                counter+=1
        elif skill in description:
            counter += 1
    skills_count_ios[skill] = counter
skills_count_ios = pd.DataFrame(dict(sorted(skills_count_ios.items(), key=lambda x: x[1], reverse=True)).items())
skills_count_ios.columns = ['skill', 'count']
skills_count_ios = skills_count_ios[skills_count_ios['count']>0]
skills_count_ios
# Out:
#                              skill  count
# 0                              ios    237
# 1                            swift    179
# 2                              git    170
# 3                             java    102
# 4                      engineering    102
# 5                          english     99
# 6                      objective c     92
# 7                           design     78
# 8                          android     74
# 9                           kotlin     67
# 10                            apis     61
# 11                           unity     56
# 12                   communication     55
# 13                      life cycle     52
# 14                           scrum     44
# 15                           xcode     44
# 16                         jenkins     39
# 17                            jira     33
# 18            programming language     30
# 19                      leadership     28
# 20                          github     26
# 21            software development     24
# 22                        firebase     23
# 23             agile methodologies     23
# 24                      javascript     22
# 25                    unit testing     22
# 26                       marketing     21
# 27                computer science     20
# 28                      full stack     19
# 29                         spanish     18
# 30                           maven     16
# 31                        training     15
# 32                      management     15
# 33                             php     14
# 34                       front end     14
# 35                machine learning     14
# 36                 software design     14
# 37                        big data     14
# 38                         graphql     13
# 39              mobile application     12
# 40                 test automation     12
# 41                          devops     12
# 42             mobile applications     11
# 43                       core data     11
# 44                        back end     10
# 45                         angular     10
# 46                             sap      9
# 47               analytical skills      9
# 48                customer service      9
# 49       software development life      9
# 50                        teamwork      8
# 51                      confluence      8
# 52                     android sdk      8
# 53                            dart      8
# 54                 web development      7
# 55                         eclipse      7
# 56                            json      7
# 57                     spring boot      7
# 58                         flutter      7
# 59                           ionic      7
# 60                            rust      7
# 61                             sql      5
# 62                   microservices      5
# 63                             css      4
# 64                            html      4
# 65                         mongodb      4
# 66                       hibernate      4
# 67                   visual studio      4
# 68                        selenium      4
# 69                      spring mvc      4
# 70                         cordova      4
# 71                        phonegap      4
# 72                             lua      3
# 73                          jquery      2
# 74                spring framework      2
# 75                    web services      2
# 76                       databases      1
# 77         application development      1
# 78  mobile application development      1

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_ios.iloc[20:40])
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top companies iOS

# %%
top_companies_ios = pd.DataFrame(ios_df['company_name'].value_counts()).reset_index()
top_companies_ios.columns =['company_name', 'number of postings']
top_companies_ios
# Out:
#                             company_name  number of postings
# 0                                 loycus                  14
# 1                                  tymit                  14
# 2                              cognizant                   9
# 3                                zendesk                   9
# 4                              nexplayer                   8
# 5                  capgemini engineering                   8
# 6                                 veepee                   8
# 7                                globant                   8
# 8   ryanair - europe's favourite airline                   7
# 9                                  fever                   7
# 10                            talentosap                   7
# 11                            acid tango                   7
# 12                              teamwire                   7
# 13                        bending spoons                   7
# 14        small world financial services                   7
# 15            idential global consulting                   7
# 16                      innocv solutions                   7
# 17                        page personnel                   6
# 18                         grupo digital                   5
# 19                               entelgy                   5
# 20                   walma dynamic group                   5
# 21                  iteration mobile s.l                   5
# 22                              openbank                   5
# 23                                 agoda                   5
# 24                                everis                   4
# 25                              arelance                   4
# 26                         talentomobile                   4
# 27                                  vass                   4
# 28   networkers - technology recruitment                   4
# 29                                 indra                   4
# 30                     kindred group plc                   4
# 31     pss tecnologias de la informacion                   4
# 32                            set europa                   4
# 33                               aircall                   3
# 34                       cmv consultores                   3
# 35                                inetum                   3
# 36                             sololearn                   3
# 37                              devoteam                   3
# 38                     paradigma digital                   2
# 39                               hiberus                   2
# 40                    between technology                   2
# 41                              randstad                   1
# 42                            ust españa                   1
# 43                        experis españa                   1

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=top_companies_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Android Analysis

# %%
android_df = df[df['platform']=='android']
android_df.shape
# Out:
# (259, 16)

# %%
skills_count_android = {}
counter = 0
for skill in skills:
    counter = 0
    for description in android_df['descriptions']:
        if (skill == 'ci'):
            if len(re.findall('ci ', description))>0:
                counter+=1
        elif skill in description:
            counter += 1
    skills_count_android[skill] = counter
skills_count_android = pd.DataFrame(dict(sorted(skills_count_android.items(), key=lambda x: x[1], reverse=True)).items())
skills_count_android.columns = ['skill', 'count']
skills_count_android = skills_count_android[skills_count_android['count']>0]
skills_count_android
# Out:
#                              skill  count
# 0                          android    259
# 1                           kotlin    226
# 2                              git    197
# 3                             java    194
# 4                           design    167
# 5                            unity    145
# 6                             apis    100
# 7                          english     91
# 8                              ios     89
# 9                      engineering     74
# 10                        retrofit     69
# 11                      management     65
# 12                   communication     64
# 13                     android sdk     57
# 14                      javascript     52
# 15                          github     51
# 16                    unit testing     48
# 17                           swift     46
# 18                      life cycle     39
# 19            programming language     36
# 20                           scrum     35
# 21                            jira     34
# 22                      full stack     34
# 23                        training     33
# 24                         graphql     31
# 25                             lua     29
# 26            software development     28
# 27         application development     28
# 28                      leadership     28
# 29                             sap     27
# 30                         spanish     26
# 31                        firebase     26
# 32                            json     25
# 33                     objective c     25
# 34                  android studio     25
# 35                       front end     24
# 36             agile methodologies     24
# 37              mobile application     24
# 38                         jenkins     24
# 39                    web services     24
# 40                       marketing     24
# 41                        back end     22
# 42                        big data     22
# 43                        teamwork     21
# 44                 software design     21
# 45                customer service     21
# 46                 data structures     20
# 47                computer science     19
# 48                             css     17
# 49                            html     17
# 50                        research     17
# 51  mobile application development     16
# 52                             sql     15
# 53                         angular     12
# 54                           azure     11
# 55       software development life     11
# 56                           xcode     10
# 57                          devops      9
# 58             mobile applications      8
# 59                      typescript      8
# 60               analytical skills      7
# 61                       databases      6
# 62                machine learning      6
# 63                   data analysis      6
# 64              project management      5
# 65                spring framework      5
# 66                         flutter      5
# 67                 troubleshooting      5
# 68                    data science      5
# 69                           ionic      5
# 70                         eclipse      4
# 71                      confluence      4
# 72            interpersonal skills      4
# 73                            dart      4
# 74                           html5      3
# 75                       bootstrap      3

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_android.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top companies Android

# %%
top_companies_android = pd.DataFrame(android_df['company_name'].value_counts()).reset_index()
top_companies_android.columns =['company_name', 'number of postings']
top_companies_android
# Out:
#                                      company_name  number of postings
# 0                                         zendesk                  21
# 1                                       pulselive                  20
# 2                                         acronis                  16
# 3                                           agoda                  15
# 4                                           tidal                  14
# 5                                           tymit                  12
# 6                                          veepee                   9
# 7                                accenture españa                   8
# 8                                     stratusgrid                   8
# 9                                           busuu                   8
# 10                                          fever                   8
# 11                                     trucksters                   7
# 12                                      nexplayer                   7
# 13                                       livanova                   6
# 14                                        tadatic                   6
# 15                                     acid tango                   6
# 16                                   jobandtalent                   5
# 17                         tribalyte technologies                   5
# 18                                         toptal                   5
# 19                                   michael page                   5
# 20                                         cabify                   5
# 21                           iteration mobile s.l                   5
# 22                                           beat                   5
# 23                  serem consultoría empresarial                   4
# 24                                     telefónica                   4
# 25                                 robert walters                   4
# 26  o2o - mo2o /digital business & transformation                   4
# 27             con&sel15, consultoría y selección                   4
# 28                            etalentum selección                   4
# 29                                      sololearn                   4
# 30                          digital talent agency                   4
# 31                               innocv solutions                   4
# 32                             between technology                   4
# 33              pss tecnologias de la informacion                   3
# 34                                           vass                   3
# 35                                       devoteam                   3
# 36                                    alten spain                   3
# 37                              paradigma digital                   1

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=top_companies_android.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()
