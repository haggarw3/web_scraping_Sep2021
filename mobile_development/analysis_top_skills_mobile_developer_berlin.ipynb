# %%
import pandas as pd
import os
import re
import numpy as np
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('AGGREGATED_DATA_mobile_developer_berlin.csv')

# %%
df.shape
# Out:
# (3737, 16)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                  0
# company_name                                0
# position                                    0
# location                                    0
# url                                         0
# date_posted                                 0
# Number of applicants                      430
# full-time/part-time                      2690
# seniority level                          3028
# employees                                  98
# descriptions                                0
# industry                                  262
# top competitive skills                      0
# Hiring Trend Company Wide                3173
# Hiring Trend Company Wide-Engineering    3180
# Median Tenure                            3173
# dtype: int64

# %%
df['seniority level'].value_counts()
# Out:
# associate    709
# Name: seniority level, dtype: int64

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['company_name', 'position', 'location', 'url', 'date_posted',
#        'Number of applicants', 'full-time/part-time', 'seniority level',
#        'employees', 'descriptions', 'industry', 'top competitive skills',
#        'Hiring Trend Company Wide', 'Hiring Trend Company Wide-Engineering',
#        'Median Tenure'],
#       dtype='object')

# %%
pd.DataFrame(df['position'].value_counts()).reset_index()
# Out:
#                                                   index  position
# 0                         software development engineer       116
# 1                                     android developer        44
# 2                              senior android developer        35
# 3                                     software engineer        31
# 4                               senior android engineer        31
# 5                                  senior ios developer        27
# 6                                   senior ios engineer        26
# 7                     lead mobile developer ios android        21
# 8                                    ios engineer f m d        21
# 9                                      android engineer        20
# 10                            software engineer backend        20
# 11        software development engineer amazon redshift        19
# 12                           senior ios developer m f d        18
# 13                           ios developer f m d 80 100        17
# 14                             senior software engineer        17
# 15                       senior android developer m f d        16
# 16                                  full stack engineer        16
# 17                 senior software development engineer        16
# 18        software development engineer berlin tech hub        15
# 19                           senior full stack engineer        14
# 20                 software development engineer mobile        14
# 21                    android software engineer in test        14
# 22    android software development engineer amazon eero        13
# 23                 mobile software development engineer        13
# 24                         android engineer kotlin java        12
# 25           software development engineer alexa search        12
# 26       software development engineer redshift storage        12
# 27                                        ios developer        12
# 28                        senior android engineer m f d        12
# 29    software development engineer amazon redshift ...        11
# 30                               android engineer d f m        11
# 31                             fullstack engineer d f m        11
# 32       sr software development engineer amazon berlin        11
# 33    senior full stack software developer f m d pro...        10
# 34                  android developer m w d remote rm21        10
# 35                software development engineer fire tv        10
# 36                        android engineer style advice        10
# 37                           software engineer frontend        10
# 38                        mobile engineer flutter m f d         9
# 39                         senior lead android engineer         9
# 40                  android engineer remote or relocate         9
# 41    software development engineer amazon redshift ...         9
# 42                           associate android engineer         9
# 43                           software engineer ii m w d         9
# 44                               mobile developer m f d         9
# 45                                 full stack developer         9
# 46             senior android engineer big release team         9
# 47                       senior android developer f m d         9
# 48                                         ios engineer         9
# 49                software development engineer geoflex         9
# 50                             frontend developer m f d         8
# 51                     senior software engineer android         8
# 52                           senior ios developer video         8
# 53                      senior android engineer outfits         8
# 54        ios software development engineer amazon eero         8
# 55                       senior frontend engineer d f m         8
# 56    junior front end or full stack developer f m d...         8
# 57                        ios engineer big release team         7
# 58                              senior backend engineer         7
# 59                    staff android engineer engagement         7
# 60                     mobile platform engineer android         7
# 61    senior ios developer m f d berlin hamburg or r...         7
# 62                     android engineer appcraft mobile         7
# 63                            ios developer at stanwood         7
# 64                software engineer jetlang platform io         7
# 65                 android engineer consumer experience         7
# 66                              audio software engineer         7
# 67                         ios engineer appcraft mobile         7
# 68                   full stack software engineer f m d         7
# 69                                  ios developer d f m         7
# 70    lead staff software engineer android bangkok b...         7
# 71    senior software engineer android bangkok based...         7
# 72                           full stack developer m f x         7
# 73        ios engineer customer profile personalization         7
# 74                              senior engineer android         6
# 75                          senior ios developer remote         6
# 76                           mobile developer ios m f d         6
# 77       observability senior go engineer elastic agent         6
# 78                      senior frontend developer m f d         6
# 79                                      mobile engineer         6
# 80                     software development engineer ii         6
# 81                 fullstack engineer product analytics         6
# 82     senior android engineer design engineering f m d         6
# 83     senior android engineer apps customer conversion         6
# 84    senior ios engineer customer profile personali...         6
# 85      react native software engineer javascript m f d         6
# 86                                ios engineer apps uct         6
# 87                       staff android engineer acquire         6
# 88                 senior android engineer style advice         6
# 89    senior ios developer f m d onsite or remote ho...         6
# 90                                   frontend developer         6
# 91      principal android engineer zalando lounge w m d         6
# 92    senior android developer m f d developer exper...         6
# 93      software development engineer amazon eero cloud         6
# 94                ios engineer apps category experience         6
# 95                                   lead ios developer         6
# 96                     senior ios engineer style advice         6
# 97                               sr ios developer f m d         6
# 98                            full stack engineer m f d         6
# 99               ios developer merchant bank engagement         6
# 100                        react native engineer remote         6
# 101            android engineer d f m berlin or hamburg         6
# 102                         software engineer iii m w d         6
# 103                            mobile android developer         6
# 104                             android developer video         6
# 105                                    sr ios developer         6
# 106                               lead engineer android         6
# 107                               ios engineer size fit         6
# 108                          full stack developer m f d         6
# 109            senior android engineer activity content         6
# 110   junior android engineer customer profile and p...         6
# 111                           full stack engineer d f m         6
# 112                         senior ios engineer outfits         6
# 113                            software dev engineer ii         6
# 114                            software developer m w d         6
# 115                  software engineer text to speech c         6
# 116    senior full stack software engineer python m f d         5
# 117     senior ios developer m f d developer experience         5
# 118   frontend engineer typescript react software de...         5
# 119                             android developer m w d         5
# 120   senior software development engineer amazon re...         5
# 121   android engineer customer profile and personal...         5
# 122   senior android engineer customer profile and p...         5
# 123                                 fullstack developer         5
# 124                             senior product designer         5
# 125                 android mobile engineer all genders         5
# 126              c engineer media streaming all genders         5
# 127                              react native developer         5
# 128   software development engineer amazon berlin te...         5
# 129                                    engineer android         5
# 130                                mobile ios developer         5
# 131        senior ios engineer apps customer conversion         5
# 132                       senior android engineer m f x         5
# 133                                  ios engineer d f m         5
# 134                      senior android developer m w d         5
# 135           software engineer search experience m f d         5
# 136                                       ios team lead         5
# 137                       senior android engineer f m d         5
# 138          senior android developer m w d remote rm21         5
# 139      senior ios mobile engineer vendor portal f m d         5
# 140        mobile engineer ios merchant bank engagement         5
# 141   frontend developer m w d experience design mob...         5
# 142      senior android developer all genders in berlin         5
# 143   software development engineer amazon web servi...         5
# 144          sr software engineer go messagebird pusher         5
# 145           senior ios developer zalando lounge w m d         5
# 146                            senior lead ios engineer         5
# 147              mobile app engineer react native f m d         5
# 148                 mobile engineer flutter all genders         5
# 149   senior ios developer iot m f x at sensorberg gmbh         5
# 150                   full stack android engineer d f m         5
# 151                  sr android developer in test m f x         5
# 152                           full stack engineer f m x         5
# 153                           full stack engineer f m d         5
# 154   software development engineer emea multiple lo...         5
# 155                        senior ios software engineer         5
# 156                    ubuntu desktop software engineer         5
# 157   mid level android engineer kotlin logistics ve...         5
# 158            software engineers multiple levels m f d         5
# 159                    infrastructure software engineer         5
# 160    android engineer customer acquisition engagement         5
# 161                                sr android developer         5
# 162                   software development engineer hpc         5
# 163                           backend software engineer         5
# 164             guidewire software engineer all genders         5
# 165                          software engineer c qt qml         5
# 166                        android engineer all genders         5
# 167           senior ios engineer design engineer f m d         5
# 168                      senior software engineer m f d         5
# 169                             ios developer ii senior         5
# 170         software engineer frontend typescript react         5
# 171            senior android developer welt apps m f d         5
# 172                          senior ios developer m w d         5
# 173   software engineer full stack bangkok based rel...         5
# 174                           android engineer fincrime         5
# 175                                lead unity developer         5
# 176                        mobile platform engineer ios         5
# 177                    software engineer backend kotlin         5
# 178                          mobile app developer f m d         5
# 179                    software engineer scripting team         5
# 180                               software dev engineer         5
# 181                            lead ios developer f d m         5
# 182                     software engineer data platform         5
# 183                             android developer m f d         5
# 184              senior full stack developer ruby react         5
# 185   kotlin backend developer and mobile enthusiast...         5
# 186             software engineer m f d core ios remote         5
# 187                         senior software engineer go         5
# 188   software development engineer ii based in luxe...         5
# 189             full stack software engineer javascript         5
# 190                           fullstack developer m f d         5
# 191               frontend software engineer javascript         5
# 192              senior ios engineer product experience         5
# 193                            senior frontend engineer         5
# 194                           senior ios engineer f m x         5
# 195                              senior product manager         4
# 196                           senior ios engineer m f d         4
# 197                               devops engineer m f d         4
# 198                           react engineer typescript         4
# 199    senior frontend fullstack engineer finance group         4
# 200                    lead ios android mobile engineer         4
# 201   senior full stack engineer f m d for business ...         4
# 202                        library developer typescript         4
# 203                     ruby full stack developer m f d         4
# 204                            fullstack engineer m f d         4
# 205                  software engineer pricing platform         4
# 206                                 junior ios engineer         4
# 207                                  software developer         4
# 208                       mobile qa automation engineer         4
# 209          backend software engineer content platform         4
# 210                       senior android engineer d f m         4
# 211                           senior frontend developer         4
# 212   senior full stack developer m f d for the inno...         4
# 213   software engineer mobile reverse engineering a...         4
# 214   senior full stack engineer amazon music machin...         4
# 215                   mobile full stack developer f m d         4
# 216                        software developer fullstack         4
# 217                   senior full stack developer m f d         4
# 218                   software engineer developer tools         4
# 219                  software developer go remote m w d         4
# 220                       software engineer entry level         4
# 221        senior android engineer zalando lounge m f d         4
# 222               java full stack developer all genders         4
# 223                      senior android developer video         4
# 224                              android engineer f m d         4
# 225         senior mobile engineer android react native         4
# 226                    software engineer data discovery         4
# 227                            mobile software engineer         4
# 228                 senior ios engineer merchant growth         4
# 229                                core mobile engineer         4
# 230                          senior ios developer f m d         4
# 231                        senior mobile engineer m w d         4
# 232   senior software engineer full stack bangkok ba...         4
# 233                   scala engineer pricing team m f x         4
# 234   software engineer m f d for computer assisted ...         4
# 235   senior front end mobile engineer react native ...         4
# 236                       full stack software developer         4
# 237                backend software engineer javascript         4
# 238   mobile app developer react native ionic ios an...         4
# 239       senior backend software engineer python m f x         4
# 240                  senior front end software engineer         4
# 241     senior android engineer d f m berlin or hamburg         4
# 242                                 software engineer c         4
# 243                     senior software engineer python         4
# 244                              flutter engineer m f x         4
# 245                         software engineer fullstack         4
# 246   fullstack engineer java reactjs content creati...         4
# 247          software engineer query optimization f m d         4
# 248                                       web developer         4
# 249                 senior mobile engineer ios hardware         4
# 250                                   ios tvos engineer         4
# 251                             software engineer f m d         4
# 252                                   softwareingenieur         4
# 253   software engineer edge routing and graphql pla...         4
# 254                       senior android engineer f m x         4
# 255                         front end software engineer         4
# 256               software engineer data infrastructure         4
# 257                         lead android engineer m f d         4
# 258                       senior mobile developer m f d         4
# 259                     senior ios engineer all genders         4
# 260                    engineering manager mobile f m d         4
# 261           android software developer embedded m f d         4
# 262                            ios engineer all genders         4
# 263   software development engineer enterprise workl...         4
# 264   senior android engineer discovery experience c...         4
# 265                           software engineer regtech         4
# 266                    android software engineer remote         4
# 267            android engineer client foundation f m d         4
# 268                      senior frontend designer w m d         4
# 269                     c software engineer all genders         4
# 270                  software engineer customer success         4
# 271                            android engineer f m d x         4
# 272                     full stack engineer all genders         4
# 273                                  front end engineer         4
# 274                      staff full stack web developer         4
# 275   observability senior software engineer develop...         4
# 276                            mobile developer android         4
# 277                  senior mobile engineer all genders         4
# 278                      software engineer finance tech         4
# 279                     ios engineer remote or relocate         4
# 280          senior mobile engineer ios merchant growth         4
# 281                        senior android engineer opsx         4
# 282              senior ios engineer travelers platform         4
# 283            senior software engineer go adtech f m d         4
# 284                 software engineer retail operations         4
# 285                                lead mobile engineer         4
# 286     software development engineer embedded software         4
# 287                    quality assurance engineer f m d         4
# 288                        senior software engineer ios         4
# 289                          software engineer collibra         4
# 290            gcp software engineer fast serving layer         4
# 291     mobile application developer react native d f m         4
# 292                             software engineer m f d         4
# 293   mobile software engineer react native for gend...         4
# 294                  mobile engineer react native m f d         4
# 295                             software engineer f d m         4
# 296            mobile developer android ios reactnative         4
# 297                                ios developer berlin         3
# 298         software engineer data infrastructure kausa         3
# 299                          software engineer microk8s         3
# 300        senior software engineer backend remote emea         3
# 301                               ios engineer fincrime         3
# 302   senior software engineer full stack typescript...         3
# 303                     senior ios developer relocation         3
# 304                   engineering manager ui components         3
# 305                            software engineer golang         3
# 306               golang software engineer f m d remote         3
# 307                      senior mobile engineer android         3
# 308   senior python developer m f d developer experi...         3
# 309    senior software engineer search experience m f d         3
# 310              senior android engineer based in dubai         3
# 311                                     unity developer         3
# 312   senior or staff fullstack engineer real time e...         3
# 313                         fullstack engineer be f m d         3
# 314                      golang software engineer f m x         3
# 315                   software engineer search platform         3
# 316              mobile engineer m f d remote bm21_1452         3
# 317                               software engineer app         3
# 318             software development engineer front end         3
# 319                          quality assurance engineer         3
# 320   senior software engineer python m f x focus ba...         3
# 321                            frontend developer m w d         3
# 322                           software engineer c f m x         3
# 323   senior software dev engineer customer reviews ...         3
# 324                 software engineer python kubernetes         3
# 325   senior software engineer android app developme...         3
# 326                          senior fullstack developer         3
# 327                     fullstack senior engineer m f d         3
# 328                         ios android developer m f d         3
# 329                               ios software engineer         3
# 330              android developer sinnerschrader f m d         3
# 331                    sales development representative         3
# 332          senior open source developer devops remote         3
# 333         software engineer zdirect marketplace w m d         3
# 334                 freelance fullstack developer m w d         3
# 335   senior kernel software developer for windows w...         3
# 336   mobile entwickler m w d ios android swift kotl...         3
# 337                             cypress engineer remote         3
# 338                               react native engineer         3
# 339   senior software engineer frontend focus all ge...         3
# 340      senior ios engineer discovery homescreen f m d         3
# 341   senior frontend engineer javascript react nati...         3
# 342   react native engineer mobile platform team remote         3
# 343                  senior software engineer ios m f d         3
# 344   lead staff full stack software engineer bangko...         3
# 345                      mobile developer flutter m w d         3
# 346                          c audio software developer         3
# 347            observability senior full stack engineer         3
# 348                                 crm manager b2c b2b         3
# 349   frontend software engineer zalando fulfillment...         3
# 350      senior android engineer automation infra f m d         3
# 351                    senior fullstack developer m f x         3
# 352                                     product manager         3
# 353                           junior frontend developer         3
# 354                   technical services engineer m f x         3
# 355   senior frontend engineer data infrastructure a...         3
# 356                        senior software engineer php         3
# 357   systems level software developer for windows w...         3
# 358   senior software development engineer amazon re...         3
# 359                  senior ios engineer ar and mapping         3
# 360                       fullstack javascript engineer         3
# 361                     sr sde amazon search navigation         3
# 362                                  mobile qa engineer         3
# 363                         software engineer launchpad         3
# 364     senior android engineer client foundation f m d         3
# 365                 senior software engineer javascript         3
# 366                    senior android software engineer         3
# 367                      backend software engineer ruby         3
# 368                 freelance fullstack developer m f d         3
# 369         software engineer backend focus all genders         3
# 370   senior or staff fullstack engineer ide incubat...         3
# 371         senior mobile sdk engineer berlin or remote         3
# 372   senior react native software engineer javascri...         3
# 373                   sr backend python engineer london         3
# 374                                  solidity developer         3
# 375                         lead android engineer m f x         3
# 376                           software engineer android         3
# 377                                      sales engineer         3
# 378   senior ios engineer discovery experience consu...         3
# 379                          full stack engineer remote         3
# 380                   sr software developement engineer         3
# 381                          senior ios developer w m d         3
# 382                          engineering manager mobile         3
# 383                      frontend developer react ui ux         3
# 384                observability senior go engineer apm         3
# 385                         sen android developer m w d         3
# 386      fullstack engineer m f x pest control platform         3
# 387                              lead backend developer         3
# 388                    staff principal android engineer         3
# 389   sales development representative f m d mobile ...         3
# 390           software engineer docker images community         3
# 391                           fullstack developer m w d         3
# 392                                  solution architect         3
# 393                             system dev engineer sap         3
# 394              senior software engineer input systems         3
# 395   software developer w m x microsoft dynamics 36...         3
# 396     senior mobile developer android merchant growth         3
# 397                    customer success account manager         3
# 398     mobile qa automation engineer native apps f m d         3
# 399                              qa engineer apps m f d         3
# 400     senior frontend engineer messagebird 24sessions         3
# 401            senior android developer f m d in berlin         3
# 402   senior software engineer development infrastru...         3
# 403                      senior python backend engineer         3
# 404            staff mobile engineer react native m f d         3
# 405               senior full stack engineer m f d city         3
# 406   senior android engineer engineer f m d discove...         3
# 407                       staff full stack ui developer         3
# 408                            senior backend developer         3
# 409              senior android developer consumer apps         3
# 410                   research engineer deep learning c         3
# 411                      senior frontend engineer f m x         3
# 412   software development engineer new aws service ...         3
# 413           senior frontend developer react dashboard         3
# 414                             software engineer m w d         3
# 415                     senior full stack engineer opsx         3
# 416   senior software engineer ios bangkok based rel...         3
# 417                     senior fullstack engineer f m d         3
# 418                            frontend developer m f x         3
# 419   full stack engineer amazon music machine learn...         3
# 420                                 backend engineer go         3
# 421                     developer for android sdk m f d         3
# 422                       golang dev fullstack engineer         3
# 423       senior backend software engineer python m f d         3
# 424                     test automation engineer remote         3
# 425                        senior ios engineer platform         3
# 426       software engineer juju go distributed systems         3
# 427                          3d software engineer cloud         3
# 428                       senior ruby software engineer         3
# 429                                 ios developer f m d         3
# 430                         ios developer with ar focus         3
# 431                         react native engineer m f d         3
# 432                    senior android engineer platform         3
# 433                          software engineer identity         3
# 434           software development engineer aws console         3
# 435                     kibana senior software engineer         3
# 436                         principal software engineer         3
# 437                    ios engineer consumer experience         3
# 438            senior android developer f m d bm21_1669         3
# 439                         fullstack engineer ui f m d         3
# 440                               product manager m w d         2
# 441   application innovation specialist specialist s...         2
# 442       software engineer backend m f x idealo travel         2
# 443                        java software engineer m f d         2
# 444                             software engineer f x m         2
# 445   c senior developer f m d for hana database bac...         2
# 446                        junior python engineer m f d         2
# 447                      senior software engineer media         2
# 448                      frontend developer all genders         2
# 449   senior software engineer jetlang platform data...         2
# 450                          junior full stack engineer         2
# 451                softwareentwickler m w d messtechnik         2
# 452    senior full stack engineer platform integrations         2
# 453        app developer android nearshore remote m f d         2
# 454         senior ios engineer client foundation f m d         2
# 455                                 java engineer f m d         2
# 456                             software engineer m f x         2
# 457                     head of engineering mobile apps         2
# 458   sr software development engineer in test ecosy...         2
# 459                    softwarentwickler m w d embedded         2
# 460                                senior web developer         2
# 461           back end developer javascript node js sre         2
# 462                       senior python developer m f x         2
# 463   senior scala engineer zalando direct marketpla...         2
# 464         senior mobile developer ios m w d in berlin         2
# 465        front end web developer vue typescript f m d         2
# 466                                    network engineer         2
# 467                     software engineer backend m f x         2
# 468             java engineer machine learning payments         2
# 469    software engineer ii frontend partner home m f x         2
# 470               senior python developer backend m f d         2
# 471                             sen ios developer m w d         2
# 472                      senior software engineer m f x         2
# 473     senior software development engineer full stack         2
# 474            adk software engineer all genders berlin         2
# 475            app developer ios nearshore remote m f d         2
# 476          senior software engineer php finance m f d         2
# 477                     mobile manual qa engineer m f d         2
# 478                 senior react native developer f m d         2
# 479   c software engineer for dynamic content all ge...         2
# 480                  senior react native engineer f m x         2
# 481                                         qa engineer         2
# 482             full stack developer salesforce m f div         2
# 483                       java software developer f m d         2
# 484   senior software development engineer amazon re...         2
# 485              senior technical product manager m f d         2
# 486                      mobile developer android w m d         2
# 487               software engineer digital advertising         2
# 488                              java software engineer         2
# 489       software developer anwendungsentwickler m w d         2
# 490   full stack engineer data team all levels bangk...         2
# 491   test engineer for mobile apps testing all gend...         2
# 492                   principal full stack ui developer         2
# 493                        backend developer m w d java         2
# 494                    senior product marketing manager         2
# 495   senior software development engineer search se...         2
# 496                     software engineer backend m f d         2
# 497              golang backend software engineer f m d         2
# 498                 entwicklungsingenieur labview m w d         2
# 499   software engineer python operations automation...         2
# 500    junior software engineer zdirect merchant orders         2
# 501                     fullstack engineer x f m remote         2
# 502   senior software development engineer amazon re...         2
# 503                  business development manager f m d         2
# 504                      senior frontend engineer m f d         2
# 505                      software engineer golang m w d         2
# 506   senior software development engineer embedded ...         2
# 507   senior software development engineer amazon mu...         2
# 508             senior frontend developer storage w m d         2
# 509   full stack engineer data engineering common voice         2
# 510                                   account executive         2
# 511   frontend developer new aws service for develop...         2
# 512   java developer customer facing applications ap...         2
# 513                        fullstack engineer pinterest         2
# 514                              qa analyst all genders         2
# 515                           fullstack developer d f m         2
# 516   experience designer experience architect sales...         2
# 517                  senior fullstack engineer snapchat         2
# 518        senior software engineer python adtech f m d         2
# 519                customer success manager paid social         2
# 520               senior software engineer python react         2
# 521                      mobile developer makinas f m x         2
# 522   senior frontend engineer zalando plus subscrip...         2
# 523                               sr front end engineer         2
# 524               full stack developer typescript m f d         2
# 525   junior scala engineer zalando direct marketpla...         2
# 526           senior frontend engineer react javascript         2
# 527   talent acquisition partner recruiter emea all ...         2
# 528        full stack engineer kotlin reactjs aws m f x         2
# 529                                        ui developer         2
# 530   senior full stack engineer m f d sap business ...         2
# 531   sr software development engineer amazon custom...         2
# 532    full stack developer m f x pest control platform         2
# 533   frontend engineer typescript javascript react ...         2
# 534                       lead frontend developer x f m         2
# 535                        frontend engineer web mobile         2
# 536   senior frontend engineer typescript javascript...         2
# 537                             head of game production         2
# 538   software engineer predictive modeling at grid ...         2
# 539        full stack entwickler m w d java java script         2
# 540        software development engineer in test remote         2
# 541             senior front end engineer product m f d         2
# 542                        senior mobile engineer m f d         2
# 543                             junior backend engineer         2
# 544               fullstack engineer greenfield product         2
# 545                            frontend developer w m d         2
# 546   fullstack engineer facebook ecosystem performa...         2
# 547       senior software engineer in test adtech f m d         2
# 548                       software engineer czech nlu c         2
# 549                         fullstack developer display         2
# 550                 senior software engineer ruby f m d         2
# 551                           engineering manager f m d         2
# 552                             backend developer m f x         2
# 553                        sr full stack engineer m f x         2
# 554                senior android engineer f m d berlin         2
# 555                interim java backend developer m f d         2
# 556                                       engineer java         2
# 557                       senior product manager retail         2
# 558   c senior developer for hana database backup re...         2
# 559     senior software engineer backend node js remote         2
# 560                          senior ios developer d f m         2
# 561             junior typescript js fullstack engineer         2
# 562                      full stack developer r d w m d         2
# 563                   senior software developer finance         2
# 564                                 product lead retail         2
# 565                        partner integration engineer         2
# 566   development engineer f m d vacuum interrupters...         2
# 567                           fullstack developer m f x         2
# 568   senior java backend engineer growth data products         2
# 569   backend software engineer remote euro crypto e...         2
# 570              senior ruby on rails software engineer         2
# 571                                 ios developer f m x         2
# 572   senior mobile engineer flutter f m d berlin re...         2
# 573          freelance react native developer 12 months         2
# 574                               product manager human         2
# 575   senior android mobile engineer java kotlin qui...         2
# 576                   full stack developer d m w remote         2
# 577   senior software engineer edge routing and grap...         2
# 578   backend software engineer fully remote crypto ...         2
# 579   senior software engineer javascript react adte...         2
# 580         software development engineer amazon s3 aws         2
# 581                            python backend developer         2
# 582                        technical support specialist         2
# 583   software developer backend cloud services pyth...         2
# 584                  salesforce software engineer m f d         2
# 585                                senior game designer         2
# 586   software engineer for data science m f d in be...         2
# 587   observability senior software engineer browser...         2
# 588                        senior backend engineer java         2
# 589               full stack developer javascript m f d         2
# 590                      front end development engineer         2
# 591                            software developer m f d         2
# 592                          full stack developer m w d         2
# 593                    senior javascript engineer m f x         2
# 594                                  senior c developer         2
# 595                             android developer f m x         2
# 596    senior software development engineer ops tech it         2
# 597    senior software engineer ruby messagebird pusher         2
# 598                          sr full stack ui developer         2
# 599       customer success account management team lead         2
# 600   python developer remote euro crypto exchange l...         2
# 601                        android java developer f m d         2
# 602                               backend engineer ruby         2
# 603            senior android developer m f d bm21_1670         2
# 604                                scala engineer m f d         2
# 605              software engineer m w d im digital lab         2
# 606   fullstack engineer review apps incubation engi...         2
# 607             senior backend engineer enterprise java         2
# 608        full stack developer react javascript remote         2
# 609          senior frontend engineer platform identity         2
# 610                   python developer mid senior level         2
# 611                               java entwickler m w d         2
# 612                     senior backend engineer node js         2
# 613                           web developer at stanwood         2
# 614                           be java engineer payments         2
# 615                     senior frontend developer f m d         2
# 616   senior software engineer applied machine learn...         2
# 617    senior frontend engineer web rendering framework         2
# 618   backend software engineer for whatsapp messagi...         2
# 619                                  ios engineer m f d         2
# 620                              android engineer m f x         2
# 621                senior ios developer m f d bm21_1010         2
# 622   sr software development engineer community sho...         2
# 623        full stack developer node js react aws m f d         2
# 624                                 ios developer m w d         2
# 625                       fullstack engineer typescript         2
# 626             software entwickler m w d o365 umgebung         2
# 627                      staff fullstack engineer m f d         2
# 628                     embedded software test engineer         2
# 629   senior frontend developer operations developer...         2
# 630   senior software engineer devops and sre bangko...         2
# 631                    softwareentwickler senior junior         2
# 632    software engineer business intelligence platform         2
# 633   junior frontend developer new aws service for ...         2
# 634                        software developer r d w m d         2
# 635                                       net developer         2
# 636                                data engineer python         2
# 637                    senior machine learning engineer         2
# 638   javascript developer m f x startup tackling cl...         2
# 639   software development engineer in test embedded...         2
# 640                                         c developer         2
# 641   software engineer frontend developer m f d in ...         2
# 642          enterprise search senior frontend engineer         2
# 643                                 ios developer m f d         2
# 644                     fullstack engineer 80 100 f m d         2
# 645                           product security engineer         2
# 646             junior android engineer m f x in berlin         2
# 647   senior data engineer event tracking streaming ...         2
# 648                  eu project engineer german speaker         2
# 649   senior software engineer in test vendor portal...         2
# 650           javascript frontend developer sdui app gn         2
# 651   working student m f x advertising products mob...         2
# 652       senior golang engineer markets sales go w m d         2
# 653          senior cloud infrastructure engineer m f d         2
# 654                                    backend engineer         2
# 655                      full stack engineer stripe tax         2
# 656   engineering manager director bangkok based rel...         2
# 657                  full stack developer remote berlin         2
# 658                          principal product mgr tech         2
# 659   senior software engineer golang order optimisa...         2
# 660      senior full stack software engineer core teams         2
# 661                     software engineer node js f m d         2
# 662                          senior ios developer x f m         2
# 663                     junior frontend developer f m d         2
# 664        senior full stack developer berlin or remote         2
# 665                     software engineer bild de m f d         2
# 666                     senior frontend developer m w d         2
# 667                      talent pool fullstack engineer         2
# 668                    product designer user experience         2
# 669          senior full stack engineer m f x at re cap         2
# 670          software development engineer aws identity         2
# 671   senior software engineer focus backend m f d r...         2
# 672   senior fullstack engineer php react for produc...         2
# 673   senior frontend engineer profile and personali...         2
# 674   senior full stack software developer engineer ...         2
# 675   senior expert engineer software architecture f...         2
# 676   customer success account manager enterprise ac...         2
# 677   senior software development engineer amazon ne...         2
# 678                           product designer traveler         2
# 679    golang software engineer transactions team m f d         2
# 680         fullstack developer m f x product discovery         2
# 681                     senior frontend developer m w x         2
# 682               full stack engineer developer console         2
# 683                  senior ios engineer m f d team ios         2
# 684                                    python developer         2
# 685   senior frontend developer m w d experience des...         2
# 686                                 senior engineer ios         2
# 687                      software engineer c pix4dmatic         2
# 688                      digital product designer m f d         2
# 689                       senior software developer ios         2
# 690     scala engineer zalando direct marketplace w m d         2
# 691      senior software engineer integration qa python         2
# 692   senior software development engineer redshift ...         2
# 693          c software engineer containers all genders         2
# 694         senior fullstack developer consultant d m w         2
# 695               full stack developer mckinsey digital         2
# 696                                      game developer         2
# 697                            frontend developer d f m         2
# 698                                  ios engineer m f x         2
# 699                          full stack engineer python         2
# 700                        frontend developer freelance         2
# 701                               fullstack developer a         2
# 702                staff engineer mobile platform f m d         2
# 703            senior frontend software engineer growth         2
# 704      software engineer mobile solutions android ios         2
# 705                                     devops engineer         2
# 706                   senior software engineer qa f m d         2
# 707                  software engineer ii ad tech m f x         2
# 708                senior front end web developer m w d         2
# 709   full stack javascript engineer multiple openin...         2
# 710               senior full stack engineer java scala         2
# 711            sr software engineer amazon reviews team         2
# 712                           technical account manager         2
# 713                          solutions engineer germany         2
# 714               ios developer swift rxswift freelance         2
# 715                          junior fullstack developer         2
# 716   speech platform engineer android all genders i...         2
# 717                    fullstack engineer node js react         2
# 718   lead staff software engineer ios bangkok based...         2
# 719   senior software engineer site reliability engi...         2
# 720   software engineer zdirect b2b marketplace merc...         2
# 721              engineering manager mobile all genders         2
# 722                               python engineer f m x         2
# 723   lisk mobile developer react native m f d bm21_...         2
# 724                               ui frontend developer         2
# 725              customer software development engineer         2
# ...
# 1120               software engineer full stack germany         1
# 1121                                  backend developer         1
# 1122                     senior mobile tech crm manager         1
# 1123  executive product manager next generation sw p...         1
# 1124                             senior consultant dipa         1
# 1125                                      game director         1
# 1126    customer success account manager for developers         1
# 1127                      backend integration developer         1
# 1128  product manager m f d vc backed clean tech ven...         1
# 1129                         director of product motors         1
# 1130      senior fullstack engineer lens kubernetes ide         1
# 1131             senior software engineer m f d bild de         1
# 1132                               social media manager         1
# 1133             software developer m f x remote berlin         1
# 1134                      junior backend engineer m f d         1
# 1135                  b2b performance marketing manager         1
# 1136                            embedded engineer f m d         1
# 1137                                 r d engineer m w d         1
# 1138                               front end entwickler         1
# 1139                    softwareentwickler in berlin de         1
# 1140  flutter app entwickler app developer applicati...         1
# 1141                                    product analyst         1
# 1142             fullstack engineer fokus node js m w d         1
# 1143                                      product owner         1
# 1144                       technical artist new product         1
# 1145  full stack entwickler w m d für webanwendungen...         1
# 1146                          engineering manager w d m         1
# 1147  senior manager bi analytics mobile free2play g...         1
# 1148     senior software engineer platform as a service         1
# 1149                          software engineer gx team         1
# 1150    senior gcp software engineer fast serving layer         1
# 1151                        competence specialist m f d         1
# 1152  senior software engineer android rider transmi...         1
# 1153             lead ux ui designer new mobile shooter         1
# 1154                              product manager f m d         1
# 1155                c embedded software developer m f d         1
# 1156                senior software engineer ruby m f d         1
# 1157                100 remote senior software engineer         1
# 1158   regional mobile crm manager m f d zalando lounge         1
# 1159                       software engineer full stack         1
# 1160               fullstack engineer media sites m w d         1
# 1161                       snr ux designer fashion tech         1
# 1162                   junior software engineer backend         1
# 1163                                  junior qa analyst         1
# 1164                       software engineer networking         1
# 1165        senior manager performance marketing berlin         1
# 1166            senior product manager web video editor         1
# 1167  berlin fullstack developer javascript node js ...         1
# 1168  c developer for interactive 3d applications f m d         1
# 1169           senior software engineer front end m f d         1
# 1170                       sales account executive apac         1
# 1171                                    visual designer         1
# 1172             senior frontend developer f m d berlin         1
# 1173  junior full stack entwickler m w d inkl remote...         1
# 1174                   senior backend software engineer         1
# 1175                 senior product manager a b testing         1
# 1176                           senior marketing analyst         1
# 1177  lead iot technology architect data platform m f d         1
# 1178  senior software development manager amazon mus...         1
# 1179      product owner web mobile team m f d bm21_1532         1
# 1180     senior cloud analytics platform engineer m f d         1
# 1181                         technical program director         1
# 1182            devops engineer multiple openings f m d         1
# 1183           process product compliance manager m f d         1
# 1184   project manager women s health medical expertise         1
# 1185  senior software engineer traffic pricing platf...         1
# 1186      senior software engineer terraform enterprise         1
# 1187             junior software engineer node js f m d         1
# 1188          digital strategist m w d based in germany         1
# 1189                           seal fullstack developer         1
# 1190               senior mobile product designer m f d         1
# 1191                  senior javascript engineer editor         1
# 1192                  people operations associate w m d         1
# 1193                       full stack software engineer         1
# 1194                                      head of video         1
# 1195                 software engineer ii backend m f d         1
# 1196                         product lead supply demand         1
# 1197  specialist project management focus data sales...         1
# 1198             react reactjs softwareentwickler m w d         1
# 1199                                data engineer m f d         1
# 1200           senior software engineer frontend growth         1
# 1201  mobile developer c c qt talent for creative wr...         1
# 1202     product owner electric mobility services m f d         1
# 1203  senior full stack engineer java react policy l...         1
# 1204                       vue react webdeveloper w m d         1
# 1205                      lead engineer consumer search         1
# 1206   lead frontend developer react at crypto start up         1
# 1207                             senior react developer         1
# 1208                           unreal engine programmer         1
# 1209                           backend engineer acquire         1
# 1210                         backend engineer bank core         1
# 1211                      ux designer automotive design         1
# 1212                        qa engineer working student         1
# 1213  java backend developer mobile game m f d at me...         1
# 1214       senior fullstack engineer greenfield product         1
# 1215           senior fullstack engineer node react aws         1
# 1216                                         ua manager         1
# 1217    berlin sr fullstack developer javascript 90 000         1
# 1218                      backend engineer devops m f d         1
# 1219                              head of product f m d         1
# 1220  fullstack engineer for web components microser...         1
# 1221                              startup analyst w m d         1
# 1222                     head of user interface android         1
# 1223                    sales technical account manager         1
# 1224       architect data collection provisioning m f d         1
# 1225            senior product manager web photo editor         1
# 1226                        accounting tax lead germany         1
# 1227     senior software quality engineer cards wallets         1
# 1228                       head of government relations         1
# 1229  projekt programm business development sr manag...         1
# 1230                          mobile qa manual engineer         1
# 1231   senior fullstack developer all genders full time         1
# 1232       engineering team lead financial technologies         1
# 1233  full stack software engineer data platform too...         1
# 1234             sales development representative m f d         1
# 1235          frontend developer office or remote m f x         1
# 1236                            senior tech coordinator         1
# 1237                    teamlead m f x game development         1
# 1238  software development engineer customer enginee...         1
# 1239  senior platform software engineer m f d data s...         1
# 1240   spokesperson content specialist hr finance m f d         1
# 1241                talent acquisition specialist m f x         1
# 1242                       vice president finance m f d         1
# 1243                               build engineer f m d         1
# 1244             full stack engineer growth team remote         1
# 1245                    engineering manager all genders         1
# 1246           full stack developer backend focus m f x         1
# 1247            senior frontend engineer react js m w d         1
# 1248                          senior data analyst m f d         1
# 1249  sw engineer car navigation systems typescript ...         1
# 1250          senior technical trainer evangelist m f d         1
# 1251                         app store business manager         1
# 1252          technical account manager german speaking         1
# 1253                               senior data engineer         1
# 1254               software engineer research fullstack         1
# 1255                software engineer ii frontend m f d         1
# 1256                             defi backend developer         1
# 1257                               talent sourcer m f d         1
# 1258                    account manager german speaking         1
# 1259  senior software engineer m f x payments engine...         1
# 1260           lead fullstack engineer node js react js         1
# 1261      fullstack developer in ml ai in digitalhealth         1
# 1262               embedded software engineer iot m f d         1
# 1263  senior full stack engineer python react node m...         1
# 1264                      c developer in berlin germany         1
# 1265    product manager experimentation logistics f m d         1
# 1266  senior software engineer frontend m f x idealo...         1
# 1267  lead fullstack engineer node js react js digit...         1
# 1268                     junior backend developer f m d         1
# 1269                 mitarbeiter kundenservice teilzeit         1
# 1270         software engineer f m d digital production         1
# 1271      data engineer algorithmic data products m f d         1
# 1272                      senior backend engineer m w d         1
# 1273  digital manufacturing operations intelligent a...         1
# 1274                      community manager mobile emea         1
# 1275               senior product designer mobile m f d         1
# 1276                                           producer         1
# 1277                     senior software engineer m w d         1
# 1278                                 unity 3d developer         1
# 1279                       senior backend engineer opsx         1
# 1280                    product manager live operations         1
# 1281                           senior flutter developer         1
# 1282                       software engineer 100 remote         1
# 1283                    support associate kundenservice         1
# 1284                         senior software engineer c         1
# 1285              senior golang software engineer m f d         1
# 1286            senior software engineer m f d bm21_998         1
# 1287                              ruby backend engineer         1
# 1288                            solutions engineer dach         1
# 1289                             backend engineer m f x         1
# 1290                           customer success manager         1
# 1291        senior account executive platform solutions         1
# 1292                       growth marketing manager b2b         1
# 1293                      head of hr operations germany         1
# 1294             senior react developer x f m freelance         1
# 1295             senior product designer hardware tribe         1
# 1296                               operations associate         1
# 1297  principal kernel software developer for window...         1
# 1298             chief technology officer m w d ecomove         1
# 1299                             product designer m f x         1
# 1300                                sr backend engineer         1
# 1301                                      analyst fraud         1
# 1302                front end developer m f d bm21_1141         1
# 1303  life science projekt programm business develop...         1
# 1304                 senior react native engineer m f d         1
# 1305  senior backend engineer java kotlin for order ...         1
# 1306  integration test manager digital lifecycle man...         1
# 1307                                    account manager         1
# 1308         engineering manager f m x partially remote         1
# 1309         senior fullstack engineer react typescript         1
# 1310                      customer success manager dach         1
# 1311                  senior full stack developer m f x         1
# 1312                       sr sde aws aqua for redshift         1
# 1313                    lead full stack developer m f x         1
# 1314            senior software engineer back end m f d         1
# 1315  associate general counsel data protection inst...         1
# 1316           head of product design restaurants f m d         1
# 1317  software architect focus on functional and pla...         1
# 1318                              full stack entwickler         1
# 1319            senior softwareentwickler android w m d         1
# 1320                  quality automation engineer m f x         1
# 1321                                         sr sde aws         1
# 1322                 senior frontend engineer vue f m d         1
# 1323                          senior unity 3d developer         1
# 1324                          full stack engineer m f x         1
# 1325  senior app marketing manager engagement growth...         1
# 1326       senior ux ui concept design specialist m f d         1
# 1327                        full stack senior developer         1
# 1328  product manager logistics ios android rider ap...         1
# 1329                                  qa engineer d f m         1
# 1330                      software engineer all genders         1
# 1331   software cloud engineer digital assistants m f d         1
# 1332                          hr business partner m f d         1
# 1333                       database engineer postgresql         1
# 1334          stack software engineer ci infrastructure         1
# 1335                  tech lead search experience m f d         1
# 1336                                    senior producer         1
# 1337  fullstack engineer electron focused x f m bm21...         1
# 1338                             backend engineer cards         1
# 1339         full stack net engineer m f d integrations         1
# 1340                        inside sales representative         1
# 1341                 senior software engineer jvm m f d         1
# 1342                      senior backend engineer d f m         1
# 1343  senior legal counsel business partner legal co...         1
# 1344                 head of base platform stacks m f d         1
# 1345           senior java developer chapter lead m f d         1
# 1346          full stack software engineer w m d berlin         1
# 1347                            react native developers         1
# 1348                     director of product ecosystems         1
# 1349               full stack frontend backend engineer         1
# 1350                                  crm manager m f d         1
# 1351                            flutter developer m f x         1
# 1352          frontend engineer product discovery m f x         1
# 1353      freelance java kotlin developer berlin remote         1
# 1354  senior software engineer w m d identity access...         1
# 1355              market development specialist germany         1
# 1356          talent acquisition partner product design         1
# 1357                                game level designer         1
# 1358           senior fullstack engineer frontend focus         1
# 1359  mobile entwickler android ios reactnative m w ...         1
# 1360                director of engineering all genders         1
# 1361                      senior product designer d f m         1

# %%
df['position'] = df['position'].apply(lambda x: x.lower())
df['descriptions'] = df['descriptions'].apply(lambda x: x.lower())

# %%
def filter_df(x, y):
    if ('mobile' in x) or ('android' in x) or ('ios' in x) or ('swift' in x) or ('kotlin' in x) :
        return "keep"
    else:
        if ('android' in y) or ('ios' in y) or ('mobile' in y) or ('swift' in y) or ('kotlin' in y):
            return 'keep'
        else:
            return 'remove'     
df['new_filter'] = list(map(filter_df, df['position'], df['descriptions']))

# %%
remove = df[df['new_filter']=='remove'].reset_index(drop=True)

# %%
df = df[df['new_filter']=='keep'].reset_index(drop=True)
df = df.drop(['new_filter'], axis=1)

# %%
df.shape
# Out:
# (2605, 15)

# %% [markdown]
# # Total Job Postings by Time Frames

# %%
def dates_posted_to_time_frames(x):
    if ('hour' in x) or ('minute' in x):
        return 'within 1 week'
    try:
        num = int(re.findall('\d+', x)[0])
    except TypeError:
        return np.NaN
    if 'week' in x:
        if num == 1:
            return 'within 1 week'
        elif num == 2:
            return 'Between 1 and 2 weeks'
        elif num == 3:
            return 'Between 2 and 3 weeks'
        else:
            return "More than 3 weeks" 
    else:
        return "More than 3 weeks"        
df['time_frames'] = list(map(dates_posted_to_time_frames, df['date_posted']))
# df['time_frames'].value_counts()

# %%
temp = pd.DataFrame(df['time_frames'].value_counts()).reset_index()
temp.columns =['time_frames', 'number of postings']
temp
# Out:
#              time_frames  number of postings
# 0      More than 3 weeks                1175
# 1          within 1 week                 795
# 2  Between 1 and 2 weeks                 355
# 3  Between 2 and 3 weeks                 280

# %%
a = 'within 1 week'
b = 'Between 1 and 2 weeks'
c = 'Between 2 and 3 weeks'
d = 'More than 3 weeks'
x = [a,b, c, d]
a = temp[temp['time_frames'] == a]['number of postings'].values[0]
b = temp[temp['time_frames'] == b]['number of postings'].values[0]
c = temp[temp['time_frames'] == c]['number of postings'].values[0]
d = temp[temp['time_frames'] == d]['number of postings'].values[0]
y = [a,b,c,d]

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x=x, y=y)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
df_within_1_week = df[df['time_frames'] == 'within 1 week']

# %%
df_within_1_month = df[(df['time_frames'].isin(['within 1 week', 'Between 1 and 2 weeks', 'Between 2 and 3 weeks'])) |
                       (df['date_posted'] == '1 month ago')]

# %% [markdown]
# # Seniority Level Segments

# %%
def segment_seniority_levels(x, y):
    if pd.isna(y):
        if ('senior' in x) or ('lead' in x) or ('sr ' in x) or ('director' in x) or ('manager' in x):
            return 'associate/senior'
        else:
            return 'junior/entry level'
    elif y == 'associate':
        return 'associate/senior'
df['seniority_segment_created'] = list(map(segment_seniority_levels, df['position'],df['seniority level']))
print(df['seniority_segment_created'].value_counts())

temp = pd.DataFrame(df['seniority_segment_created'].value_counts()).reset_index()
temp.columns =['Seniority', 'number of postings']
print(temp)

fig, ax = plt.subplots(figsize= (8,5))
ax = sns.barplot(x="Seniority", y="number of postings", data=temp)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()
# Out:
# associate/senior      1437
# junior/entry level    1168
# Name: seniority_segment_created, dtype: int64
#             Seniority  number of postings
# 0    associate/senior                1437
# 1  junior/entry level                1168

# %%
junior_level_df = df[df['seniority_segment_created']=='junior/entry level']
print(junior_level_df.shape)
senior_level_df = df[df['seniority_segment_created']=='associate/senior']
print(senior_level_df.shape)
# Out:
# (1168, 17)
# (1437, 17)

# %% [markdown]
# # Junior Level job postings by Time Frames

# %%
temp = pd.DataFrame(junior_level_df['time_frames'].value_counts()).reset_index()
temp.columns =['time_frames', 'number of postings']
temp
# Out:
#              time_frames  number of postings
# 0      More than 3 weeks                 521
# 1          within 1 week                 321
# 2  Between 1 and 2 weeks                 184
# 3  Between 2 and 3 weeks                 142

# %%
a = 'within 1 week'
b = 'Between 1 and 2 weeks'
c = 'Between 2 and 3 weeks'
d = 'More than 3 weeks'
x = [a,b, c, d]
a = temp[temp['time_frames'] == a]['number of postings'].values[0]
b = temp[temp['time_frames'] == b]['number of postings'].values[0]
c = temp[temp['time_frames'] == c]['number of postings'].values[0]
d = temp[temp['time_frames'] == d]['number of postings'].values[0]
y = [a,b,c,d]
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x=x, y=y)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Companies Hiring

# %%
temp = pd.DataFrame(df['company_name'].value_counts()).reset_index()
temp.columns =['company_name', 'number of postings']
temp.head(30)
# Out:
#                  company_name  number of postings
# 0                     zalando                 189
# 1                      amazon                 175
# 2                     picsart                  84
# 3               delivery hero                  74
# 4                      cariad                  57
# 5              mobile.de gmbh                  40
# 6                       sumup                  37
# 7                       agoda                  35
# 8                         n26                  33
# 9               client server                  33
# 10              tier mobility                  31
# 11                      moyyn                  31
# 12                     zattoo                  30
# 13                      flink                  29
# 14                     adjust                  29
# 15                    zendesk                  27
# 16               michael page                  27
# 17                       wolt                  26
# 18                 contentful                  24
# 19               getyourguide                  23
# 20  mimi hearing technologies                  23
# 21                     zenjob                  21
# 22                 mattermost                  20
# 23                     babbel                  20
# 24               surprise.com                  20
# 25           axel springer se                  19
# 26                 soundcloud                  19
# 27                   join.com                  18
# 28                  sharecare                  16
# 29                     klarna                  16

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=temp.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # top companies hiring within 1 week

# %%
temp = pd.DataFrame(df_within_1_week['company_name'].value_counts()).reset_index()
temp.columns =['company_name', 'number of postings']
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=temp.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # top companies hiring within 1 month

# %%
temp = pd.DataFrame(df_within_1_month['company_name'].value_counts()).reset_index()
temp.columns =['company_name', 'number of postings']
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=temp.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Companies hiring only for junior positions

# %%
temp = pd.DataFrame(junior_level_df['company_name'].value_counts()).reset_index()
temp.columns =['company_name', 'number of postings']
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=temp.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Positions Overall

# %%
top_positions = pd.DataFrame(df['position'].value_counts()).reset_index()
top_positions.columns = ['position', 'count']
top_positions
# Out:
#                                               position  count
# 0                                    android developer     44
# 1                        software development engineer     40
# 2                             senior android developer     35
# 3                              senior android engineer     31
# 4                                 senior ios developer     27
# 5                                  senior ios engineer     26
# 6                    lead mobile developer ios android     21
# 7                                   ios engineer f m d     21
# 8                                     android engineer     20
# 9                           senior ios developer m f d     18
# 10                          ios developer f m d 80 100     17
# 11                      senior android developer m f d     16
# 12                   android software engineer in test     14
# 13                software development engineer mobile     14
# 14                mobile software development engineer     13
# 15   android software development engineer amazon eero     13
# 16                       senior android engineer m f d     12
# 17                senior software development engineer     12
# 18                                       ios developer     12
# 19                        android engineer kotlin java     12
# 20                            fullstack engineer d f m     11
# 21      sr software development engineer amazon berlin     11
# 22                              android engineer d f m     11
# 23                 android developer m w d remote rm21     10
# 24                       android engineer style advice     10
# 25                           software engineer backend     10
# 26                              mobile developer m f d      9
# 27                 android engineer remote or relocate      9
# 28                      senior android developer f m d      9
# 29            senior android engineer big release team      9
# 30                       mobile engineer flutter m f d      9
# 31                                        ios engineer      9
# 32                        senior lead android engineer      9
# 33                          associate android engineer      9
# 34                    senior software engineer android      8
# 35                                   software engineer      8
# 36                                 full stack engineer      8
# 37                          senior ios developer video      8
# 38                     senior android engineer outfits      8
# 39       ios software development engineer amazon eero      8
# 40   junior front end or full stack developer f m d...      8
# 41                      senior frontend engineer d f m      8
# 42                           ios developer at stanwood      7
# 43                                 ios developer d f m      7
# 44                        ios engineer appcraft mobile      7
# 45   lead staff software engineer android bangkok b...      7
# 46                       ios engineer big release team      7
# 47                   staff android engineer engagement      7
# 48                             audio software engineer      7
# 49                    mobile platform engineer android      7
# 50                android engineer consumer experience      7
# 51                    android engineer appcraft mobile      7
# 52       ios engineer customer profile personalization      7
# 53   senior software engineer android bangkok based...      7
# 54   senior ios developer m f d berlin hamburg or r...      7
# 55   junior android engineer customer profile and p...      6
# 56                        react native engineer remote      6
# 57                senior android engineer style advice      6
# 58                         senior ios developer remote      6
# 59                             android developer video      6
# 60                              sr ios developer f m d      6
# 61                                    sr ios developer      6
# 62                            software dev engineer ii      6
# 63    senior android engineer design engineering f m d      6
# 64   senior android developer m f d developer exper...      6
# 65                               ios engineer size fit      6
# 66                             senior engineer android      6
# 67                               ios engineer apps uct      6
# 68              ios developer merchant bank engagement      6
# 69            android engineer d f m berlin or hamburg      6
# 70   senior ios engineer customer profile personali...      6
# 71                           full stack engineer d f m      6
# 72                            mobile android developer      6
# 73   senior ios developer f m d onsite or remote ho...      6
# 74                    senior ios engineer style advice      6
# 75                             senior backend engineer      6
# 76                      staff android engineer acquire      6
# 77                  software engineer text to speech c      6
# 78            senior android engineer activity content      6
# 79                         senior ios engineer outfits      6
# 80     principal android engineer zalando lounge w m d      6
# 81               software development engineer fire tv      6
# 82     react native software engineer javascript m f d      6
# 83                          mobile developer ios m f d      6
# 84                               lead engineer android      6
# 85     software development engineer amazon eero cloud      6
# 86    senior android engineer apps customer conversion      6
# 87                                     mobile engineer      6
# 88               ios engineer apps category experience      6
# 89                                  lead ios developer      6
# 90              c engineer media streaming all genders      5
# 91                        android engineer all genders      5
# 92   senior full stack software developer f m d pro...      5
# 93                   full stack android engineer d f m      5
# 94                      senior android developer m w d      5
# 95                             android developer m w d      5
# 96                 android mobile engineer all genders      5
# 97     senior ios developer m f d developer experience      5
# 98   android engineer customer profile and personal...      5
# 99                        senior ios software engineer      5
# 100            guidewire software engineer all genders      5
# 101              frontend software engineer javascript      5
# 102  software development engineer emea multiple lo...      5
# 103  senior android engineer customer profile and p...      5
# 104                   infrastructure software engineer      5
# 105             mobile app engineer react native f m d      5
# 106     senior android developer all genders in berlin      5
# 107   android engineer customer acquisition engagement      5
# 108                               sr android developer      5
# 109                               mobile ios developer      5
# 110                   software engineer backend kotlin      5
# 111   senior full stack software engineer python m f d      5
# 112                mobile engineer flutter all genders      5
# 113                            ios developer ii senior      5
# 114            full stack software engineer javascript      5
# 115             senior ios engineer product experience      5
# 116                 sr android developer in test m f x      5
# 117  frontend developer m w d experience design mob...      5
# 118                           lead ios developer f d m      5
# 119  software development engineer amazon web servi...      5
# 120                                 ios engineer d f m      5
# 121  software engineer full stack bangkok based rel...      5
# 122  senior ios developer iot m f x at sensorberg gmbh      5
# 123         senior android developer m w d remote rm21      5
# 124                   software engineer scripting team      5
# 125                       mobile platform engineer ios      5
# 126  kotlin backend developer and mobile enthusiast...      5
# 127                            senior product designer      5
# 128                      senior android engineer m f x      5
# 129                          senior ios engineer f m x      5
# 130                      senior android engineer f m d      5
# 131                         mobile app developer f m d      5
# 132          software engineer search experience m f d      5
# 133             senior full stack developer ruby react      5
# 134  software development engineer amazon berlin te...      5
# 135                           senior frontend engineer      5
# 136                         software engineer c qt qml      5
# 137                               lead unity developer      5
# 138       senior ios engineer apps customer conversion      5
# 139            software engineer m f d core ios remote      5
# 140       mobile engineer ios merchant bank engagement      5
# 141                             react native developer      5
# 142                                      ios team lead      5
# 143                          android engineer fincrime      5
# 144                            android developer m f d      5
# 145          senior ios developer zalando lounge w m d      5
# 146                           senior lead ios engineer      5
# 147  mid level android engineer kotlin logistics ve...      5
# 148                         senior ios developer m w d      5
# 149                              software dev engineer      5
# 150  frontend engineer typescript react software de...      5
# 151     senior ios mobile engineer vendor portal f m d      5
# 152                                   engineer android      5
# 153           senior android developer welt apps m f d      5
# 154          senior ios engineer design engineer f m d      5
# 155                    c software engineer all genders      4
# 156   senior frontend fullstack engineer finance group      4
# 157                                 front end engineer      4
# 158                           senior software engineer      4
# 159           android engineer client foundation f m d      4
# 160                            software engineer f d m      4
# 161  software engineer edge routing and graphql pla...      4
# 162  senior android engineer discovery experience c...      4
# 163        senior mobile engineer android react native      4
# 164                 senior mobile engineer all genders      4
# 165                   quality assurance engineer f m d      4
# 166                senior ios engineer merchant growth      4
# 167                    ios engineer remote or relocate      4
# 168    mobile application developer react native d f m      4
# 169                      senior android engineer d f m      4
# 170  senior front end mobile engineer react native ...      4
# 171         senior mobile engineer ios merchant growth      4
# 172                     staff full stack web developer      4
# 173                    senior ios engineer all genders      4
# 174                       senior mobile engineer m w d      4
# 175                             android engineer f m d      4
# 176                     senior android developer video      4
# 177         software engineer query optimization f m d      4
# 178                   lead ios android mobile engineer      4
# 179                          senior ios engineer m f d      4
# 180                               core mobile engineer      4
# 181                       senior android engineer opsx      4
# 182                  software engineer developer tools      4
# 183                           mobile software engineer      4
# 184           mobile developer android ios reactnative      4
# 185             senior ios engineer travelers platform      4
# 186                                  ios tvos engineer      4
# 187  senior software engineer full stack bangkok ba...      4
# 188  senior full stack engineer amazon music machin...      4
# 189                             senior product manager      4
# 190                        lead android engineer m f d      4
# 191  mobile app developer react native ionic ios an...      4
# 192                              devops engineer m f d      4
# 193       senior android engineer zalando lounge m f d      4
# 194               backend software engineer javascript      4
# 195           senior software engineer go adtech f m d      4
# 196                             flutter engineer m f x      4
# 197                               lead mobile engineer      4
# 198                 mobile engineer react native m f d      4
# 199                 software developer go remote m w d      4
# 200          android software developer embedded m f d      4
# 201                         senior ios developer f m d      4
# 202  software engineer mobile reverse engineering a...      4
# 203                      senior android engineer f m x      4
# 204                           android engineer f m d x      4
# 205                           ios engineer all genders      4
# 206                                 software developer      4
# 207  fullstack engineer java reactjs content creati...      4
# 208    senior android engineer d f m berlin or hamburg      4
# 209                   android software engineer remote      4
# 210                      mobile qa automation engineer      4
# 211  mobile software engineer react native for gend...      4
# 212                                junior ios engineer      4
# 213                  mobile full stack developer f m d      4
# 214                   engineering manager mobile f m d      4
# 215                      senior mobile developer m f d      4
# 216                       senior software engineer ios      4
# 217                          backend software engineer      4
# 218    software development engineer embedded software      4
# 219                           mobile developer android      4
# 220                    ruby full stack developer m f d      4
# 221                senior mobile engineer ios hardware      4
# 222  senior software engineer ios bangkok based rel...      3
# 223    senior android engineer client foundation f m d      3
# 224             senior android developer consumer apps      3
# 225          software development engineer aws console      3
# 226                             qa engineer apps m f d      3
# 227                     mobile developer flutter m w d      3
# 228  senior frontend engineer data infrastructure a...      3
# 229                                     sales engineer      3
# 230        software engineer backend focus all genders      3
# 231                                    product manager      3
# 232                        ios developer with ar focus      3
# 233                                crm manager b2c b2b      3
# 234                                 solution architect      3
# 235    senior frontend engineer messagebird 24sessions      3
# 236                           software developer m w d      3
# 237                            system dev engineer sap      3
# 238                         quality assurance engineer      3
# 239                  engineering manager ui components      3
# 240                              ios software engineer      3
# 241  senior python developer m f d developer experi...      3
# 242                         senior ios developer w m d      3
# 243                   sales development representative      3
# 244  lead staff full stack software engineer bangko...      3
# 245        senior mobile sdk engineer berlin or remote      3
# 246  react native engineer mobile platform team remote      3
# 247             mobile engineer m f d remote bm21_1452      3
# 248                               ios developer berlin      3
# 249         senior open source developer devops remote      3
# 250                             lead backend developer      3
# 251                   staff principal android engineer      3
# 252  senior frontend engineer javascript react nati...      3
# 253                   customer success account manager      3
# 254  senior software engineer frontend focus all ge...      3
# 255        software engineer data infrastructure kausa      3
# 256             senior software engineer input systems      3
# 257                            cypress engineer remote      3
# 258                        lead android engineer m f x      3
# 259                        fullstack engineer be f m d      3
# 260  senior software engineer development infrastru...      3
# 261             android developer sinnerschrader f m d      3
# 262                   senior android software engineer      3
# 263                         full stack developer m f d      3
# 264                                    unity developer      3
# 265                   ios engineer consumer experience      3
# 266  sales development representative f m d mobile ...      3
# 267                     senior mobile engineer android      3
# 268                    software engineer data platform      3
# 269  senior software engineer android app developme...      3
# 270                        ios android developer m f d      3
# 271                        react native engineer m f d      3
# 272                       senior ios engineer platform      3
# 273                        principal software engineer      3
# 274                  software engineer search platform      3
# 275                              ios engineer fincrime      3
# 276                         engineering manager mobile      3
# 277                     backend software engineer ruby      3
# 278           senior android developer f m d bm21_1669      3
# 279                        sen android developer m w d      3
# 280                     golang software engineer f m x      3
# 281           senior android developer f m d in berlin      3
# 282           staff mobile engineer react native m f d      3
# 283  senior android engineer engineer f m d discove...      3
# 284                 senior ios engineer ar and mapping      3
# 285                    fullstack senior engineer m f d      3
# 286                    senior ios developer relocation      3
# 287  mobile entwickler m w d ios android swift kotl...      3
# 288                   senior android engineer platform      3
# 289             senior android engineer based in dubai      3
# 290                    developer for android sdk m f d      3
# 291                     frontend developer react ui ux      3
# 292                 senior software engineer ios m f d      3
# 293                   senior fullstack developer m f x      3
# 294              senior full stack engineer m f d city      3
# 295                        fullstack engineer ui f m d      3
# 296                         full stack engineer remote      3
# 297  systems level software developer for windows w...      3
# 298                                ios developer f m d      3
# 299          senior frontend developer react dashboard      3
# 300                    senior full stack engineer opsx      3
# 301     senior ios engineer discovery homescreen f m d      3
# 302     senior android engineer automation infra f m d      3
# 303                      fullstack javascript engineer      3
# 304    senior mobile developer android merchant growth      3
# 305                         3d software engineer cloud      3
# 306                          software engineer android      3
# 307  senior react native software engineer javascri...      3
# 308   senior software engineer search experience m f d      3
# 309                              react native engineer      3
# 310                          full stack engineer f m d      3
# 311                      full stack software developer      3
# 312  senior kernel software developer for windows w...      3
# 313                    test automation engineer remote      3
# 314                                 mobile qa engineer      3
# 315    mobile qa automation engineer native apps f m d      3
# 316                  technical services engineer m f x      3
# 317  senior ios engineer discovery experience consu...      3
# 318  full stack engineer amazon music machine learn...      3
# 319             golang backend software engineer f m d      2
# 320               senior front end web developer m w d      2
# 321                   softwareentwickler senior junior      2
# 322                           senior backend developer      2
# 323               customer success manager paid social      2
# 324  lisk mobile developer react native m f d bm21_...      2
# 325                     mobile developer makinas f m x      2
# 326  senior data engineer event tracking streaming ...      2
# 327                           frontend developer m f x      2
# 328                            sen ios developer m w d      2
# 329  full stack javascript engineer multiple openin...      2
# 330                                 senior c developer      2
# 331                          fullstack developer m f x      2
# 332               senior android engineer f m d berlin      2
# 333    senior software engineer backend node js remote      2
# 334                              ui frontend developer      2
# 335                          technical account manager      2
# 336                 senior ios engineer m f d team ios      2
# 337         senior cloud infrastructure engineer m f d      2
# 338  engineering manager director bangkok based rel...      2
# 339  senior software engineer javascript react adte...      2
# 340       full stack engineer kotlin reactjs aws m f x      2
# 341             senior technical product manager m f d      2
# 342                  senior software engineer qa f m d      2
# 343                       senior mobile engineer m f d      2
# 344                       sr full stack engineer m f x      2
# 345     software engineer mobile solutions android ios      2
# 346           app developer ios nearshore remote m f d      2
# 347                           frontend developer d f m      2
# 348                                  account executive      2
# 349  experience designer experience architect sales...      2
# 350                              ios lead f m d 80 100      2
# 351                    software engineer backend m f x      2
# 352              full stack engineer developer console      2
# 353                               senior game designer      2
# 354                                 ios engineer m f x      2
# 355         c software engineer containers all genders      2
# 356                junior hybrid cloud architect f m x      2
# 357                      senior product manager retail      2
# 358          senior frontend engineer react javascript      2
# 359                            android developer f m x      2
# 360                   senior javascript engineer m f x      2
# 361    senior software development engineer full stack      2
# 362                   product designer user experience      2
# 363                            software engineer m f x      2
# 364              full stack developer javascript m f d      2
# 365                       senior backend engineer java      2
# 366  software developer backend cloud services pyth...      2
# 367        senior mobile developer ios m w d in berlin      2
# 368                     senior software engineer m f d      2
# 369         enterprise search senior frontend engineer      2
# 370                   senior machine learning engineer      2
# 371  software engineer kotlin react azeti mes platform      2
# 372                     digital product designer m f d      2
# 373              software engineer digital advertising      2
# 374                  python developer mid senior level      2
# 375  senior software engineer applied machine learn...      2
# 376                              product manager m w d      2
# 377              ios developer swift rxswift freelance      2
# 378                            software engineer f x m      2
# 379       full stack developer node js react aws m f d      2
# 380                      software engineer czech nlu c      2
# 381                     software engineer c pix4dmatic      2
# 382        senior ios engineer client foundation f m d      2
# 383                                java engineer f m d      2
# 384                                    devops engineer      2
# 385                           fullstack engineer m f d      2
# 386                                ios developer f m x      2
# 387                         senior ios developer d f m      2
# 388                                      net developer      2
# 389      senior software engineer in test adtech f m d      2
# 390                senior software engineer ruby f m d      2
# 391                          senior frontend developer      2
# 392                           frontend developer m f d      2
# 393                     frontend developer all genders      2
# 394        ios android entwickler w m d at ampada gmbh      2
# 395       senior software engineer python adtech f m d      2
# 396  talent acquisition partner recruiter emea all ...      2
# 397       app developer android nearshore remote m f d      2
# 398             engineering manager mobile all genders      2
# 399  application innovation specialist specialist s...      2
# 400                                       ui developer      2
# 401  senior software development engineer amazon mu...      2
# 402                 senior react native engineer f m x      2
# 403                    software engineer node js f m d      2
# 404                                product lead retail      2
# 405                     staff fullstack engineer m f d      2
# 406                    embedded software test engineer      2
# 407  senior android mobile engineer java kotlin qui...      2
# 408  senior software development engineer embedded ...      2
# 409                       technical support specialist      2
# 410                          engineering manager f m d      2
# 411  senior expert engineer software architecture f...      2
# 412  frontend engineer typescript javascript react ...      2
# 413            senior front end engineer product m f d      2
# 414       software development engineer in test remote      2
# 415                                ios developer m w d      2
# 416                            software engineer m w d      2
# 417  lead staff software engineer ios bangkok based...      2
# 418      customer success account management team lead      2
# 419              full stack developer mckinsey digital      2
# 420                       android java developer f m d      2
# 421         software development engineer aws identity      2
# 422                    mobile manual qa engineer m f d      2
# 423                              backend engineer ruby      2
# 424                business analyst client infra f m d      2
# 425             software engineer m w d im digital lab      2
# 426  senior full stack software developer engineer ...      2
# 427  customer success account manager enterprise ac...      2
# 428                             android engineer m f x      2
# 429              senior ios developer courier app team      2
# 430                         senior ios developer x f m      2
# 431                         junior full stack engineer      2
# 432                                   network engineer      2
# 433                         full stack developer m f x      2
# 434                         principal product mgr tech      2
# 435                          product designer traveler      2
# 436            sr lead software engineer flutter m f x      2
# 437                     full stack engineer stripe tax      2
# 438  senior frontend developer m w d experience des...      2
# 439                    head of engineering mobile apps      2
# 440          javascript frontend developer sdui app gn      2
# 441           senior frontend software engineer growth      2
# 442                                senior engineer ios      2
# 443                     mobile developer android w m d      2
# 444                   senior product marketing manager      2
# 445       front end web developer vue typescript f m d      2
# 446                senior react native developer f m d      2
# 447               staff engineer mobile platform f m d      2
# 448                       frontend engineer web mobile      2
# 449  senior mobile engineer flutter f m d berlin re...      2
# 450                                 ios engineer m f d      2
# 451  javascript developer m f x startup tackling cl...      2
# 452  test engineer for mobile apps testing all gend...      2
# 453            senior backend engineer enterprise java      2
# 454  senior frontend engineer typescript javascript...      2
# 455  speech platform engineer android all genders i...      2
# 456  working student m f x advertising products mob...      2
# 457                    senior backend engineer node js      2
# 458                      java software developer f m d      2
# 459           senior android developer m f d bm21_1670      2
# 460                              product manager human      2
# 461                       partner integration engineer      2
# 462                                        qa engineer      2
# 463                 software engineer ii ad tech m f x      2
# 464  senior fullstack engineer php react for produc...      2
# 465                                ios developer m f d      2
# 466                                   backend engineer      2
# 467                            head of game production      2
# 468                         solutions engineer germany      2
# 469         freelance react native developer 12 months      2
# 470                                     game developer      2
# 471                          full stack engineer f m x      2
# 472                          fullstack developer d f m      2
# 473  senior software engineer in test vendor portal...      2
# 474            senior frontend developer storage w m d      2
# 475                          product security engineer      2
# 476            junior android engineer m f x in berlin      2
# 477  software engineer frontend developer m f d in ...      2
# 478               senior ios developer m f d bm21_1010      2
# 479  senior software engineer edge routing and grap...      2
# 480   senior software development engineer ops tech it      2
# 481  senior software engineer golang order optimisa...      2
# 482      software developer anwendungsentwickler m w d      2
# 483                      senior software developer ios      2
# 484                            android developer f m d      1
# 485            senior product manager web photo editor      1
# 486                        accounting tax lead germany      1
# 487       architect data collection provisioning m f d      1
# 488                                    head of product      1
# 489                  senior product designer s banking      1
# 490  digital manufacturing operations intelligent a...      1
# 491                                        seo manager      1
# 492                          software quality engineer      1
# 493  mobile developer c c qt talent for creative wr...      1
# 494             chief technology officer m w d ecomove      1
# 495            senior frontend software engineer m f d      1
# 496                                    head of content      1
# 497  senior frontend engineer design engineering f m d      1
# 498                                frontend entwickler      1
# 499   senior fullstack developer all genders full time      1
# 500             senior kotlin android entwickler m w d      1
# 501                              user acquisition lead      1
# 502                    senior research lead manager eu      1
# 503                senior software engineer full stack      1
# 504                             backend engineer m f d      1
# 505       engineering team lead financial technologies      1
# 506       junior growth consultant retention crm m f d      1
# 507             sales development representative m f d      1
# 508                             restaurant menu editor      1
# 509               senior backend developer all genders      1
# 510  senior full stack engineer java reactjs for as...      1
# 511            project manager f2p mobile games berlin      1
# 512                              ruby backend engineer      1
# 513              product owner internal communications      1
# 514       talent partner tech global software scale up      1
# 515                             senior react developer      1
# 516  sw engineer car navigation systems typescript ...      1
# 517  life science projekt programm business develop...      1
# 518                                     java developer      1
# 519                       sales account executive apac      1
# 520                 sr software engineer in test m f x      1
# 521                                 solutions engineer      1
# 522  senior manager bi analytics mobile free2play g...      1
# 523                        competence specialist m f d      1
# 524                  senior product owner mobile f m x      1
# 525                                 lead game designer      1
# 526  senior devops engineer developer experience m f d      1
# 527  senior software engineer real time microservic...      1
# 528            backend engineer logistics optimization      1
# 529                                media analyst m f d      1
# 530  senior legal counsel business partner legal co...      1
# 531             campaign and template specialist m f d      1
# 532     senior technical crm manager for app messaging      1
# 533                      senior solution engineer emea      1
# 534          frontend developer office or remote m f x      1
# 535  senior fullstack engineer javascript node js r...      1
# 536                          senior ios engineer m f x      1
# 537          product manager qa scrum specialist m f d      1
# 538   senior mobile engineer ionic f m d remote berlin      1
# 539  junior mobile developer m w d cross plattform web      1
# 540                     lead technical product manager      1
# 541                       senior crm manager fabletics      1
# 542               senior product manager image quality      1
# 543              senior customer success manager m f d      1
# 544    senior staff staff engineer consumer experience      1
# 545  senior software engineer senior php developer ...      1
# 546                            head of finance germany      1
# 547                            senior elixir developer      1
# 548                                  senior bi analyst      1
# 549                    eu senior crm manager fabletics      1
# 550                                product design lead      1
# 551                                  junior qa analyst      1
# 552                         engineering manager remote      1
# 553   spokesperson content specialist hr finance m f d      1
# 554                        qa engineer m f d bm21_1561      1
# 555                senior native react developer m w d      1
# 556                       head of government relations      1
# 557  frontend react engineer m f x in berlin de remote      1
# 558                      ux designer automotive design      1
# 559                            solutions engineer emea      1
# 560  development quality specialist operating syste...      1
# 561                                        ai engineer      1
# 562                  junior product owner mobile f m x      1
# 563                           javascript lead engineer      1
# 564           backend engineer multiple openings f m d      1
# 565              senior growth consultant pm crm m f d      1
# 566              digital product owner fleet b2b m f d      1
# 567         senior ios developer all genders full time      1
# 568   chromium software engineer berlin cologne remote      1
# 569                   data governance specialist m f d      1
# 570         visual product designer design engineering      1
# 571  senior application security engineer bangkok b...      1
# 572              growth consultant retention crm m f d      1
# 573                              head of b2b marketing      1
# 574                                    lead programmer      1
# 575                    android developer with ar focus      1
# 576  software developer identity and access managem...      1
# 577  head of product management solution train digi...      1
# 578                                           producer      1
# 579  c developer for interactive 3d applications f m d      1
# 580  staff data engineer big loop and advanced syst...      1
# 581  solution architect digital hr services data st...      1
# 582               director of product management m f d      1
# 583  staff software engineer gpu computing machine ...      1
# 584  young professional web frontend developer all ...      1
# 585                      technical consultant presales      1
# 586                      fullstack web developer m f d      1
# 587                     senior backend engineer nodejs      1
# 588  software developer backend for mobility servic...      1
# 589                         iam specialist regtech iam      1
# 590                      people operations coordinator      1
# 591                                 head of technology      1
# 592            senior backend engineer zalando loyalty      1
# 593                          senior fullstack engineer      1
# 594                               senior product owner      1
# 595      senior web developer typescript angular f m x      1
# 596  senior development engineer advanced driver as...      1
# 597          senior enterprise account executive m f d      1
# 598         technical account manager russian speaking      1
# 599   financial planning analysis fp a manager germany      1
# 600                        senior java developer m f d      1
# 601                       backend engineer marketplace      1
# 602                    data protection counsel product      1
# 603                             voodoo unity developer      1
# 604  executive product manager next generation sw p...      1
# 605                   freelance qa analyst all genders      1
# 606  engineering student and graduate program remot...      1
# 607                     scala software engineers m f d      1
# 608   lead talent acquisition manager commercial m f d      1
# 609           process product compliance manager m f d      1
# 610   senior backend engineer data infrastructure java      1
# 611                           senior crm manager m f d      1
# 612                  senior product designer consumers      1
# 613                                  platform engineer      1
# 614                   lead product designer s shopping      1
# 615  software developer cloud live data services au...      1
# 616                    technical account manager m f d      1
# 617                             product designer m f d      1
# 618                                 analytics engineer      1
# 619                              full stack developers      1
# 620                              php software engineer      1
# 621                    product manager live operations      1
# 622                                data engineer m f d      1
# 623               senior javascript engineer web teams      1
# 624                      senior product designer m w x      1
# 625                  freelance android kotlin contract      1
# 626  software engineer ii catalog foundations expan...      1
# 627  customer success account manager for developer...      1
# 628                   engineering manager atfarm f m d      1
# 629              senior qa automation engineer backend      1
# 630                     senior frontend engineer f m x      1
# 631                                solutions architect      1
# 632               senior level designer world building      1
# 633                   softwareentwickler m w d angular      1
# 634         development team lead hosting integrations      1
# 635          stack software engineer ci infrastructure      1
# 636                                   product designer      1
# 637                             engineering lead f m d      1
# 638                           product manager terminal      1
# 639                                engineering manager      1
# 640                          product marketing manager      1
# 641       open source office operational manager m f d      1
# 642                                  qa engineer f m d      1
# 643                                    program manager      1
# 644                               app entwickler m w d      1
# 645                      customer success manager dach      1
# 646                             product designer m f x      1
# 647                      senior product designer d f m      1
# 648  senior solution architect pre sales central eu...      1
# 649                     community manager m f d mobile      1
# 650  quality assurance qa engineer mobile django au...      1
# 651                          restaurant menu associate      1
# 652                              head of product f m d      1
# 653                         qa engineer at felmo m f d      1
# 654          global salesforce administrator team lead      1
# 655              quality assurance automation engineer      1
# 656                                seo project manager      1
# 657                   software security engineer f m x      1
# 658          software engineer java team postman m f x      1
# 659                                     ux ui designer      1
# 660                     senior product manager web b2b      1
# 661                      expert backend engineer w m x      1
# 662                        qa engineer working student      1
# 663                                      game director      1
# 664                       senior react developer x f m      1
# 665  senior software development manager amazon mus...      1
# 666                                    account manager      1
# 667        engineering manager mobile team all genders      1
# 668                      backend integration developer      1
# 669                           senior flutter developer      1
# 670                          engineering manager w d m      1
# 671                      engineering manager ios f d m      1
# 672          full stack developer marketing tech m f d      1
# 673                         lead ios engineering m f d      1
# 674         lead legal counsel m a corporate law m f d      1
# 675                   quality assurance engineer m f d      1
# 676                customer service agent france m f d      1
# 677                            vp of engineering m w d      1
# 678      full stack developer berlin 18 month contract      1
# 679                              visual designer f m d      1
# 680     alexa skills kit content test specialist m f d      1
# 681                 engineering manager apps lifecycle      1
# 682   spokesperson content specialist technology m f d      1
# 683                           scrum master all genders      1
# 684           performance automation qa engineer m w d      1
# 685                            embedded engineer f m d      1
# 686                         senior front end developer      1
# 687  flutter app entwickler app developer applicati...      1
# 688                            system support engineer      1
# 689                      junior backend engineer m f d      1
# 690                              tech lead web acquire      1
# 691                  b2b performance marketing manager      1
# 692      senior backend software engineer python m f d      1
# 693     senior software quality engineer cards wallets      1
# 694                               front end entwickler      1
# 695                                    product analyst      1
# 696                       technical artist new product      1
# 697                senior react native developer m w d      1
# 698                           customer success manager      1
# 699                                 android entwickler      1
# 700              senior mobile engineer m w d at upday      1
# 701         technical account manager turkish speaking      1
# 702           senior software engineer front end m f d      1
# 703             senior product manager api layer m f d      1
# 704                   senior platform backend engineer      1
# 705  product manager m f d vc backed clean tech ven...      1
# 706                     senior mobile tech crm manager      1
# 707             fullstack engineer fokus node js m w d      1
# 708         product owner mobile online services m f d      1
# 709                               full stack developer      1
# 710  senior software engineer android rider transmi...      1
# 711             lead ux ui designer new mobile shooter      1
# 712                              product manager f m d      1
# 713               senior product designer mobile m f d      1
# 714                c embedded software developer m f d      1
# 715   regional mobile crm manager m f d zalando lounge      1
# 716                         lead engineer mobile m f d      1
# 717    product manager experimentation logistics f m d      1
# 718                       snr ux designer fashion tech      1
# 719  software development manager shopping performa...      1
# 720            senior softwareentwickler android w m d      1
# 721        senior manager performance marketing berlin      1
# 722                               social media manager      1
# 723    customer success account manager for developers      1
# 724  senior fullstack engineer javascript typescrip...      1
# 725          sr director of infrastructure engineering      1
# 726                           front end engineer m f d      1
# 727       senior mobile engineer personalization m f d      1
# 728                            java back end developer      1
# 729                            software engineer m f d      1
# 730                         lead product manager m f x      1
# 731                     lead game engineer unannounced      1
# 732                                  reactjs developer      1
# 733                 product owner ux ui travel germany      1
# 734         senior fullstack engineer react typescript      1
# 735                            senior tech coordinator      1
# 736  test manager software and system engineering m...      1
# 737  digital experience manager products services m...      1
# 738                      senior product designer m f d      1
# 739  engineering manager customer conversion mobile...      1
# 740                              game economy designer      1
# 741                       principal software architect      1
# 742                        inhouse legal counsel m f d      1
# 743              aso consultant mobile marketing m f d      1
# 744      jump start in die app entwicklung ios android      1
# 745                              senior aso specialist      1
# 746                   director of platform engineering      1
# 747  architect m f d requirements and functions man...      1
# 748                business development representative      1
# 749         working student m f d software development      1
# 750  product manager zendesk sdks android ios unity...      1
# 751  lead software architect safe ai development m f d      1
# 752  head of information security and compliance le...      1
# 753  senior software engineer catalog foundations e...      1
# 754                      senior product designer m f x      1
# 755                            programmatic specialist      1
# 756             junior online marketing manager berlin      1
# 757                                  security engineer      1
# 758                senior product owner messages m f x      1
# 759   senior product designer integrations all genders      1
# 760           performance marketing specialist manager      1
# 761                              product manager x f m      1
# 762                             senior consultant dipa      1
# 763                          mobile qa manual engineer      1
# 764                       senior product owner m f div      1
# 765                       cto head of technology m f d      1
# 766  principal kernel software developer for window...      1
# 767      analyst business development russian speaking      1
# 768  product manager mobile app retention kyiv base...      1
# 769                         senior product owner f m d      1
# 770     senior product owner messages berlin b2b titan      1
# 771                               product designer b2b      1
# 772                     front end developer mid senior      1
# 773                                     head of design      1
# 774  projekt programm business development sr manag...      1
# 775                             product sales engineer      1
# 776                     marketing manager partnerships      1
# 777                                  qa engineer m f d      1
# 778                     retention crm consultant m f d      1
# 779               fullstack engineer media sites m w d      1
# 780                         senior full stack engineer      1
# 781  senior qa engineer d f m search routing berlin...      1
# 782                front end developer m f d bm21_1141      1
# 783                 senior react native engineer m f d      1
# 784                     senior software engineer m w d      1
# 785                       software engineer 100 remote      1
# 786                     head of user interface android      1
# 787                         director of product motors      1
# 788                               talent sourcer m f d      1
# 789                               senior data engineer      1
# 790                               build engineer f m d      1
# 791                                         ua manager      1
# 792            senior fullstack engineer backend f x m      1
# 793                                      head of video      1
# 794                 mitarbeiter kundenservice teilzeit      1
# 795                 head of base platform stacks m f d      1
# 796      freelance java kotlin developer berlin remote      1
# 797                        inside sales representative      1
# 798                            react native developers      1
# 799              senior golang software engineer m f d      1
# 800                    support associate kundenservice      1
# 801                             paid social specialist      1
# 802  sw engineer car navigation systems m f x types...      1
# 803                    senior technical art consultant      1
# 804                             qa analyst all genders      1
# 805                       database engineer postgresql      1
# 806                  tech lead search experience m f d      1
# 807                          senior data analyst m f d      1
# 808                                    senior producer      1
# 809                    account manager german speaking      1
# 810         senior software engineer java search f m d      1
# 811  specialist project management focus data sales...      1
# 812                          full stack engineer m f d      1
# 813  senior mobile developer m w d cross plattform web      1
# 814                                  crm manager m f d      1
# 815     product owner electric mobility services m f d      1
# 816                                  lead engineer ios      1
# 817   lead frontend developer react at crypto start up      1
# 818                           backend engineer acquire      1
# 819                           android developer berlin      1
# 820  java backend developer mobile game m f d at me...      1
# 821                          hr business partner m f d      1
# 822  product manager logistics ios android rider ap...      1
# 823       senior ux ui concept design specialist m f d      1
# 824              data compliance governance specialist      1
# 825                      senior backend engineer d f m      1
# 826                     director of product ecosystems      1
# 827    senior software engineer embedded systems m f d      1
# 828  associate general counsel data protection inst...      1
# 829          talent acquisition partner product design      1
# 830                                game level designer      1
# 831  mobile entwickler android ios reactnative m w ...      1
# 832                             backend engineer cards      1
# 833  software architect focus on functional and pla...      1
# 834                  quality automation engineer m f x      1
# 835                                         sr sde aws      1
# 836                          senior unity 3d developer      1
# 837  junior full stack entwickler m w d inkl remote...      1
# 838  senior app marketing manager engagement growth...      1
# 839           head of product design restaurants f m d      1
# 840                                  qa engineer d f m      1
# 841                  people operations associate w m d      1
# 842                           unreal engine programmer      1
# 843          technical account manager german speaking      1
# 844           senior fullstack engineer node react aws      1
# 845                          software engineer go lang      1
# 846                    engineering manager all genders      1
# 847            senior frontend engineer react js m w d      1
# 848  sw engineer car navigation systems typescript ...      1
# 849          senior technical trainer evangelist m f d      1
# 850                         app store business manager      1
# 851                    teamlead m f x game development      1
# 852                  senior javascript engineer editor      1
# 853          senior backend engineer nodejs typescript      1
# 854                 softwareentwickler ios swift w m d      1
# 855  senior software engineer m f x payments engine...      1
# 856               embedded software engineer iot m f d      1
# 857                       vice president finance m f d      1
# 858                talent acquisition specialist m f x      1
# 859                 senior frontend engineer vue f m d      1
# 860               senior mobile product designer m f d      1
# 861  client solutions manager apps performance mark...      1
# 862                           sr devops engineer m f x      1
# 863                     game artist hyper casual games      1
# 864                                    visual designer      1
# 865                         backend engineer bank core      1
# 866                   senior backend software engineer      1
# 867                 senior product manager a b testing      1
# 868                           senior marketing analyst      1
# 869  lead iot technology architect data platform m f d      1
# 870      product owner web mobile team m f d bm21_1532      1
# 871               senior frontend engineer all genders      1
# 872     senior cloud analytics platform engineer m f d      1
# 873      fullstack engineer search engine optimisation      1
# 874                 full stack software engineer f m x      1
# 875                         technical program director      1
# 876            devops engineer multiple openings f m d      1
# 877   project manager women s health medical expertise      1
# 878  senior software engineer traffic pricing platf...      1
# 879                  product owner digital advertising      1
# 880            senior software engineer back end m f d      1
# 881                    lead full stack developer m f x      1
# 882     talent acquisition partner it series c fintech      1
# 883                                   copywriter w m d      1
# 884                                gameplay programmer      1
# 885                                 data analyst m f d      1
# 886                        product manager traveler ux      1
# 887  senior backend engineer python django shore po...      1
# 888               product designer design system f m d      1
# 889    solution train engineer software platform m f d      1
# 890  full stack entwickler w m d für webanwendungen...      1
# 891                            solutions engineer dach      1
# 892                         user experience researcher      1
# 893  senior software developer identity and access ...      1
# 894        software engineer in machine learning m f d      1
# 895                       senior product manager f m d      1
# 896                          senior product manager gn      1
# 897      sr software development engineer aws identity      1
# 898  backend engineer rider acquisition m f d hambu...      1
# 899                            country manager germany      1
# 900          full stack engineer playbooks team remote      1
# 901          sap abap entwickler m w d mobile lösungen      1
# 902  senior devops engineer analytics cloud platfor...      1
# 903                          ios engineer m f d remote      1
# 904         lead full stack developer berlin or remote      1
# 905        senior full stack engineer berlin or remote      1
# 906  system development engineer adas automated dri...      1
# 907  enterprise solution architect mobility service...      1
# 908                  graduate program business of tech      1
# 909  software development manager amazon music ml p...      1
# 910  associate general counsel data protection product      1
# 911  senior talent acquisition manager tech product...      1
# 912         business development representative remote      1
# 913  devops engineer for mobile apps all genders in...      1
# 914     senior devops engineer multiple openings f m d      1
# 915                    backend software engineer f m x      1
# 916                             product lead logistics      1
# 917                        senior cloud engineer m f d      1
# 918                           frontend developer f m x      1
# 919  product marketing manager m f d predictive mai...      1
# 920               senior mobile engineer flutter f m d      1
# 921             full stack engineer growth team remote      1
# 922         engineering manager f m x partially remote      1
# 923                  senior full stack developer m f x      1
# 924        senior account executive platform solutions      1
# 925                         product lead supply demand      1
# 926           senior java developer chapter lead m f d      1
# 927         software engineer f m d digital production      1
# 928                backend engineer remote or relocate      1
# 929              market development specialist germany      1
# 930                      community manager mobile emea      1
# 931           technical team lead full stack developer      1
# 932                                 unity 3d developer      1
# 933                       senior backend engineer opsx      1
# 934                director of engineering all genders      1
# 935           senior node js typescript engineer x f m      1
# 936            senior software engineer m f d bm21_998      1
# 937   software cloud engineer digital assistants m f d      1
# 938  integration test manager digital lifecycle man...      1
# 939                       lead software engineer m f d      1
# 940  software entwickler programmierer developer m ...      1
# 941  senior product manager logistics ios android r...      1
# 942  experience design consultant ux ui all levels ...      1
# 943            senior product manager web video editor      1
# 944                      head of hr operations germany      1
# 945             senior react developer x f m freelance      1
# 946                               operations associate      1
# 947                      senior product designer f m d      1
# 948   pmt architect digital lifecycle management m f d      1
# 949                                      analyst fraud      1
# 950             senior product designer hardware tribe      1
# 951                       growth marketing manager b2b      1
# 952  java backend developer mobile game fixed posit...      1
# 953                               qa engineer hardware      1
# 954                      lead engineer consumer search      1
# 955  senior backend engineer java kotlin for order ...      1
# 956                      sr lead visual designer m f x      1

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="position", y="count", data=top_positions.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Positions this week

# %%
top_positions = pd.DataFrame(df_within_1_week['position'].value_counts()).reset_index()
top_positions.columns = ['position', 'count']
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="position", y="count", data=top_positions.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Positions This Month

# %%
top_positions = pd.DataFrame(df_within_1_month['position'].value_counts()).reset_index()
top_positions.columns = ['position', 'count']
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="position", y="count", data=top_positions.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Positions For Junior/Entry Level Roles

# %%
top_positions = pd.DataFrame(junior_level_df['position'].value_counts()).reset_index()
top_positions.columns = ['position', 'count']
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="position", y="count", data=top_positions.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
top_skills = []
for row_content in df['top competitive skills']:
    row_content = row_content.replace('/', ' ').replace('-', ' ')
    if len(row_content) > 3:
        try:
            for item in re.findall('\w+ \w+ \w+', row_content):  # Skills with 3 words
                top_skills.append(item)
            for item in re.findall('\w+ \w+', row_content):  # Skills with 2 words
                top_skills.append(item)
            for item in re.findall('\'\w+\'', row_content):  # Skill with single word
                top_skills.append(re.findall('\w+', item)[0])
        except TypeError:
            pass

top_skills = [item.lower() for item in top_skills]

# %%
# len(top_skills)
# ios_skill = []
# for item in top_skills:
#     if 'ios' in item:
#         ios_skill.append(item)
# ios_skill

# %%
def clean_skill(x):
    if ('cascading' in x) or ('css' in x):
        return 'css'
    elif 'ios' in x:
        return 'ios'
    elif 'android' in x:
        return 'android'
    elif 'sql' in x:
        return'sql'
    elif 'object oriented' in x:
        return 'object oriented programing'
    elif 'back end' in x:
        return 'back end'
    elif 'front end' in x:
        return 'front end'
    elif ('full stack' in x) or ('fullstack' in x):
        return 'full stack'
    elif 'user interface' in x:
        return 'user interface design'
    elif 'php' in x:
        return 'php'
    elif 'model view' in x:
        return 'model view'
    elif 'programming' in x:
        return 'programming language'
    elif 'azure' in x:
        return 'azure'
    elif 'web design' in x:
        return 'web design'
    elif ('software project' in x) or ('project management' in x):
        return 'project management'
    elif 'java database' in x:
        return 'java database'
    elif 'sap' in x:
        return 'sap'
    elif 'apis' in x:
        return 'apis'
    else:
        return x

# %%
top_skills = pd.Series(top_skills).apply(clean_skill)

# %% [markdown]
# # Top Skills of the candidates who applied for the job

# %%
x = pd.DataFrame(pd.DataFrame(top_skills).value_counts())
x.columns = ['count']
x = x.reset_index()
x.columns = ['skill', 'count']
x = x[x['count']> 7]
x
# Out:
#                                 skill  count
# 0                                 sql   1524
# 1                             android   1070
# 2                          javascript    762
# 3                                 css    740
# 4                programming language    729
# 5                          model view    534
# 6          object oriented programing    522
# 7                                java    500
# 8                                 ios    491
# 9                                 git    375
# 10                                php    338
# 11                               html    310
# 12                             kotlin    286
# 13               software development    245
# 14                    web development    244
# 15                              xcode    216
# 16                               json    196
# 17                               jira    164
# 18                        objective c    157
# 19                           back end    154
# 20                 project management    143
# 21                            english    139
# 22                mobile applications    136
# 23                agile methodologies    129
# 24                 mobile application    123
# 25     mobile application development    113
# 26                           firebase    112
# 27                            mongodb    110
# 28                    data structures    108
# 29              user interface design    106
# 30                    microsoft excel    105
# 31                              html5    101
# 32                   machine learning    100
# 33                     microsoft word     99
# 34                         leadership     97
# 35                             matlab     91
# 36                       web services     91
# 37                             jquery     91
# 38                          core data     88
# 39                          databases     87
# 40                             rxjava     83
# 41                              scrum     82
# 42                   microsoft office     82
# 43                    public speaking     80
# 44                            jenkins     78
# 45                            eclipse     78
# 46                    design patterns     77
# 47                         management     72
# 48                              linux     70
# 49               microsoft powerpoint     68
# 50                        test driven     66
# 51            test driven development     66
# 52                                xml     65
# 53                          core java     63
# 54                         full stack     62
# 55                        cocoa touch     62
# 56                         life cycle     61
# 57                             github     60
# 58                              unity     60
# 59                    docker products     58
# 60          software development life     56
# 61                          bootstrap     55
# 62     iphone application development     54
# 63                 iphone application     54
# 64                         algorithms     54
# 65                        spring boot     53
# 66                          hibernate     53
# 67                         web design     52
# 68                      java database     52
# 69                       unit testing     50
# 70                    team leadership     49
# 71                      net framework     48
# 72                               apis     48
# 73                              maven     48
# 74                           retrofit     46
# 75                             django     46
# 76                    adobe photoshop     45
# 77                       react native     45
# 78                      data analysis     43
# 79                            angular     43
# 80                   computer science     42
# 81                          marketing     42
# 82                               ajax     42
# 83                            flutter     40
# 84                amazon web services     40
# 85                         amazon web     40
# 86                         e commerce     39
# 87                  adobe illustrator     39
# 88                    test automation     38
# 89                               sass     38
# 90                            windows     38
# 91                           teamwork     38
# 92                           research     36
# 93                restful webservices     35
# 94                   spring framework     35
# 95                    oracle database     34
# 96                          angularjs     34
# 97                    user experience     31
# 98                      communication     31
# 99                    problem solving     30
# 100                        typescript     29
# 101                   software design     29
# 102                    manual testing     29
# 103                         front end     28
# 104                        jakarta ee     28
# 105                  web applications     28
# 106                      social media     26
# 107                 business strategy     25
# 108                            gradle     25
# 109                          training     24
# 110                  customer service     24
# 111                             uikit     24
# 112                            devops     24
# 113                          fastlane     23
# 114                      visual basic     23
# 115                         cocoapods     23
# 116                             junit     23
# 117                          servlets     22
# 118                strategic planning     21
# 119                           swiftui     21
# 120              business development     20
# 121                           net mvc     20
# 122                     microservices     20
# 123                             azure     20
# 124                           graphql     19
# 125                     agile project     19
# 126   representational state transfer     19
# 127                     visual studio     19
# 128            representational state     19
# 129                   team management     19
# 130                 augmented reality     19
# 131              internet information     18
# 132                   shell scripting     18
# 133     internet information services     18
# 134                        networking     18
# 135                   design thinking     18
# 136                   market research     18
# 137                   time management     18
# 138                              dart     18
# 139                  google analytics     18
# 140                functional testing     17
# 141                           arduino     17
# 142                 digital marketing     17
# 143                           testing     16
# 144             google cloud platform     16
# 145                       photography     16
# 146             requirements analysis     16
# 147                        ecmascript     16
# 148                marketing strategy     16
# 149                      google cloud     16
# 150                          strategy     16
# 151                product management     15
# 152                  game development     15
# 153                            javase     15
# 154                          selenium     14
# 155                            tomcat     14
# 156                             latex     14
# 157            social media marketing     14
# 158                          net core     14
# 159                regression testing     14
# 160                   computer vision     13
# 161                        test cases     13
# 162                        kubernetes     13
# 163             operations management     13
# 164                  javaserver pages     13
# 165                         bitbucket     13
# 166                        embedded c     13
# 167                  embedded systems     13
# 168                    mobile testing     13
# 169                 analytical skills     13
# 170                   test management     12
# 171                       google maps     12
# 172          application architecture     12
# 173                               sap     12
# 174          software design patterns     11
# 175           solid design principles     11
# 176  windows communication foundation     11
# 177             windows communication     11
# 178                           tableau     11
# 179                   adobe lightroom     11
# 180                       advertising     11
# 181                    graphic design     11
# 182           application development     11
# 183            continuous integration     11
# 184                             arkit     11
# 185                         terraform     11
# 186                      solid design     11
# 187                     test planning     11
# 188                  software testing     11
# 189                          net ajax     11
# 190                           finance     11
# 191                            appium     11
# 192                    multithreading     11
# 193         mobile application design     10
# 194                     intellij idea     10
# 195                      data science     10
# 196                     deep learning     10
# 197         test automation framework     10
# 198                               a b     10
# 199                       a b testing     10
# 200                       wireframing     10
# 201                         app store     10
# 202                   api development     10
# 203              unix shell scripting     10
# 204                        unix shell     10
# 205                  creative writing      9
# 206               organization skills      9
# 207                              vhdl      9
# 208                        spring mvc      9
# 209                       codeigniter      9
# 210                     unreal engine      9
# 211                             redis      9
# 212                 operating systems      9
# 213                         black box      9
# 214                 black box testing      9
# 215                            testng      9
# 216                 career management      8
# 217                  sales management      8
# 218                            drupal      8
# 219             solution architecture      8
# 220                             scala      8
# 221                          big data      8
# 222                               sdk      8
# 223            electrical engineering      8
# 224                selenium webdriver      8
# 225                   spring security      8
# 226                 product marketing      8
# 227                        sketch app      8
# 228              relational databases      8
# 229                       engineering      8
# 230                 memory management      8
# 231           waterfall methodologies      8
# 232                          netbeans      8
# 233                 kotlin coroutines      8
# 234                        google ads      8
# 235                 agile environment      8
# 236                        google api      8

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=x.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
skills = x['skill']
skills = list(skills.values)

# %%
other_skills = ['swift', 'xamarin', 'appcelerator', 'cordova', 'phonegap', 'buildfire', 'ionic', 'android sdk', 
               'android studio', 'angular', 'objective-c', 'dart', 'lua', 'rust' ,'action script' ,
               'mobile design']

# %%
skills = skills + other_skills

# %% [markdown]
# # Top Skills Asked by the employers

# %%
import re

# %%
skills_count = {}
for skill in skills:
    counter = 0
    for description in df['descriptions']:
        if (skill == 'ci') and len(re.findall('ci ', description))>0:
            counter+=1
        elif skill in description:
            counter += 1
    skills_count[skill] = counter

# %%
skills_count = pd.DataFrame(dict(sorted(skills_count.items(), key=lambda x: x[1], reverse=True)).items())
skills_count.columns = ['skill', 'count']

# %%
skills_count
# Out:
#                                 skill  count
# 0                               unity   1501
# 1                                 ios   1422
# 2                             android   1383
# 3                                 git   1325
# 4                         engineering   1318
# 5                             english   1277
# 6                                java   1235
# 7                             testing   1230
# 8                                 a b   1195
# 9                       communication   1167
# 10                             kotlin    958
# 11                         management    799
# 12                              swift    717
# 13               software development    694
# 14                               apis    652
# 15                              scala    626
# 16                   computer science    588
# 17                    user experience    545
# 18                 mobile application    515
# 19                         javascript    494
# 20                           training    455
# 21                           research    449
# 22                                sdk    441
# 23                               rust    430
# 24                mobile applications    429
# 25                         leadership    426
# 26                         typescript    377
# 27                                lua    329
# 28                        objective c    317
# 29                    problem solving    316
# 30                    design patterns    313
# 31                                sql    305
# 32                           strategy    302
# 33                          front end    301
# 34                         kubernetes    281
# 35                         full stack    272
# 36                       react native    272
# 37                              scrum    268
# 38               programming language    267
# 39                             github    265
# 40                            graphql    243
# 41                          databases    219
# 42                   machine learning    217
# 43                          marketing    216
# 44                         life cycle    212
# 45           application architecture    201
# 46                         algorithms    199
# 47                               html    194
# 48                                css    192
# 49                             rxjava    191
# 50                        advertising    189
# 51                    data structures    176
# 52             continuous integration    175
# 53                            angular    174
# 54                       unit testing    172
# 55                            windows    171
# 56                        android sdk    166
# 57          software development life    162
# 58                  agile environment    154
# 59                 product management    149
# 60            application development    147
# 61                      microservices    146
# 62                        a b testing    142
# 63                             devops    140
# 64                               jira    139
# 65                           back end    137
# 66                            jenkins    130
# 67                           big data    129
# 68                              linux    127
# 69                           fastlane    123
# 70                         e commerce    122
# 71                    software design    122
# 72                        spring boot    111
# 73                               json    110
# 74                           teamwork    110
# 75                          app store    108
# 76                            flutter    106
# 77                              uikit    104
# 78                   web applications    103
# 79                              redis    100
# 80                          terraform     98
# 81                                sap     94
# 82                              azure     92
# 83                              xcode     90
# 84                        test driven     90
# 85                              junit     88
# 86                  kotlin coroutines     87
# 87            test driven development     86
# 88                         networking     85
# 89                             gradle     84
# 90                    test automation     76
# 91                           firebase     75
# 92                   customer service     73
# 93                            swiftui     72
# 94                       web services     71
# 95                             django     68
# 96                    web development     67
# 97                     android studio     67
# 98                            mongodb     64
# 99                               sass     64
# 100                      data science     63
# 101                           finance     62
# 102                     data analysis     60
# 103                      google cloud     59
# 104              relational databases     56
# 105                          retrofit     53
# 106                        test cases     52
# 107                               php     50
# 108            electrical engineering     50
# 109                         cocoapods     48
# 110                project management     44
# 111               agile methodologies     44
# 112                      social media     44
# 113                           xamarin     42
# 114                   computer vision     40
# 115                       cocoa touch     38
# 116                             html5     36
# 117                          selenium     35
# 118                     mobile design     35
# 119                         core data     34
# 120                        amazon web     32
# 121             google cloud platform     32
# 122               amazon web services     29
# 123                 analytical skills     28
# 124                               xml     27
# 125                            appium     27
# 126                  spring framework     25
# 127                   market research     25
# 128                  embedded systems     25
# 129    mobile application development     24
# 130              business development     23
# 131                         angularjs     22
# 132                 digital marketing     22
# 133                              dart     21
# 134                       photography     20
# 135                         bootstrap     19
# 136                     visual studio     19
# 137                    multithreading     19
# 138                 product marketing     19
# 139                 augmented reality     18
# 140                   shell scripting     18
# 141                  game development     18
# 142                           cordova     18
# 143                   design thinking     16
# 144                 business strategy     15
# 145                 memory management     15
# 146                   time management     14
# 147                           tableau     14
# 148                 operating systems     14
# 149                        model view     12
# 150                         core java     12
# 151                             maven     12
# 152                        unix shell     12
# 153                    manual testing     11
# 154                  google analytics     11
# 155                     deep learning     10
# 156         test automation framework     10
# 157                   spring security     10
# 158                             ionic     10
# 159                         black box      9
# 160                         bitbucket      8
# 161                    mobile testing      8
# 162                  software testing      8
# 163                        web design      7
# 164                             arkit      7
# 165                marketing strategy      6
# 166                          net core      6
# 167                regression testing      6
# 168                    graphic design      6
# 169                     unreal engine      6
# 170                   public speaking      5
# 171                           eclipse      5
# 172                         hibernate      5
# 173                   test management      5
# 174                       wireframing      5
# 175                 black box testing      5
# 176                   team management      4
# 177                     intellij idea      4
# 178             user interface design      3
# 179                   microsoft excel      3
# 180                            jquery      3
# 181                strategic planning      3
# 182                   api development      3
# 183               organization skills      3
# 184                        spring mvc      3
# 185             solution architecture      3
# 186                   team leadership      2
# 187                              ajax      2
# 188                           net mvc      2
# 189            social media marketing      2
# 190                        embedded c      2
# 191                       google maps      2
# 192                  creative writing      2
# 193                  microsoft office      1
# 194                functional testing      1
# 195                            tomcat      1
# 196          software design patterns      1
# 197                            drupal      1
# 198        object oriented programing      0
# 199                    microsoft word      0
# 200                            matlab      0
# 201              microsoft powerpoint      0
# 202                   docker products      0
# 203    iphone application development      0
# 204                iphone application      0
# 205                     java database      0
# 206                     net framework      0
# 207                   adobe photoshop      0
# 208                 adobe illustrator      0
# 209               restful webservices      0
# 210                   oracle database      0
# 211                        jakarta ee      0
# 212                      visual basic      0
# 213                          servlets      0
# 214                     agile project      0
# 215   representational state transfer      0
# 216            representational state      0
# 217              internet information      0
# 218     internet information services      0
# 219                           arduino      0
# 220             requirements analysis      0
# 221                        ecmascript      0
# 222                            javase      0
# 223                             latex      0
# 224             operations management      0
# 225                  javaserver pages      0
# 226           solid design principles      0
# 227  windows communication foundation      0
# 228             windows communication      0
# 229                   adobe lightroom      0
# 230                      solid design      0
# 231                     test planning      0
# 232                          net ajax      0
# 233         mobile application design      0
# 234              unix shell scripting      0
# 235                              vhdl      0
# 236                       codeigniter      0
# 237                            testng      0
# 238                 career management      0
# 239                  sales management      0
# 240                selenium webdriver      0
# 241                        sketch app      0
# 242           waterfall methodologies      0
# 243                          netbeans      0
# 244                        google ads      0
# 245                        google api      0
# 246                      appcelerator      0
# 247                          phonegap      0
# 248                         buildfire      0
# 249                       objective-c      0
# 250                     action script      0

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top Skills Required by Employers for Junior/Entry Level Positions

# %%
skills_count = {}
for skill in skills:
    counter = 0
    for description in junior_level_df['descriptions']:
        if (skill == 'ci') and len(re.findall('ci ', description))>0:
            counter+=1
        elif skill in description:
            counter += 1
    skills_count[skill] = counter
skills_count = pd.DataFrame(dict(sorted(skills_count.items(), key=lambda x: x[1], reverse=True)).items())
skills_count.columns = ['skill', 'count']
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
## Next analysis : Top skills for iOS jobs and for Android Jobs

# %%
df['position'].value_counts()
# Out:
# android developer                                                                                                 44
# software development engineer                                                                                     40
# senior android developer                                                                                          35
# senior android engineer                                                                                           31
# senior ios developer                                                                                              27
# senior ios engineer                                                                                               26
# lead mobile developer ios android                                                                                 21
# ios engineer f m d                                                                                                21
# android engineer                                                                                                  20
# senior ios developer m f d                                                                                        18
# ios developer f m d 80 100                                                                                        17
# senior android developer m f d                                                                                    16
# android software engineer in test                                                                                 14
# software development engineer mobile                                                                              14
# mobile software development engineer                                                                              13
# android software development engineer amazon eero                                                                 13
# senior android engineer m f d                                                                                     12
# senior software development engineer                                                                              12
# ios developer                                                                                                     12
# android engineer kotlin java                                                                                      12
# fullstack engineer d f m                                                                                          11
# sr software development engineer amazon berlin                                                                    11
# android engineer d f m                                                                                            11
# android developer m w d remote rm21                                                                               10
# android engineer style advice                                                                                     10
# software engineer backend                                                                                         10
# mobile developer m f d                                                                                             9
# android engineer remote or relocate                                                                                9
# senior android developer f m d                                                                                     9
# senior android engineer big release team                                                                           9
# mobile engineer flutter m f d                                                                                      9
# ios engineer                                                                                                       9
# senior lead android engineer                                                                                       9
# associate android engineer                                                                                         9
# senior software engineer android                                                                                   8
# software engineer                                                                                                  8
# full stack engineer                                                                                                8
# senior ios developer video                                                                                         8
# senior android engineer outfits                                                                                    8
# ios software development engineer amazon eero                                                                      8
# junior front end or full stack developer f m d for lob real estate limited contract                                8
# senior frontend engineer d f m                                                                                     8
# ios developer at stanwood                                                                                          7
# ios developer d f m                                                                                                7
# ios engineer appcraft mobile                                                                                       7
# lead staff software engineer android bangkok based relocation provided                                             7
# ios engineer big release team                                                                                      7
# staff android engineer engagement                                                                                  7
# audio software engineer                                                                                            7
# mobile platform engineer android                                                                                   7
# android engineer consumer experience                                                                               7
# android engineer appcraft mobile                                                                                   7
# ios engineer customer profile personalization                                                                      7
# senior software engineer android bangkok based relocation provided                                                 7
# senior ios developer m f d berlin hamburg or remote in eu                                                          7
# junior android engineer customer profile and personalization                                                       6
# react native engineer remote                                                                                       6
# senior android engineer style advice                                                                               6
# senior ios developer remote                                                                                        6
# android developer video                                                                                            6
# sr ios developer f m d                                                                                             6
# sr ios developer                                                                                                   6
# software dev engineer ii                                                                                           6
# senior android engineer design engineering f m d                                                                   6
# senior android developer m f d developer experience                                                                6
# ios engineer size fit                                                                                              6
# senior engineer android                                                                                            6
# ios engineer apps uct                                                                                              6
# ios developer merchant bank engagement                                                                             6
# android engineer d f m berlin or hamburg                                                                           6
# senior ios engineer customer profile personalization                                                               6
# full stack engineer d f m                                                                                          6
# mobile android developer                                                                                           6
# senior ios developer f m d onsite or remote home office                                                            6
# senior ios engineer style advice                                                                                   6
# senior backend engineer                                                                                            6
# staff android engineer acquire                                                                                     6
# software engineer text to speech c                                                                                 6
# senior android engineer activity content                                                                           6
# senior ios engineer outfits                                                                                        6
# principal android engineer zalando lounge w m d                                                                    6
# software development engineer fire tv                                                                              6
# react native software engineer javascript m f d                                                                    6
# mobile developer ios m f d                                                                                         6
# lead engineer android                                                                                              6
# software development engineer amazon eero cloud                                                                    6
# senior android engineer apps customer conversion                                                                   6
# mobile engineer                                                                                                    6
# ios engineer apps category experience                                                                              6
# lead ios developer                                                                                                 6
# c engineer media streaming all genders                                                                             5
# android engineer all genders                                                                                       5
# senior full stack software developer f m d process automation                                                      5
# full stack android engineer d f m                                                                                  5
# senior android developer m w d                                                                                     5
# android developer m w d                                                                                            5
# android mobile engineer all genders                                                                                5
# senior ios developer m f d developer experience                                                                    5
# android engineer customer profile and personalisation                                                              5
# senior ios software engineer                                                                                       5
# guidewire software engineer all genders                                                                            5
# frontend software engineer javascript                                                                              5
# software development engineer emea multiple locations teams                                                        5
# senior android engineer customer profile and personalisation                                                       5
# infrastructure software engineer                                                                                   5
# mobile app engineer react native f m d                                                                             5
# senior android developer all genders in berlin                                                                     5
# android engineer customer acquisition engagement                                                                   5
# sr android developer                                                                                               5
# mobile ios developer                                                                                               5
# software engineer backend kotlin                                                                                   5
# senior full stack software engineer python m f d                                                                   5
# mobile engineer flutter all genders                                                                                5
# ios developer ii senior                                                                                            5
# full stack software engineer javascript                                                                            5
# senior ios engineer product experience                                                                             5
# sr android developer in test m f x                                                                                 5
# frontend developer m w d experience design mobile in berlin                                                        5
# lead ios developer f d m                                                                                           5
# software development engineer amazon web services ides berlin                                                      5
# ios engineer d f m                                                                                                 5
# software engineer full stack bangkok based relocation provided                                                     5
# senior ios developer iot m f x at sensorberg gmbh                                                                  5
# senior android developer m w d remote rm21                                                                         5
# software engineer scripting team                                                                                   5
# mobile platform engineer ios                                                                                       5
# kotlin backend developer and mobile enthusiast m f d                                                               5
# senior product designer                                                                                            5
# senior android engineer m f x                                                                                      5
# senior ios engineer f m x                                                                                          5
# senior android engineer f m d                                                                                      5
# mobile app developer f m d                                                                                         5
# software engineer search experience m f d                                                                          5
# senior full stack developer ruby react                                                                             5
# software development engineer amazon berlin tech hub                                                               5
# senior frontend engineer                                                                                           5
# software engineer c qt qml                                                                                         5
# lead unity developer                                                                                               5
# senior ios engineer apps customer conversion                                                                       5
# software engineer m f d core ios remote                                                                            5
# mobile engineer ios merchant bank engagement                                                                       5
# react native developer                                                                                             5
# ios team lead                                                                                                      5
# android engineer fincrime                                                                                          5
# android developer m f d                                                                                            5
# senior ios developer zalando lounge w m d                                                                          5
# senior lead ios engineer                                                                                           5
# mid level android engineer kotlin logistics vendor f m d                                                           5
# senior ios developer m w d                                                                                         5
# software dev engineer                                                                                              5
# frontend engineer typescript react software developer                                                              5
# senior ios mobile engineer vendor portal f m d                                                                     5
# engineer android                                                                                                   5
# senior android developer welt apps m f d                                                                           5
# senior ios engineer design engineer f m d                                                                          5
# c software engineer all genders                                                                                    4
# senior frontend fullstack engineer finance group                                                                   4
# front end engineer                                                                                                 4
# senior software engineer                                                                                           4
# android engineer client foundation f m d                                                                           4
# software engineer f d m                                                                                            4
# software engineer edge routing and graphql platforms                                                               4
# senior android engineer discovery experience consumer discovery f m d                                              4
# senior mobile engineer android react native                                                                        4
# senior mobile engineer all genders                                                                                 4
# quality assurance engineer f m d                                                                                   4
# senior ios engineer merchant growth                                                                                4
# ios engineer remote or relocate                                                                                    4
# mobile application developer react native d f m                                                                    4
# senior android engineer d f m                                                                                      4
# senior front end mobile engineer react native m f d                                                                4
# senior mobile engineer ios merchant growth                                                                         4
# staff full stack web developer                                                                                     4
# senior ios engineer all genders                                                                                    4
# senior mobile engineer m w d                                                                                       4
# android engineer f m d                                                                                             4
# senior android developer video                                                                                     4
# software engineer query optimization f m d                                                                         4
# lead ios android mobile engineer                                                                                   4
# senior ios engineer m f d                                                                                          4
# core mobile engineer                                                                                               4
# senior android engineer opsx                                                                                       4
# software engineer developer tools                                                                                  4
# mobile software engineer                                                                                           4
# mobile developer android ios reactnative                                                                           4
# senior ios engineer travelers platform                                                                             4
# ios tvos engineer                                                                                                  4
# senior software engineer full stack bangkok based relocation provided                                              4
# senior full stack engineer amazon music machine learning teams berlin                                              4
# senior product manager                                                                                             4
# lead android engineer m f d                                                                                        4
# mobile app developer react native ionic ios android                                                                4
# devops engineer m f d                                                                                              4
# senior android engineer zalando lounge m f d                                                                       4
# backend software engineer javascript                                                                               4
# senior software engineer go adtech f m d                                                                           4
# flutter engineer m f x                                                                                             4
# lead mobile engineer                                                                                               4
# mobile engineer react native m f d                                                                                 4
# software developer go remote m w d                                                                                 4
# android software developer embedded m f d                                                                          4
# senior ios developer f m d                                                                                         4
# software engineer mobile reverse engineering android all genders                                                   4
# senior android engineer f m x                                                                                      4
# android engineer f m d x                                                                                           4
# ios engineer all genders                                                                                           4
# software developer                                                                                                 4
# fullstack engineer java reactjs content creation w m d                                                             4
# senior android engineer d f m berlin or hamburg                                                                    4
# android software engineer remote                                                                                   4
# mobile qa automation engineer                                                                                      4
# mobile software engineer react native for gender equality app                                                      4
# junior ios engineer                                                                                                4
# mobile full stack developer f m d                                                                                  4
# engineering manager mobile f m d                                                                                   4
# senior mobile developer m f d                                                                                      4
# senior software engineer ios                                                                                       4
# backend software engineer                                                                                          4
# software development engineer embedded software                                                                    4
# mobile developer android                                                                                           4
# ruby full stack developer m f d                                                                                    4
# senior mobile engineer ios hardware                                                                                4
# senior software engineer ios bangkok based relocation provided                                                     3
# senior android engineer client foundation f m d                                                                    3
# senior android developer consumer apps                                                                             3
# software development engineer aws console                                                                          3
# qa engineer apps m f d                                                                                             3
# mobile developer flutter m w d                                                                                     3
# senior frontend engineer data infrastructure angular                                                               3
# sales engineer                                                                                                     3
# software engineer backend focus all genders                                                                        3
# product manager                                                                                                    3
# ios developer with ar focus                                                                                        3
# crm manager b2c b2b                                                                                                3
# solution architect                                                                                                 3
# senior frontend engineer messagebird 24sessions                                                                    3
# software developer m w d                                                                                           3
# system dev engineer sap                                                                                            3
# quality assurance engineer                                                                                         3
# engineering manager ui components                                                                                  3
# ios software engineer                                                                                              3
# senior python developer m f d developer experience                                                                 3
# senior ios developer w m d                                                                                         3
# sales development representative                                                                                   3
# lead staff full stack software engineer bangkok based relocation provided                                          3
# senior mobile sdk engineer berlin or remote                                                                        3
# react native engineer mobile platform team remote                                                                  3
# mobile engineer m f d remote bm21_1452                                                                             3
# ios developer berlin                                                                                               3
# senior open source developer devops remote                                                                         3
# lead backend developer                                                                                             3
# staff principal android engineer                                                                                   3
# senior frontend engineer javascript react native f m x mobile                                                      3
# customer success account manager                                                                                   3
# senior software engineer frontend focus all genders                                                                3
# software engineer data infrastructure kausa                                                                        3
# senior software engineer input systems                                                                             3
# cypress engineer remote                                                                                            3
# lead android engineer m f x                                                                                        3
# fullstack engineer be f m d                                                                                        3
# senior software engineer development infrastructure f m d                                                          3
# android developer sinnerschrader f m d                                                                             3
# senior android software engineer                                                                                   3
# full stack developer m f d                                                                                         3
# unity developer                                                                                                    3
# ios engineer consumer experience                                                                                   3
# sales development representative f m d mobile games                                                                3
# senior mobile engineer android                                                                                     3
# software engineer data platform                                                                                    3
# senior software engineer android app development m f d                                                             3
# ios android developer m f d                                                                                        3
# react native engineer m f d                                                                                        3
# senior ios engineer platform                                                                                       3
# principal software engineer                                                                                        3
# software engineer search platform                                                                                  3
# ios engineer fincrime                                                                                              3
# engineering manager mobile                                                                                         3
# backend software engineer ruby                                                                                     3
# senior android developer f m d bm21_1669                                                                           3
# sen android developer m w d                                                                                        3
# golang software engineer f m x                                                                                     3
# senior android developer f m d in berlin                                                                           3
# staff mobile engineer react native m f d                                                                           3
# senior android engineer engineer f m d discovery homescreen                                                        3
# senior ios engineer ar and mapping                                                                                 3
# fullstack senior engineer m f d                                                                                    3
# senior ios developer relocation                                                                                    3
# mobile entwickler m w d ios android swift kotlin flutter                                                           3
# senior android engineer platform                                                                                   3
# senior android engineer based in dubai                                                                             3
# developer for android sdk m f d                                                                                    3
# frontend developer react ui ux                                                                                     3
# senior software engineer ios m f d                                                                                 3
# senior fullstack developer m f x                                                                                   3
# senior full stack engineer m f d city                                                                              3
# fullstack engineer ui f m d                                                                                        3
# full stack engineer remote                                                                                         3
# systems level software developer for windows w m d                                                                 3
# ios developer f m d                                                                                                3
# senior frontend developer react dashboard                                                                          3
# senior full stack engineer opsx                                                                                    3
# senior ios engineer discovery homescreen f m d                                                                     3
# senior android engineer automation infra f m d                                                                     3
# fullstack javascript engineer                                                                                      3
# senior mobile developer android merchant growth                                                                    3
# 3d software engineer cloud                                                                                         3
# software engineer android                                                                                          3
# senior react native software engineer javascript m f d                                                             3
# senior software engineer search experience m f d                                                                   3
# react native engineer                                                                                              3
# full stack engineer f m d                                                                                          3
# full stack software developer                                                                                      3
# senior kernel software developer for windows w m d                                                                 3
# test automation engineer remote                                                                                    3
# mobile qa engineer                                                                                                 3
# mobile qa automation engineer native apps f m d                                                                    3
# technical services engineer m f x                                                                                  3
# senior ios engineer discovery experience consumer discovery f m d                                                  3
# full stack engineer amazon music machine learning teams berlin                                                     3
# golang backend software engineer f m d                                                                             2
# senior front end web developer m w d                                                                               2
# softwareentwickler senior junior                                                                                   2
# senior backend developer                                                                                           2
# customer success manager paid social                                                                               2
# lisk mobile developer react native m f d bm21_1427                                                                 2
# mobile developer makinas f m x                                                                                     2
# senior data engineer event tracking streaming analytics                                                            2
# frontend developer m f x                                                                                           2
# sen ios developer m w d                                                                                            2
# full stack javascript engineer multiple openings f m d                                                             2
# senior c developer                                                                                                 2
# fullstack developer m f x                                                                                          2
# senior android engineer f m d berlin                                                                               2
# senior software engineer backend node js remote                                                                    2
# ui frontend developer                                                                                              2
# technical account manager                                                                                          2
# senior ios engineer m f d team ios                                                                                 2
# senior cloud infrastructure engineer m f d                                                                         2
# engineering manager director bangkok based relocation provided                                                     2
# senior software engineer javascript react adtech f m d                                                             2
# full stack engineer kotlin reactjs aws m f x                                                                       2
# senior technical product manager m f d                                                                             2
# senior software engineer qa f m d                                                                                  2
# senior mobile engineer m f d                                                                                       2
# sr full stack engineer m f x                                                                                       2
# software engineer mobile solutions android ios                                                                     2
# app developer ios nearshore remote m f d                                                                           2
# frontend developer d f m                                                                                           2
# account executive                                                                                                  2
# experience designer experience architect salesforce core                                                           2
# ios lead f m d 80 100                                                                                              2
# software engineer backend m f x                                                                                    2
# full stack engineer developer console                                                                              2
# senior game designer                                                                                               2
# ios engineer m f x                                                                                                 2
# c software engineer containers all genders                                                                         2
# junior hybrid cloud architect f m x                                                                                2
# senior product manager retail                                                                                      2
# senior frontend engineer react javascript                                                                          2
# android developer f m x                                                                                            2
# senior javascript engineer m f x                                                                                   2
# senior software development engineer full stack                                                                    2
# product designer user experience                                                                                   2
# software engineer m f x                                                                                            2
# full stack developer javascript m f d                                                                              2
# senior backend engineer java                                                                                       2
# software developer backend cloud services python nodejs m f d enote gmbh                                           2
# senior mobile developer ios m w d in berlin                                                                        2
# senior software engineer m f d                                                                                     2
# enterprise search senior frontend engineer                                                                         2
# senior machine learning engineer                                                                                   2
# software engineer kotlin react azeti mes platform                                                                  2
# digital product designer m f d                                                                                     2
# software engineer digital advertising                                                                              2
# python developer mid senior level                                                                                  2
# senior software engineer applied machine learning speech processing                                                2
# product manager m w d                                                                                              2
# ios developer swift rxswift freelance                                                                              2
# software engineer f x m                                                                                            2
# full stack developer node js react aws m f d                                                                       2
# software engineer czech nlu c                                                                                      2
# software engineer c pix4dmatic                                                                                     2
# senior ios engineer client foundation f m d                                                                        2
# java engineer f m d                                                                                                2
# devops engineer                                                                                                    2
# fullstack engineer m f d                                                                                           2
# ios developer f m x                                                                                                2
# senior ios developer d f m                                                                                         2
# net developer                                                                                                      2
# senior software engineer in test adtech f m d                                                                      2
# senior software engineer ruby f m d                                                                                2
# senior frontend developer                                                                                          2
# frontend developer m f d                                                                                           2
# frontend developer all genders                                                                                     2
# ios android entwickler w m d at ampada gmbh                                                                        2
# senior software engineer python adtech f m d                                                                       2
# talent acquisition partner recruiter emea all genders                                                              2
# app developer android nearshore remote m f d                                                                       2
# engineering manager mobile all genders                                                                             2
# application innovation specialist specialist sales solution area                                                   2
# ui developer                                                                                                       2
# senior software development engineer amazon music machine learning teams berlin                                    2
# senior react native engineer f m x                                                                                 2
# software engineer node js f m d                                                                                    2
# product lead retail                                                                                                2
# staff fullstack engineer m f d                                                                                     2
# embedded software test engineer                                                                                    2
# senior android mobile engineer java kotlin quick commerce f m d                                                    2
# senior software development engineer embedded software                                                             2
# technical support specialist                                                                                       2
# ...
# hr business partner m f d                                                                                          1
# product manager logistics ios android rider apps f m d                                                             1
# senior ux ui concept design specialist m f d                                                                       1
# data compliance governance specialist                                                                              1
# senior backend engineer d f m                                                                                      1
# director of product ecosystems                                                                                     1
# senior software engineer embedded systems m f d                                                                    1
# associate general counsel data protection instagram                                                                1
# talent acquisition partner product design                                                                          1
# game level designer                                                                                                1
# mobile entwickler android ios reactnative m w d anwendungsentwicklung it                                           1
# backend engineer cards                                                                                             1
# software architect focus on functional and platform software m f d                                                 1
# quality automation engineer m f x                                                                                  1
# sr sde aws                                                                                                         1
# senior unity 3d developer                                                                                          1
# junior full stack entwickler m w d inkl remote anteil                                                              1
# senior app marketing manager engagement growth retention m f x                                                     1
# head of product design restaurants f m d                                                                           1
# qa engineer d f m                                                                                                  1
# people operations associate w m d                                                                                  1
# unreal engine programmer                                                                                           1
# technical account manager german speaking                                                                          1
# senior fullstack engineer node react aws                                                                           1
# software engineer go lang                                                                                          1
# engineering manager all genders                                                                                    1
# senior frontend engineer react js m w d                                                                            1
# sw engineer car navigation systems typescript rxjs grpc node berlin irc125399                                      1
# senior technical trainer evangelist m f d                                                                          1
# app store business manager                                                                                         1
# teamlead m f x game development                                                                                    1
# senior javascript engineer editor                                                                                  1
# senior backend engineer nodejs typescript                                                                          1
# softwareentwickler ios swift w m d                                                                                 1
# senior software engineer m f x payments engineering                                                                1
# embedded software engineer iot m f d                                                                               1
# vice president finance m f d                                                                                       1
# talent acquisition specialist m f x                                                                                1
# senior frontend engineer vue f m d                                                                                 1
# senior mobile product designer m f d                                                                               1
# client solutions manager apps performance marketing                                                                1
# sr devops engineer m f x                                                                                           1
# game artist hyper casual games                                                                                     1
# visual designer                                                                                                    1
# backend engineer bank core                                                                                         1
# senior backend software engineer                                                                                   1
# senior product manager a b testing                                                                                 1
# senior marketing analyst                                                                                           1
# lead iot technology architect data platform m f d                                                                  1
# product owner web mobile team m f d bm21_1532                                                                      1
# senior frontend engineer all genders                                                                               1
# senior cloud analytics platform engineer m f d                                                                     1
# fullstack engineer search engine optimisation                                                                      1
# full stack software engineer f m x                                                                                 1
# technical program director                                                                                         1
# devops engineer multiple openings f m d                                                                            1
# project manager women s health medical expertise                                                                   1
# senior software engineer traffic pricing platform engineering                                                      1
# product owner digital advertising                                                                                  1
# senior software engineer back end m f d                                                                            1
# lead full stack developer m f x                                                                                    1
# talent acquisition partner it series c fintech                                                                     1
# copywriter w m d                                                                                                   1
# gameplay programmer                                                                                                1
# data analyst m f d                                                                                                 1
# product manager traveler ux                                                                                        1
# senior backend engineer python django shore pos f m d                                                              1
# product designer design system f m d                                                                               1
# solution train engineer software platform m f d                                                                    1
# full stack entwickler w m d für webanwendungen remote de                                                           1
# solutions engineer dach                                                                                            1
# user experience researcher                                                                                         1
# senior software developer identity and access management m f d                                                     1
# software engineer in machine learning m f d                                                                        1
# senior product manager f m d                                                                                       1
# senior product manager gn                                                                                          1
# sr software development engineer aws identity                                                                      1
# backend engineer rider acquisition m f d hamburg berlin or remote in eu                                            1
# country manager germany                                                                                            1
# full stack engineer playbooks team remote                                                                          1
# sap abap entwickler m w d mobile lösungen                                                                          1
# senior devops engineer analytics cloud platform m f d                                                              1
# ios engineer m f d remote                                                                                          1
# lead full stack developer berlin or remote                                                                         1
# senior full stack engineer berlin or remote                                                                        1
# system development engineer adas automated driving and predictive safety m f d                                     1
# enterprise solution architect mobility services m f d                                                              1
# graduate program business of tech                                                                                  1
# software development manager amazon music ml personalization                                                       1
# associate general counsel data protection product                                                                  1
# senior talent acquisition manager tech product c4l m f d                                                           1
# business development representative remote                                                                         1
# devops engineer for mobile apps all genders in berlin                                                              1
# senior devops engineer multiple openings f m d                                                                     1
# backend software engineer f m x                                                                                    1
# product lead logistics                                                                                             1
# senior cloud engineer m f d                                                                                        1
# frontend developer f m x                                                                                           1
# product marketing manager m f d predictive maintenance                                                             1
# senior mobile engineer flutter f m d                                                                               1
# full stack engineer growth team remote                                                                             1
# engineering manager f m x partially remote                                                                         1
# senior full stack developer m f x                                                                                  1
# senior account executive platform solutions                                                                        1
# product lead supply demand                                                                                         1
# senior java developer chapter lead m f d                                                                           1
# software engineer f m d digital production                                                                         1
# backend engineer remote or relocate                                                                                1
# market development specialist germany                                                                              1
# community manager mobile emea                                                                                      1
# technical team lead full stack developer                                                                           1
# unity 3d developer                                                                                                 1
# senior backend engineer opsx                                                                                       1
# director of engineering all genders                                                                                1
# senior node js typescript engineer x f m                                                                           1
# senior software engineer m f d bm21_998                                                                            1
# software cloud engineer digital assistants m f d                                                                   1
# integration test manager digital lifecycle management m f d                                                        1
# lead software engineer m f d                                                                                       1
# software entwickler programmierer developer m w d in vollzeit teilzeit unbefristet                                 1
# senior product manager logistics ios android rider apps f m d                                                      1
# experience design consultant ux ui all levels genders                                                              1
# senior product manager web video editor                                                                            1
# head of hr operations germany                                                                                      1
# senior react developer x f m freelance                                                                             1
# operations associate                                                                                               1
# senior product designer f m d                                                                                      1
# pmt architect digital lifecycle management m f d                                                                   1
# analyst fraud                                                                                                      1
# senior product designer hardware tribe                                                                             1
# growth marketing manager b2b                                                                                       1
# java backend developer mobile game fixed position in berlin m f d                                                  1
# qa engineer hardware                                                                                               1
# lead engineer consumer search                                                                                      1
# senior backend engineer java kotlin for order management retail core w m d                                         1
# sr lead visual designer m f x                                                                                      1
# Name: position, dtype: int64

# %%
def platform_ios_android(x, y):
    if 'android' in x:
        return "android"
    elif 'kotlin' in x:
        return "android"
    elif 'ios' in x:
        return 'ios'
    elif 'swift' in x:
        return 'ios'
    elif ('android' in y) and ('ios' not in y):
        return 'android'
    elif ('ios' in y) and ('android' not in y):
        return 'ios'
    elif ('swift' in y) and ('kotlin' not in y) and ('android' not in y):
        return 'ios'
    elif ('kotlin' in y) and ('swift' not in y) and ('ios' not in y):
        return 'android'
    else:
        return 'not specified'     
df['platform'] = list(map(platform_ios_android, df['position'], df['descriptions']))

# %%
df['platform'].value_counts()
# Out:
# not specified    1041
# android           907
# ios               657
# Name: platform, dtype: int64

# %% [markdown]
# # iOS Analysis

# %%
ios_df = df[df['platform']=='ios']
ios_df.shape
# Out:
# (657, 18)

# %%
# ios_df.head()

# %%
ios_junior_df = df[(df['platform']=='ios') & (df['seniority_segment_created']=='junior/entry level')]
ios_junior_df.shape
# Out:
# (241, 18)

# %%
# ios_junior_df.head()

# %% [markdown]
# # IOS JOBS BY TIMEFRAMES

# %%
temp = pd.DataFrame(ios_df['time_frames'].value_counts()).reset_index()
temp.columns =['time_frames', 'number of postings']
temp
# Out:
#              time_frames  number of postings
# 0      More than 3 weeks                 291
# 1          within 1 week                 194
# 2  Between 1 and 2 weeks                  91
# 3  Between 2 and 3 weeks                  81

# %%
a = 'within 1 week'
b = 'Between 1 and 2 weeks'
c = 'Between 2 and 3 weeks'
d = 'More than 3 weeks'
x = [a,b, c, d]
a = temp[temp['time_frames'] == a]['number of postings'].values[0]
b = temp[temp['time_frames'] == b]['number of postings'].values[0]
c = temp[temp['time_frames'] == c]['number of postings'].values[0]
d = temp[temp['time_frames'] == d]['number of postings'].values[0]
y = [a,b,c,d]

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x=x, y=y)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # JUNIOR LEVEL IOS JOBS BY TIMEFRAMES

# %%
temp = pd.DataFrame(ios_junior_df['time_frames'].value_counts()).reset_index()
temp.columns =['time_frames', 'number of postings']
a = 'within 1 week'
b = 'Between 1 and 2 weeks'
c = 'Between 2 and 3 weeks'
d = 'More than 3 weeks'
x = [a,b, c, d]
a = temp[temp['time_frames'] == a]['number of postings'].values[0]
b = temp[temp['time_frames'] == b]['number of postings'].values[0]
c = temp[temp['time_frames'] == c]['number of postings'].values[0]
d = temp[temp['time_frames'] == d]['number of postings'].values[0]
y = [a,b,c,d]
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x=x, y=y)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # SKILLS

# %%
skills_count_ios = {}
counter = 0
for skill in skills:
    counter = 0
    for description in ios_df['descriptions']:
        if (skill == 'ci'):
            if len(re.findall('ci ', description))>0:
                counter+=1
        elif skill in description:
            counter += 1
    skills_count_ios[skill] = counter
skills_count_ios = pd.DataFrame(dict(sorted(skills_count_ios.items(), key=lambda x: x[1], reverse=True)).items())
skills_count_ios.columns = ['skill', 'count']
skills_count_ios = skills_count_ios[skills_count_ios['count']>0]
skills_count_ios
# Out:
#                               skill  count
# 0                               ios    633
# 1                             swift    469
# 2                             unity    405
# 3                               git    348
# 4                           english    342
# 5                       engineering    324
# 6                     communication    311
# 7                           testing    311
# 8                               a b    309
# 9                       objective c    218
# 10                             apis    206
# 11                          android    191
# 12                  user experience    165
# 13                              sdk    161
# 14                       management    151
# 15             software development    149
# 16                             java    134
# 17                  design patterns    130
# 18                         research    127
# 19                 computer science    126
# 20                            scala    123
# 21               mobile application    121
# 22                         training    118
# 23              mobile applications    106
# 24                             rust    105
# 25                            uikit    104
# 26                              lua    102
# 27                       leadership     88
# 28         application architecture     80
# 29           continuous integration     76
# 30                         fastlane     74
# 31                       javascript     72
# 32                      advertising     72
# 33                         strategy     71
# 34                          swiftui     70
# 35                            xcode     64
# 36                           kotlin     63
# 37                           github     62
# 38                  problem solving     62
# 39                          graphql     62
# 40                            scrum     60
# 41                        app store     58
# 42                       kubernetes     57
# 43                     unit testing     55
# 44                agile environment     50
# 45                       full stack     48
# 46                       algorithms     48
# 47                       typescript     48
# 48                        cocoapods     48
# 49             programming language     46
# 50                  software design     46
# 51                 machine learning     45
# 52                       e commerce     44
# 53                             json     43
# 54                         back end     42
# 55                        front end     42
# 56                  data structures     40
# 57                      cocoa touch     37
# 58                              sql     35
# 59                        core data     34
# 60                     react native     33
# 61                      a b testing     33
# 62                             jira     32
# 63                       life cycle     32
# 64                          windows     32
# 65                          jenkins     29
# 66                      test driven     29
# 67          test driven development     29
# 68                    microservices     28
# 69          application development     28
# 70                        databases     27
# 71                        marketing     27
# 72               product management     27
# 73                             html     24
# 74                         firebase     24
# 75                        terraform     24
# 76                         teamwork     22
# 77                       networking     22
# 78                           devops     20
# 79                         big data     20
# 80                          flutter     19
# 81                              css     18
# 82                            linux     18
# 83                  test automation     18
# 84                            junit     17
# 85                      spring boot     15
# 86                            azure     15
# 87                     data science     15
# 88                 customer service     14
# 89                          mongodb     13
# 90                           django     13
# 91                          angular     13
# 92                     google cloud     13
# 93        software development life     12
# 94                              sap     12
# 95                            redis     12
# 96           electrical engineering     12
# 97                          finance     11
# 98                  web development     10
# 99                       unix shell     10
# 100                embedded systems      9
# 101                             php      8
# 102                            sass      8
# 103               augmented reality      8
# 104                 computer vision      8
# 105                spring framework      7
# 106                          gradle      7
# 107           google cloud platform      7
# 108                        selenium      7
# 109                           arkit      7
# 110              project management      6
# 111             agile methodologies      6
# 112  mobile application development      6
# 113                    web services      6
# 114                web applications      6
# 115               analytical skills      6
# 116               operating systems      6
# 117                 spring security      6
# 118                  manual testing      5
# 119              regression testing      5
# 120                  multithreading      5
# 121                         xamarin      5
# 122                         cordova      5
# 123             amazon web services      4
# 124                      amazon web      4
# 125                       angularjs      4
# 126                    social media      4
# 127                 shell scripting      4
# 128                      test cases      4
# 129                   visual studio      3
# 130                      spring mvc      3
# 131                   mobile design      3
# 132                             xml      2
# 133                       bootstrap      2
# 134               business strategy      2
# 135            business development      2
# 136                 design thinking      2
# 137                      embedded c      2
# 138                  mobile testing      2
# 139                         tableau      2
# 140            relational databases      2
# 141                           html5      1
# 142                 team leadership      1
# 143              strategic planning      1
# 144                 time management      1
# 145                game development      1
# 146                 test management      1
# 147                software testing      1
# 148                   deep learning      1
# 149       test automation framework      1
# 150                 api development      1
# 151                creative writing      1
# 152           solution architecture      1
# 153               product marketing      1

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_ios.iloc[20:40])
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # JUNIOR LEVEL SKILLS

# %%
skills_count_ios = {}
counter = 0
for skill in skills:
    counter = 0
    for description in ios_junior_df['descriptions']:
        if (skill == 'ci'):
            if len(re.findall('ci ', description))>0:
                counter+=1
        elif skill in description:
            counter += 1
    skills_count_ios[skill] = counter
skills_count_ios = pd.DataFrame(dict(sorted(skills_count_ios.items(), key=lambda x: x[1], reverse=True)).items())
skills_count_ios.columns = ['skill', 'count']
skills_count_ios = skills_count_ios[skills_count_ios['count']>0]
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top companies iOS

# %%
top_companies_ios = pd.DataFrame(ios_df['company_name'].value_counts()).reset_index()
top_companies_ios.columns =['company_name', 'number of postings']
top_companies_ios
# Out:
#                                           company_name  number of postings
# 0                                              zalando                  74
# 1                                                sumup                  26
# 2                                              picsart                  24
# 3                                        delivery hero                  20
# 4                                               amazon                  19
# 5                            mimi hearing technologies                  19
# 6                                             join.com                  12
# 7                                       mobile.de gmbh                  12
# 8                                               cariad                  11
# 9                                              gymondo                  11
# 10                                              exasol                  11
# 11                                           sharecare                  11
# 12                                        michael page                  11
# 13                                               flink                   9
# 14                                               lemon                   9
# 15                                              babbel                   8
# 16                                              stripe                   7
# 17                                  ebay kleinanzeigen                   7
# 18                                        marley spoon                   7
# 19                                            free now                   7
# 20                                             combyne                   6
# 21                                              taxfix                   6
# 22   1&1 mail & media applications se - gmx | web.d...                   6
# 23                                               wefox                   6
# 24                                             elastic                   6
# 25                                              zenjob                   6
# 26                                  darwin recruitment                   6
# 27                                             flixbus                   6
# 28                               rebuy recommerce gmbh                   6
# 29                                              vimcar                   6
# 30                                         auto1 group                   5
# 31                                               agoda                   5
# 32                                 lightspeed commerce                   5
# 33                                      bending spoons                   5
# 34                           gleeson recruitment group                   5
# 35                                             phiture                   5
# 36                                             scandit                   5
# 37                                             zendesk                   5
# 38                             vinted / kleiderkreisel                   5
# 39                                          contentful                   5
# 40                                             aircall                   5
# 41                                               artsy                   5
# 42                                         immoscout24                   5
# 43                                                yelp                   5
# 44                                              adjust                   5
# 45                                       tier mobility                   5
# 46                                              klarna                   5
# 47                                            duolingo                   4
# 48                                            blinkist                   4
# 49                                               mitte                   4
# 50                                             dimpact                   4
# 51                                              zattoo                   4
# 52                                             workist                   4
# 53                                               kayak                   4
# 54                                        getyourguide                   4
# 55                                               choco                   4
# 56                                      trade republic                   4
# 57                                          liveperson                   4
# 58             zero to one search | recruitment agency                   3
# 59                                        surprise.com                   3
# 60                                             feather                   3
# 61                                 savage game studios                   3
# 62                                           fraugster                   3
# 63                                            fantasmo                   3
# 64                                                vivy                   3
# 65                                      spark networks                   3
# 66                                            deloitte                   3
# 67                                           microsoft                   3
# 68                                       centa mg gmbh                   3
# 69                                               tribe                   3
# 70                                            jam city                   3
# 71                                          travelperk                   3
# 72                                    friday insurance                   3
# 73                  brands4friends - private sale gmbh                   3
# 74                                  sigmar recruitment                   3
# 75                                          hellofresh                   3
# 76                                               moyyn                   3
# 77                           avrios. the power to act.                   3
# 78                                               wire™                   3
# 79                                                 n26                   3
# 80                                               dance                   3
# 81                                                 oda                   3
# 82                                             spotify                   3
# 83                                       pixtunes gmbh                   2
# 84                                                 ibm                   2
# 85                                    lesson nine gmbh                   2
# 86                                      newstore, inc.                   2
# 87                                               wajve                   2
# 88                                              thryve                   2
# 89                                            vodafone                   2
# 90                                neugelb studios gmbh                   2
# 91                                           talentful                   2
# 92                                            diconium                   2
# 93                                      wow tech group                   2
# 94                                        lion studios                   2
# 95                                               comgy                   2
# 96                                              raisin                   2
# 97                                       hero software                   2
# 98                               dkb code factory gmbh                   2
# 99                                           voodoo.io                   2
# 100                                       orderbird ag                   2
# 101                                     orange quarter                   2
# 102                                  evolution germany                   2
# 103                              just eat takeaway.com                   2
# 104                                    spryker systems                   2
# 105                           thermo fisher scientific                   2
# 106                                     gameduell gmbh                   2
# 107                                               suse                   2
# 108                                              getir                   2
# 109                                         crealytics                   2
# 110                         tandem - language exchange                   2
# 111                                      caspar health                   1
# 112                                               moia                   1
# 113                          amazon web services (aws)                   1
# 114                                     pectus finance                   1
# 115                                              clark                   1
# 116                                         sauce labs                   1
# 117                         leaders for climate action                   1
# 118                                              lovoo                   1
# 119                                    architrave gmbh                   1
# 120                                       gematik gmbh                   1
# 121                                             preply                   1
# 122                                    schindler group                   1
# 123                                               king                   1
# 124                                           tooltime                   1
# 125                          mentor talent acquisition                   1
# 126             8bit is looking for awesome recruiters                   1
# 127                                          home24 se                   1
# 128                                             onfido                   1
# 129                                      bold business                   1
# 130                                            solexas                   1
# 131                                    emil group gmbh                   1
# 132                                                cgi                   1

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=top_companies_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # TOP IOS JOB COMPANIES FOR JUNIOR POSITIONS

# %%
top_companies_ios = pd.DataFrame(ios_junior_df['company_name'].value_counts()).reset_index()
top_companies_ios.columns =['company_name', 'number of postings']
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=top_companies_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Android Analysis

# %%
android_df = df[df['platform']=='android']
android_df.shape
# Out:
# (907, 18)

# %%
android_junior_df = df[(df['platform']=='android') & (df['seniority_segment_created']=='junior/entry level')]
android_junior_df.shape
# Out:
# (427, 18)

# %% [markdown]
# # ANDROID JOBS BY TIMEFRAME

# %%
temp = pd.DataFrame(android_df['time_frames'].value_counts()).reset_index()
temp.columns =['time_frames', 'number of postings']
temp
# Out:
#              time_frames  number of postings
# 0      More than 3 weeks                 384
# 1          within 1 week                 296
# 2  Between 1 and 2 weeks                 125
# 3  Between 2 and 3 weeks                 102

# %%
a = temp['time_frames'][0]
b = temp['time_frames'][2]
c = temp['time_frames'][3]
d = temp['time_frames'][1]
x = [a,b, c, d]
a = temp['number of postings'][0]
b = temp['number of postings'][2]
c = temp['number of postings'][3]
d = temp['number of postings'][1]
y = [a,b,c,d]

# %%
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x=x, y=y)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # JUNIOR LEVEL ANDROID JOBS BY TIME FRAME

# %%
temp = pd.DataFrame(android_junior_df['time_frames'].value_counts()).reset_index()
temp.columns =['time_frames', 'number of postings']
a = 'within 1 week'
b = 'Between 1 and 2 weeks'
c = 'Between 2 and 3 weeks'
d = 'More than 3 weeks'
x = [a,b, c, d]
a = temp[temp['time_frames'] == a]['number of postings'].values[0]
b = temp[temp['time_frames'] == b]['number of postings'].values[0]
c = temp[temp['time_frames'] == c]['number of postings'].values[0]
d = temp[temp['time_frames'] == d]['number of postings'].values[0]
y = [a,b,c,d]
fig, ax = plt.subplots(figsize= (20,5))
ax = sns.barplot(x=x, y=y)
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # ANDROID SKILLS

# %%
skills_count_android = {}
counter = 0
for skill in skills:
    counter = 0
    for description in android_df['descriptions']:
        if (skill == 'ci'):
            if len(re.findall('ci ', description))>0:
                counter+=1
        elif skill in description:
            counter += 1
    skills_count_android[skill] = counter
skills_count_android = pd.DataFrame(dict(sorted(skills_count_android.items(), key=lambda x: x[1], reverse=True)).items())
skills_count_android.columns = ['skill', 'count']
skills_count_android = skills_count_android[skills_count_android['count']>0]
skills_count_android.head(20)
# Out:
#                    skill  count
# 0                 kotlin    742
# 1                android    712
# 2                   java    640
# 3                testing    510
# 4                  unity    473
# 5            engineering    455
# 6                    git    435
# 7                english    416
# 8          communication    390
# 9                    a b    373
# 10                   ios    309
# 11  software development    270
# 12            management    228
# 13                  apis    228
# 14      computer science    210
# 15                 scala    209
# 16    mobile application    207
# 17                   sdk    202
# 18                rxjava    191
# 19              training    173

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_android.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # ANDROID SKILLS FOR JUNIOR POSITIONS

# %%
skills_count_ios = {}
counter = 0
for skill in skills:
    counter = 0
    for description in android_junior_df['descriptions']:
        if (skill == 'ci'):
            if len(re.findall('ci ', description))>0:
                counter+=1
        elif skill in description:
            counter += 1
    skills_count_ios[skill] = counter
skills_count_ios = pd.DataFrame(dict(sorted(skills_count_ios.items(), key=lambda x: x[1], reverse=True)).items())
skills_count_ios.columns = ['skill', 'count']
skills_count_ios = skills_count_ios[skills_count_ios['count']>0]
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="skill", y="count", data=skills_count_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Top companies Android

# %%
top_companies_android = pd.DataFrame(android_df['company_name'].value_counts()).reset_index()
top_companies_android.columns =['company_name', 'number of postings']
top_companies_android
# Out:
#                             company_name  number of postings
# 0                                zalando                 103
# 1                                 amazon                  77
# 2                          delivery hero                  33
# 3                          client server                  33
# 4                                picsart                  26
# 5                                 zattoo                  25
# 6                                    n26                  21
# 7                         mobile.de gmbh                  20
# 8                                  moyyn                  20
# 9                          tier mobility                  19
# 10                          surprise.com                  17
# 11                               zendesk                  16
# 12                                 flink                  16
# 13                          getyourguide                  15
# 14                      axel springer se                  14
# 15                                 agoda                  14
# 16                          michael page                  12
# 17                               mobimeo                  11
# 18                                klarna                   9
# 19                            soundcloud                   9
# 20                        bending spoons                   9
# 21                                cariad                   9
# 22                              livanova                   9
# 23                                 sumup                   8
# 24                      friday insurance                   8
# 25                 just eat takeaway.com                   8
# 26                          mbition gmbh                   7
# 27                               spotify                   7
# 28                          marley spoon                   7
# 29                     here technologies                   7
# 30                    sigmar recruitment                   7
# 31                            azeti gmbh                   7
# 32                                framen                   7
# 33                             superchat                   7
# 34                                adjust                   6
# 35    vertex solutions international ltd                   6
# 36                               tillhub                   6
# 37                                 xcede                   6
# 38                     sharecare germany                   6
# 39                               scandit                   5
# 40                                 wire™                   5
# 41                                 kayak                   5
# 42                    darwin recruitment                   5
# 43                               sprylab                   5
# 44                                  pleo                   5
# 45                            ubitricity                   5
# 46                                  vivy                   5
# 47                                babbel                   5
# 48                            travelperk                   5
# 49               aperto - an ibm company                   5
# 50                       kfzteile24 gmbh                   5
# 51                             sharecare                   5
# 52                                 oviva                   4
# 53                                  omio                   4
# 54                              join.com                   4
# 55                            ada health                   4
# 56                           auto1 group                   4
# 57                         stott and may                   4
# 58                                 wefox                   4
# 59                  idealo internet gmbh                   4
# 60                 rebuy recommerce gmbh                   4
# 61                            sauce labs                   4
# 62                              atheneum                   4
# 63                            hellofresh                   4
# 64                                trovit                   4
# 65                      lesson nine gmbh                   4
# 66                                zenjob                   4
# 67                                 jodel                   4
# 68                        trade republic                   3
# 69                   transition partners                   3
# 70             amazon web services (aws)                   3
# 71                                 kausa                   3
# 72                  neugelb studios gmbh                   3
# 73                ebay classifieds group                   3
# 74                               dimpact                   3
# 75                     maibornwolff gmbh                   3
# 76                           immoscout24                   3
# 77    kitchen stories - anyone can cook!                   3
# 78                        third republic                   3
# 79                     evolution germany                   3
# 80            craftnote - handwerker app                   3
# 81                        rise technical                   3
# 82                                onfido                   3
# 83                        storecast gmbh                   3
# 84                           globallogic                   3
# 85                                 choco                   3
# 86               vinted / kleiderkreisel                   3
# 87                                  mika                   3
# 88                       discovered mena                   3
# 89                        orange quarter                   3
# 90                         nord security                   3
# 91                             meltwater                   3
# 92             delphi hr-consulting gmbh                   3
# 93                        accenture dach                   3
# 94                         caspar health                   2
# 95                                  fitx                   2
# 96                              applovin                   2
# 97                   lightspeed commerce                   2
# 98                             share now                   2
# 99                    mckinsey & company                   2
# 100                             suitepad                   2
# 101                             diconium                   2
# 102                        hero software                   2
# 103                            doctorbox                   2
# 104                             fantasmo                   2
# 105                               twitch                   2
# 106                                 noir                   2
# 107  carsguide autotrader media solution                   2
# 108                        metro.digital                   2
# 109                               luxoft                   2
# 110                                tribe                   1
# 111                            staffbase                   1
# 112        check24 vergleichsportal gmbh                   1
# 113                                 eyeo                   1
# 114                 snom technology gmbh                   1
# 115                 interim group berlin                   1
# 116                     computer futures                   1
# 117                             free now                   1
# 118                      dhl it services                   1
# 119                         gematik gmbh                   1
# 120                                 eidu                   1
# 121                       ethinking gmbh                   1
# 122                               naviro                   1
# 123                         #blacklane10                   1
# 124                   yara international                   1
# 125                           simpleclub                   1
# 126                       spark networks                   1
# 127                         healthmetrix                   1
# 128                    talentwunder gmbh                   1
# 129        clear edge search & selection                   1
# 130                             doordash                   1

# %%
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=top_companies_android.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # TOP COMPANIES ANDROID FOR JUNIOR POSITIONS

# %%
top_companies_android = pd.DataFrame(android_junior_df['company_name'].value_counts()).reset_index()
top_companies_android.columns =['company_name', 'number of postings']
fig = plt.subplots(figsize= (20,5))
ax = sns.barplot(x="company_name", y="number of postings", data=top_companies_ios.head(20))
plt.xticks(rotation=30)
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, color='black', ha='center', va='bottom')
plt.show()
